# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")
#parser info:  https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
d=soup.find(class_='r-ent')
print('作者: ',d.find(class_="meta").find(class_='author').text)
print('標題: ',d.find(class_="title").text.replace('\t', '').replace('\n', ''))
print('時間: ',d.find(class_='date').text,'\n')
# Out:
# 作者:  Yui5
# 標題:  [情報] Perkins支持LBJ MVP：他是在西區打出表現
# 時間:   3/10

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    看板 NBA 文章列表 - 批踢踢實業坊
#   </title>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#  </head>
#  <body>
#   <div id="topbar-container">
#    <div class="bbs-content" id="topbar">
#     <a href="/bbs/" id="logo">
#      批踢踢實業坊
#     </a>
#     <span>
#      ›
#     </span>
#     <a class="board" href="/bbs/NBA/index.html">
#      <span class="board-label">
#       看板
#      </span>
# ...

# %%
url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)
soup = BeautifulSoup(r.text, "html5lib")



for d in soup.find_all(class_='r-ent'):
    try:
        print(' 作者: ',d.find(class_="meta").find(class_='author').text.replace('\t', '').replace('\n', ''),'\n',
              '標題: ',d.find(class_="title").text.replace('\t', '').replace('\n', ''),'\n',
              '時間: ',d.find(class_='date').text,'\n')
    except:
        continue
# Out:
#  作者:  Yui5
#  標題:  [情報] Perkins支持LBJ MVP：他是在西區打出表現
#  時間:   3/10
#
#  作者:  Yui5
#  標題:  [新聞] 湯瑪斯與克勞佛待價而沽 安吉點出現實殘
#  時間:   3/10
#
#  作者:  VeryGoodBoy
#  標題:  [情報] Perkins: 暴龍教練是今年最佳教練
#  時間:   3/10
#
#  作者:  smallksc
#  標題:  Re: [討論] NBA有誰是低調的強?
#  時間:   3/10
#
#  作者:  PttGod
#  標題:  [新聞] 請纓盯字母哥與雷納德 詹皇：剩下就是歷
#  時間:   3/10
#
#  作者:  -
#  標題:  (本文已被刪除) [go190214]
#  時間:   3/10
#
#  作者:  sodistrues
#  標題:  [新聞] 韋德力薦角逐最佳防守球員 史馬特：真的
#  時間:   3/10
#
#  作者:  PttGod
#  標題:  [情報] 鄧肯羅賓遜本賽季跳投有效命中率67.7%
#  時間:   3/10
#
#  作者:  PttGod
#  標題:  [花邊] A.Smith：不應該對詹姆斯用雙重標準
#  時間:   3/10
#
#  作者:  Gotham
#  標題:  [新聞] 替4連敗火箭開藥單 教頭丹東尼堅持投三分
#  時間:   3/10
#
#  作者:  -
#  標題:  (已被Vedan刪除) <Wall62>1-1(150)
#  時間:   3/10
#
#  作者:  TYisBRoKen
#  標題:  [討論] LBJ跟MJ都是GOAT不行嗎？
#  時間:   3/11
#
#  作者:  pen13ex
#  標題:  [討論] 艇湖最後五分鐘-LeBron挑人打
#  時間:   3/11
#
#  作者:  fukawa947
#  標題:  [花邊] 問手術痛不痛竟釣出KD親回　讓粉絲有勇
#  時間:   3/11
#
#  作者:  -
#  標題:  (已被Vedan刪除) <s111228s>1-1(150)
#  時間:   3/11
#
#  作者:  Vedan
# ...

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
url = 'https://www.ptt.cc/bbs/MLB/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")
for d in soup.find_all(class_='r-ent'):
    #利用try/except 過濾不完整或非正確target
    try:
        print(' 作者: ',d.find(class_="meta").find(class_='author').text,'\n',
              '標題: ',d.find(class_="title").text.replace('\t', '').replace('\n', ''),'\n',
              '時間: ',d.find(class_='date').text,'\n')
    except:
        continue
# Out:
#  作者:  ylrafale
#  標題:  [新聞] 2020/03/07消息彙整
#  時間:   3/08
#
#  作者:  davidex
#  標題:  Re: [閒聊] 一朗人氣超旺的原因是什麼?
#  時間:   3/08
#
#  作者:  greenpeace21
#  標題:  Re: [閒聊] 一朗人氣超旺的原因是什麼?
#  時間:   3/08
#
#  作者:  ylrafale
#  標題:  [新聞] 2020/03/08消息彙整
#  時間:   3/08
#
#  作者:  pneumo
#  標題:  [外電] 條子Willie Calhoun觸身球打到 下巴骨折
#  時間:   3/09
#
#  作者:  pneumo
#  標題:  [閒聊] A-Rod跟J-Lo玩Flip the Switch
#  時間:   3/09
#
#  作者:  ylrafale
#  標題:  [新聞] 2020/03/09消息彙整
#  時間:   3/09
#
#  作者:  x6073123
#  標題:  [情報] Kershaw 被任命為本季開幕戰先發
#  時間:   3/10
#
#  作者:  ShockHo222
#  標題:  [情報] Verlander背闊肌拉傷
#  時間:   3/10
#
#  作者:  pneumo
#  標題:  [外電] 有人假冒Lincecum騙NFL球員Hayden Hurst
#  時間:   3/10
#
#  作者:  ylrafale
#  標題:  [新聞] 2020/03/10消息彙整
#  時間:   3/10
#
#  作者:  pneumo
#  標題:  [情報] Gary Sanchez發燒未上場
#  時間:   3/11
#
#  作者:  -
#  標題:  (本文已被刪除) [c871111116]
#  時間:   3/11
#
#  作者:  s90523
#  標題:  [公告] 2018 MLB板 板規
#  時間:   3/30
#
#  作者:  ZaneTrout
#  標題:  [公告] 臨時閒聊怒灌區
#  時間:   2/13
#
#  作者:  iambiaggi
#  標題:  [公告] 2020 MLB.TV 徵求區
# ...
