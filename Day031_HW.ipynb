# %% [markdown]
# # 反爬：瀏覽器標頭與基本資訊
#
#
# * 了解「檢查 HTTP 標頭檔」的反爬蟲機制
# * 「檢查 HTTP 標頭檔」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）
# * 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %%
import requests

# %% [markdown]
# ### 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）

# %% [raw]
# url='https://www.amazon.com/'
# r = requests.get(url)
# response = r.text
# response

# %% [markdown]
# ### 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %%
url='https://www.amazon.com/'
headers={'authority': 'www.amazon.com',
'method': 'GET','scheme':'https','cookie':'ubid-main=132-9452149-6169721; lc-main=en_US; x-wl-uid=1JIaCwE9fTq55CtanPAyE/LozYqqsy3RGBzeqwno3/iYCyFnp/KZySkd2cHP7uq7g5NWpNI1mwTnsdVR7OPbVtLpar2VcqaJhquu+YdBJL5oQfqdKRCco+skVsjaDvhHL3yV1l0gguts=; session-id=136-9141466-0979211; s_fid=43FCB00EEA985563-11DE43C365FD007D; regStatus=pre-register; s_ev22=%5B%5B%27missing%27%2C%271569862517975%27%5D%5D; _sdsat_custID=amzn1.account.AHAZVVFJ5OBNKKACL3RWZZ53XEBA; AMCV_69C78985561E42B67F000101%40AdobeOrg=283337926%7CMCIDTS%7C18177%7CMCMID%7C49102598866924106089074650042336594056%7CMCAID%7CNONE; lc=en_US; s_vnum=1979452825621%26vn%3D15; x-main="1AFBOAGP0q7SpxTVDKdn9r7WxvV?T?j2RtqqN13LTVGV?SxI5E8RtK9BQpLkRFRA"; at-main=Atza|IwEBIMLUXl_wPHTver0OlTuosT73q6TycO_dn521IXhI1n97YlTdRsWIWLana7mdGrfUD5ICjZ0et5ohjukr0QFbbSUXC-cAIrfnr2Amg-5F1Bhq6tSNX9a6EQ2K6Be7r1649e1ruv6MUrLLFXu5CtnIKHPoovwtK6XWIs15Rw3-1j9J9RtEDIrQIkZdTA5JvilNnvD1RM7sePhUt0k7FWpCyWs7i9uwI3Xi1lrXBbOhS4uMs8lkWI4WPmI5n2S3b1bWsf-jOTnOLynvXX-7ouy0t5X_SJlSubMxxEMubFSUPj0v_4GFxvwFPPsqw6r0Ml9MuL_0txbaXjzMOZlOMVyssfjEdMlUVw3rJ3k-myHPUYI9oKJ37vagaifJz_SD-qN2RhwnNwEt47Knwnvyr-Tvdd1b; sess-at-main="xFmtJ1F/4utmb8YW4Ht0qj3SlaQYlo6OpZwVLP9aOas="; sst-main=Sst1|PQGcvSWI62X7TPvi2kl_CPwWC2Sf5fTcZOPEhp3AaFF6CzUPs7mprDH4hXP4SAhhWWdW8ZRaT1Vxgz1Y_JMrJQw53jSI4CTmBqPI6cT-ZCEO9WixdIcIvSX0TNnMSHWTQYc5g769jfP-An2wgL7r04-bcJTg9r5mqctdPMbMSjD57t2XB90J7M_bgSJfBbKgraWaSFGm_1sgn1FXnGS5wSo6aSTb3ZNNfZiGLAl_1GC4X4cI2q8lkubF75cbzECCBGVf0oXudILQ4E1RLplPU2EZtcsVratazHXor16IYhvPbPey4FOGrSUnwduI7RGGggC5N7UHjAKHPg7Nsizjhxpj5w; i18n-prefs=USD; session-id-time=2082787201l; s_cc=true; aws-priv=eyJ2IjoxLCJzdCI6MX0=; s_sq=%5B%5BB%5D%5D; s_dslv=1587074430518; s_vn=1599932035997%26vn%3D3; s_nr=1587074430526-Repeat; skin=noskin; session-token=""; csm-hit=tb:s-KH83V31GT2MY4S4YV5PS|1589518493620&adb:adblk_yes&t:1589518496082',
'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}
r=requests.get(url,headers=headers)
response=r.text
response
# Out:
# '<!doctype html><html lang="en-us" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script><!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'><link rel="dns-prefetch" href="https://images-na.ssl-images-amazon.com" crossorigin><link rel="preconnect" href="https://images-na.ssl-images-amazon.com" crossorigin><link rel="dns-prefetch" href="https://m.media-amazon.com" crossorigin><link rel="preconnect" href="https://m.media-amazon.com" crossorigin><link rel="dns-prefetch" href="https://completion.amazon.com" crossorigin><link rel="preconnect" href="https://completion.amazon.com" crossorigin><script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d
# ...
