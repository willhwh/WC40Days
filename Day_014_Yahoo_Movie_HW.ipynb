# %% [markdown]
# # YAHOO電影爬蟲練習
# ## 練習爬取電影放映資訊。必須逐步獲取電影的代號、放映地區、放映日期後，再送出查詢給伺服器。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先搜尋全部的電影代號(ID)資訊

# %%
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="zh_TW">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, user-minimum-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="501887343352051" property="fb:app_id"/>
#   <meta content="Yahoo奇摩電影" property="og:site_name"/>
#   <title>
#    Yahoo奇摩電影
#   </title>
#   <meta content="Yahoo奇摩電影" name="twitter:title"/>
#   <meta content="Yahoo奇摩電影" property="og:title"/>
#   <link href="https://movies.yahoo.com.tw" rel="canonical"/>
#   <meta content="https://movies.yahoo.com.tw" property="og:url"/>
#   <meta content="提供最新的電影資訊、預告片、劇照、電影時刻表、明星資訊、網友期待榜、網友滿意榜、票房榜和電影相關動態" name="twitter:description"/>
#   <meta content="提供最新的電影資訊、預告片、劇照、電影時刻表、明星資訊、網友期待榜、網友滿意榜、票房榜和電影相關動態" name="description"/>
#   <meta content="提供最新的電影資訊、預告片、劇照、電影時刻表、明星資訊、網友期待榜、網友滿意榜、票房榜和電影相關動態" property="og:description"/>
#   <meta content="https://movies.yahoo.com.tw/build/images/ogImage.png" name="twitter:image"/>
#   <meta content="https://movies.yahoo.com.tw/build/images/ogImage.png" property="og:image"/>
#   <meta content="https://movies.yahoo.com.tw/build/images/ogImage.png" name="twitter:image:src"/>
#   <meta content="電影, yahoo奇摩電影, 時刻表, 新片, 預告片, 網友滿意榜, yahoo 電影, 劇照, 線上訂票, 票房, 台北票房, 全美票房, 排行榜, 戲院, 片名, 電視, 熱映中, 本週新片, 海報, 滿意度, 期待度" name="keywords"/>
#   <script type="application/ld+json">
#    {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "https://movies.yahoo.com.tw",
#     "potentialAction": {
#       "@type": "SearchAction",
#       "target": "/moviesearch_result.html?keyword={search_term_string}",
#       "query-input": "required name=search_term_string"
#     }
#   }
#   </script>
#   <link href="/build/css/app.css?id=eadc5e22ade55ba173fe&amp;r=1555478321" rel="stylesheet"/>
#   <meta content="guce.yahoo.com.tw" name="oath:guce:consent-host"/>
#   <!-- Consent Manager Tag : Script -->
#   <script async="" src="https://consent.cmp.oath.com/cmp.js" type="text/javascript">
#   </script>
#   <!-- Consent Manager Tag : Stubbed (updated 2018-04-27T17:00) -->
#   <script type="text/javascript">
#    (function () {
#         var gdprAppliesGlobally = false;
#
#         function addFrame() {
#             if (!window.frames['__cmpLocator']) {
#                 if (document.body && document.body.firstChild) {
#                     var body = document.body,
#                         iframe = document.createElement('iframe');
#
#                       iframe.style.display = 'none';
# 			  iframe.height = iframe.width = 0;
#
#                     iframe.name = '__cmpLocator';
#                     body.insertBefore(iframe, body.firstChild);
#                 } else {
#                     setTimeout(addFrame, 5);
#                 }
#             }
#         }
#
#         addFrame();
#
#         function stubCMP() {
#             var b = arguments;
#             __cmp.a = __cmp.a || [];
#
#             if (!b.length) return __cmp.a;
#             else if (b[0] === 'ping') {
#                 b[2]({
#                     "gdprAppliesGlobally": gdprAppliesGlobally,
#                     "cmpLoaded": false
#                 }, true);
#             }
#             else {
#                 __cmp.a.push([].slice.apply(b));
#             }
#         }
#
#         function cmpMsgHandler(event) {
#             var msgIsString = typeof event.data === "string";
#             var json = event.data;
#             if (msgIsString) {
#                 try {
#                     json = JSON.parse(event.data);
#                 } catch (e) {}
#             }
#             if (json.__cmpCall) {
#                 var i = json.__cmpCall;
#                 window.__cmp(i.command, i.parameter, function (retValue, success) {
#                     var returnMsg = {
#                         "__cmpReturn": {
#                             "returnValue": retValue,
#                             "success": success,
#                             "callId": i.callId
#                         }
#                     };
#                     event.source.postMessage(msgIsString ?
#                         JSON.stringify(returnMsg) : returnMsg, '*');
#                 });
#             }
#         }
#
#         if (typeof (__cmp) !== 'function') {
#             window.__cmp = stubCMP;
#             __cmp.msgHandler = cmpMsgHandler;
#             if (window.addEventListener)
#                 window.addEventListener('message', cmpMsgHandler, false);
#             else window.attachEvent('onmessage', cmpMsgHandler);
#         }
#     })();
#   </script>
#   <!-- End Consent Manager Tag : Stubbed -->
#   <script type="text/javascript">
#    window.__cmp('init');
#   </script>
#  </head>
#  <body id="">
#   <data data-login="false" data-login-href="https://movies.yahoo.com.tw/login">
#   </data>
#   <span data-id="794026701" id="ad-space-id">
#   </span>
#   <span data-id="2" id="pt-type">
#   </span>
#   <!--Website-->
#   <div id="maincontainer">
#    <header>
#     <div id="y-header">
#      <nav class="nav content">
#       <ul>
#        <li>
#         <a class="gabtn" data-ga="['頻道入口','頻道入口_Yahoo首頁','頁首_頻道入口']" href="https://tw.yahoo.com/">
#          <span class="icon_home">
#          </span>
#          首頁
#         </a>
#        </li>
#        <li>
#         <a class="gabtn" data-ga="['頻道入口','頻道入口_信箱','頁首_頻道入口']" href="https://tw.mail.yahoo.com/">
#          信箱
#         </a>
#        </li>
#        <li>
#         <a class="gabtn" data-ga="['頻道入口','頻道入口_新聞','頁首_頻道入口']" href="https://tw.news.yahoo.com/">
#          新聞
#         </a>
#        </li>
#        <li>
#         <a class="gabtn" data-ga="['頻道入口','頻道入口_股市','頁首_頻道入口']" href="https://tw.stock.yahoo.com/">
#          股市
#         </a>
#        </li>
#        <li>
#         <a class="gabtn" data-ga="['頻道入口','頻道入口_氣象','頁首_頻道入口']" href="https://tw.news.yahoo.com/weather-forecast/">
#          氣象
#         </a>
#        </li>
#        <li>
#         <a class="gabtn" data-ga="['頻道入口','頻道入口_運動','頁首_頻道入口']" href="https://tw.sports.yahoo.com/">
#          運動
#         </a>
#        </li>
#        <li>
#         <a class="gabtn" data-ga="['頻道入口','頻道入口_名人娛樂','頁首_頻道入口']" href="https://tw.news.yahoo.com/entertainment">
#          名人娛樂
#         </a>
#        </li>
#        <li>
#         <a class="gabtn" data-ga="['頻道入口','頻道入口_App下載','頁首_頻道入口']" href="http://tw.mobile.yahoo.com/">
#          App下載
#         </a>
#        </li>
#        <li>
#         <a class="gabtn" data-ga="['頻道入口','頻道入口_購物中心','頁首_頻道入口']" href="https://tw.buy.yahoo.com/">
#          購物中心
#         </a>
#        </li>
#        <li>
#         <a class="gabtn" data-ga="['頻道入口','頻道入口_商域','頁首_頻道入口']" href="https://tw.mall.yahoo.com/">
#          商城
#         </a>
#        </li>
#        <li>
#         <a class="gabtn" data-ga="['頻道入口','頻道入口_拍賣','頁首_頻道入口']" href="https://tw.bid.yahoo.com/">
#          拍賣
#         </a>
#        </li>
#        <li class="nav_more">
#         <a href="javascript:void(0)">
#          更多
#          <span class="icon_more">
#          </span>
#         </a>
#         <div class="dropdown_list">
#          <dl>
#           <dd>
#            <a class="gabtn" data-ga="['頻道入口','頻道入口_影音','頁首_頻道入口']" href="https://tw.video.yahoo.com/">
#             影音
#            </a>
#           </dd>
#           <dd>
#            <a class="gabtn" data-ga="['頻道入口','頻道入口_知識+','頁首_頻道入口']" href="https://tw.knowledge.yahoo.com/">
#             知識+
#            </a>
#           </dd>
#           <dd>
#            <a class="gabtn" data-ga="['頻道入口','頻道入口_汽車機車','頁首_頻道入口']" href="https://autos.yahoo.com.tw/">
#             汽車機車
#            </a>
#           </dd>
#           <dd>
#            <a class="gabtn" data-ga="['頻道入口','頻道入口_電影','頁首_頻道入口']" href="https://movies.yahoo.com.tw/">
#             電影
#            </a>
#           </dd>
#           <dd>
#            <a class="gabtn" data-ga="['頻道入口','頻道入口_字典','頁首_頻道入口']" href="https://tw.dictionary.yahoo.com/">
#             字典
#            </a>
#           </dd>
#           <dd>
#            <a class="gabtn" data-ga="['頻道入口','頻道入口_遊戲','頁首_頻道入口']" href="https://games.yahoo.com.tw/">
#             遊戲
#            </a>
#           </dd>
#           <dd>
#            <a class="gabtn" data-ga="['頻道入口','頻道入口_旅遊','頁首_頻道入口']" href="https://travel.yahoo.com.tw/">
#             旅遊
#            </a>
#           </dd>
#           <dd>
#            <a class="gabtn" data-ga="['頻道入口','頻道入口_理財','頁首_頻道入口']" href="https://tw.money.yahoo.com/">
#             理財
#            </a>
#           </dd>
#           <dd>
#            <a class="gabtn" data-ga="['頻道入口','頻道入口_房地產','頁首_頻道入口']" href="https://house.yahoo.com.tw/">
#             房地產
#            </a>
#           </dd>
#           <dd>
#            <a class="gabtn" data-ga="['頻道入口','頻道入口_時尚美妝','頁首_頻道入口']" href="https://style.yahoo.com.tw/">
#             時尚美妝
#            </a>
#           </dd>
#           <dd>
#            <a class="gabtn" data-ga="['頻道入口','頻道入口_折扣城','頁首_頻道入口']" href="https://tw.discount.yahoo.net/index.php?group=all">
#             折扣城
#            </a>
#           </dd>
#          </dl>
#         </div>
#        </li>
#       </ul>
#      </nav>
#     </div>
#     <div id="kv">
#      <div class="content">
#       <div class="_c" id="y_hous_serch">
#        <div id="y_serch_l">
#         <a class="gabtn" data-ga="['電影頻道logo','電影頻道logo_連結','頁首_電影頻道logo']" href="https://movies.yahoo.com.tw/index.html" id="ylogo">
#          <img alt="Yahoo Logo" src="/build/images/header_logo.png" srcset="/build/images/header_logo@2x.png 2x, /build/images/header_logo@3x.png 3x"/>
#         </a>
#         <form action="https://tw.search.yahoo.com/search" method="get" target="_blank">
#          <input autocomplete="off" id="serchinput" name="p" placeholder="搜尋" type="text"/>
#          <div class="inputex" style="visibility:hidden">
#          </div>
#          <button class="serch_movie gabtn" data-ga="['top search','top search_電影明星搜尋','']" data-input="['input','serchinput','']">
#           電影‧明星搜尋
#          </button>
#          <!--20170531-->
#          <button class="gabtn" data-ga="['top search','top search_網頁搜尋','']" data-input="['input','serchinput','']" type="submit">
#           網頁搜尋
#          </button>
#          <!--20170531-->
#          <input id="fr" name="fr" type="hidden" value="ush-movies"/>
#         </form>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!-- jurisdiction-type: US -->
#     <div id="bg_main_menu">
#      <div class="content">
#       <ul id="mainmenu">
#        <li>
#         <a class="gabtn" data-ga="['選單','選單_首頁','頁首_選單']" href="https://movies.yahoo.com.tw/" target="">
#          <span>
#           首頁
#          </span>
#         </a>
#        </li>
#        <li>
#         <a class="gabtn" data-ga="['選單','選單_本週新片','頁首_選單']" href="https://movies.yahoo.com.tw/movie_thisweek.html" target="">
#          <span>
#           本週新片
#          </span>
#         </a>
#        </li>
#        <li>
#         <a class="gabtn" data-ga="['選單','選單_上映中','頁首_選單']" href="https://movies.yahoo.com.tw/movie_intheaters.html" target="">
#          <span>
#           上映中
#          </span>
#         </a>
#        </li>
#        <li>
#         <a class="gabtn" data-ga="['選單','選單_即將上映','頁首_選單']" href="https://movies.yahoo.com.tw/movie_comingsoon.html" target="">
#          <span>
#           即將上映
#          </span>
#         </a>
#        </li>
#        <li>
#         <a class="gabtn" data-ga="['選單','選單_預告片','頁首_選單']" href="https://movies.yahoo.com.tw/trailer_index.html" target="">
#          <span>
#           預告片
#          </span>
#         </a>
#        </li>
#        <li>
#         <a class="gabtn" data-ga="['選單','選單_排行榜','頁首_選單']" href="https://movies.yahoo.com.tw/chart.html" target="">
#          <span>
#           排行榜
#          </span>
#         </a>
#        </li>
#        <li class="hassub">
#         <a class="gabtn" data-ga="['選單','選單_情報站','頁首_選單']" href="https://movies.yahoo.com.tw/article_index.html" target="">
#          <span>
#           情報站
#          </span>
#         </a>
#         <div class="submenu">
#          <dl class="submenu_inner">
#           <dt>
#            <a class="gabtn" data-ga="['選單','選單_情報站_電影新聞','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/movieheadline" target="">
#             電影新聞
#            </a>
#           </dt>
#           <dt>
#            <a class="gabtn" data-ga="['選單','選單_情報站_專題報導','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/spotlight" target="">
#             專題報導
#            </a>
#           </dt>
#           <dt>
#            <a class="gabtn" data-ga="['選單','選單_情報站_影評','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/moviereview" target="">
#             影評
#            </a>
#           </dt>
#           <dt>
#            <a class="gabtn" data-ga="['選單','選單_情報站_精彩圖片','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/slideshow" target="">
#             精彩圖片
#            </a>
#           </dt>
#           <dt>
#            <a class="gabtn" data-ga="['選單','選單_情報站_懶人卡','頁首_選單']" href="https://tw.youcard.yahoo.com/category/movie" target="_blank">
#             懶人卡
#            </a>
#           </dt>
#          </dl>
#         </div>
#        </li>
#        <li>
#         <a class="gabtn" data-ga="['選單','選單_電視時刻','頁首_選單']" href="https://movies.yahoo.com.tw/tv_index.html" target="">
#          <span>
#           電視時刻
#          </span>
#         </a>
#        </li>
#       </ul>
#       <dl id="sharebox">
#        <dt>
#         追蹤我們
#        </dt>
#        <dd class="gabtn" data-ga="['選單','選單_追蹤我們','頁首_選單']" onclick="javascript:window.open('https://www.facebook.com/Ymovie/');">
#        </dd>
#       </dl>
#      </div>
#     </div>
#    </header>
#    <!--主內容-->
#    <main>
#     <!--top_ad-->
#     <div class="maincontent ga_index">
#      <div class="boxAD" id="boxMAST">
#      </div>
#      <div class="content _c" id="top_serch">
#       <div data-topserch="0">
#        <div class="tab_serch _c">
#         <div class="tab_hot">
#          <a class="gabtn" data-ga="['search box','search box_熱門1','窪塚洋介']" href="https://movies.yahoo.com.tw/movieinfo_main/最初的晚餐-the-first-supper-10510" target="">
#           窪塚洋介
#          </a>
#          <a class="gabtn" data-ga="['search box','search box_熱門2','噤界II']" href="https://movies.yahoo.com.tw/movieinfo_main/噤界II-a-quiet-place-part-ii-10435" target="">
#           噤界II
#          </a>
#          <a class="gabtn" data-ga="['search box','search box_熱門3','記憶屋']" href="https://movies.yahoo.com.tw/movieinfo_main/記憶屋-kiokuya-10470" target="">
#           記憶屋
#          </a>
#         </div>
#         <a class="btn_booking btn_toptxt gabtn" data-ga="['search box','search box_訂票客服中心','']" href="https://www.ezding.com.tw/page/faq/faq.html" target="_blank">
#          訂票客服中心
#         </a>
#         <a class="btn_all btn_toptxt gabtn" data-ga="['search box','search box_戲院總覽','']" href="https://movies.yahoo.com.tw/theater_list.html">
#          戲院總覽
#         </a>
#        </div>
#        <span data-url="https://movies.yahoo.com.tw" id="mainURL">
#        </span>
#        <span data-type="0" id="searchType">
#        </span>
#        <div class="tab_serchbar">
#         <div class="icon_serch">
#         </div>
#         <select id="movie_time" name="search_type">
#          <option value="0">
#           電影時刻
#          </option>
#          <option value="1">
#           電視時刻
#          </option>
#          <option value="2">
#           快速訂票
#          </option>
#          <option value="3">
#           電影/明星搜尋
#          </option>
#         </select>
#         <!--tab_serchbar  style0-->
#         <div class="top_change" data-change="0" style="">
#          <form action="https://movies.yahoo.com.tw/movietime_result.html" id="form_moviearea" method="get">
#           <span>
#            選擇
#            <br/>
#            片名
#           </span>
#           <select class="movie_name" id="sbox_mid" name="movie_id">
#            <option value="">
#             請選擇片名
#            </option>
#            <option data-name="電影版 地獄少女" value="10525">
#             電影版 地獄少女
#            </option>
#            <option data-name="刺激1995" value="10518">
#             刺激1995
#            </option>
#            <option data-name="通靈少年2020" value="10517">
#             通靈少年2020
#            </option>
#            <option data-name="安雅的回家路" value="10516">
#             安雅的回家路
#            </option>
#            <option data-name="牆內的房客" value="10512">
#             牆內的房客
#            </option>
#            <option data-name="南山的部長們" value="10509">
#             南山的部長們
#            </option>
#            <option data-name="另類神父" value="10500">
#             另類神父
#            </option>
#            <option data-name="破．局" value="10496">
#             破．局
#            </option>
#            <option data-name="劇場版 不起眼女主角培育法 Fine" value="10486">
#             劇場版 不起眼女主角培育法 Fine
#            </option>
#            <option data-name="複製柔伊" value="10455">
#             複製柔伊
#            </option>
#            <option data-name="練愛iNG" value="10442">
#             練愛iNG
#            </option>
#            <option data-name="鋼鐵勳章" value="10432">
#             鋼鐵勳章
#            </option>
#            <option data-name="我，最親愛的" value="10503">
#             我，最親愛的
#            </option>
#            <option data-name="血衛" value="10469">
#             血衛
#            </option>
#            <option data-name="導演先生的完美假期" value="10545">
#             導演先生的完美假期
#            </option>
#            <option data-name="大地蜜語" value="10513">
#             大地蜜語
#            </option>
#            <option data-name="狂飆一夢" value="10506">
#             狂飆一夢
#            </option>
#            <option data-name="親愛的莎瑪" value="10491">
#             親愛的莎瑪
#            </option>
#            <option data-name="大畫特務" value="10478">
#             大畫特務
#            </option>
#            <option data-name="戰慄糖果屋" value="10472">
#             戰慄糖果屋
#            </option>
#            <option data-name="失戀殺人：三角禁戀" value="10465">
#             失戀殺人：三角禁戀
#            </option>
#            <option data-name="明明會說話" value="10440">
#             明明會說話
#            </option>
#            <option data-name="艾瑪" value="10396">
#             艾瑪
#            </option>
#            <option data-name="罪樂園" value="10349">
#             罪樂園
#            </option>
#            <option data-name="鳴鳥不飛：烏雲密布" value="10458">
#             鳴鳥不飛：烏雲密布
#            </option>
#            <option data-name="哥布林殺手 劇場版" value="10438">
#             哥布林殺手 劇場版
#            </option>
#            <option data-name="女鬼橋" value="10437">
#             女鬼橋
#            </option>
#            <option data-name="怨咒" value="10421">
#             怨咒
#            </option>
#            <option data-name="娘娘腔日記" value="10401">
#             娘娘腔日記
#            </option>
#            <option data-name="極地守護犬" value="10383">
#             極地守護犬
#            </option>
#            <option data-name="叔．叔" value="10371">
#             叔．叔
#            </option>
#            <option data-name="隱形人" value="10359">
#             隱形人
#            </option>
#            <option data-name="電影音效傳奇：好萊塢之聲" value="10484">
#             電影音效傳奇：好萊塢之聲
#            </option>
#            <option data-name="悲慘世界" value="10479">
#             悲慘世界
#            </option>
#            <option data-name="閃閃小超人電影版" value="10474">
#             閃閃小超人電影版
#            </option>
#            <option data-name="陰櫥" value="10457">
#             陰櫥
#            </option>
#            <option data-name="絕命大平台" value="10447">
#             絕命大平台
#            </option>
#            <option data-name="李察朱威爾事件" value="10368">
#             李察朱威爾事件
#            </option>
#            <option data-name="音速小子" value="9246">
#             音速小子
#            </option>
#            <option data-name="逃出夢幻島" value="10485">
#             逃出夢幻島
#            </option>
#            <option data-name="超＂人＂氣動物園" value="10445">
#             超＂人＂氣動物園
#            </option>
#            <option data-name="就愛斷捨離" value="10436">
#             就愛斷捨離
#            </option>
#            <option data-name="猛禽小隊：小丑女大解放" value="10268">
#             猛禽小隊：小丑女大解放
#            </option>
#            <option data-name="紅鞋公主與七矮人" value="10417">
#             紅鞋公主與七矮人
#            </option>
#            <option data-name="1917" value="10189">
#             1917
#            </option>
#            <option data-name="你的情歌" value="10407">
#             你的情歌
#            </option>
#            <option data-name="她們" value="10202">
#             她們
#            </option>
#            <option data-name="巧虎電影：英雄遊樂園" value="10429">
#             巧虎電影：英雄遊樂園
#            </option>
#            <option data-name="寄生上流" value="10020">
#             寄生上流
#            </option>
#           </select>
#           <span>
#            選擇
#            <br/>
#            地區
#           </span>
#           <select class="movie_area" id="sbox_aid" name="area_id">
#           </select>
#           <div class="btn_serch gabtn" data-ga="['search box','search box_電影時刻','']" data-input="['select','sbox_mid','sbox_aid']">
#            查詢
#           </div>
#          </form>
#         </div>
#         <!--tab_serchbar  style1-->
#         <div class="top_change" data-change="1" style="display:none;">
#          <form action="https://movies.yahoo.com.tw/tv_channels.html" id="form_catechannel" method="get" style="display:inline;">
#           <span>
#            選擇
#            <br/>
#            分類
#           </span>
#           <select class="movie_theater" id="sbox_cid" name="tv_category_id">
#            <option value="">
#             請選擇分類
#            </option>
#            <option data-name="西片" value="1">
#             西片
#            </option>
#            <option data-name="國片" value="2">
#             國片
#            </option>
#            <option data-name="戲劇" value="3">
#             戲劇
#            </option>
#            <option data-name="體育" value="4">
#             體育
#            </option>
#            <option data-name="綜合" value="5">
#             綜合
#            </option>
#            <option data-name="知性" value="6">
#             知性
#            </option>
#            <option data-name="日本" value="7">
#             日本
#            </option>
#            <option data-name="音樂" value="8">
#             音樂
#            </option>
#            <option data-name="卡通" value="9">
#             卡通
#            </option>
#            <option data-name="新聞" value="10">
#             新聞
#            </option>
#            <option data-name="財經" value="11">
#             財經
#            </option>
#            <option data-name="宗教" value="12">
#             宗教
#            </option>
#           </select>
#           <span>
#            選擇
#            <br/>
#            頻道
#           </span>
#           <select class="movie_name" id="sbox_chid" name="channel">
#           </select>
#           <div class="btn_serch gabtn" data-ga="['search box','search box_電視時刻','']" data-input="['select','sbox_cid','sbox_chid']">
#            查詢
#           </div>
#          </form>
#          <form action="https://movies.yahoo.com.tw/tvtime_result.html" id="form_channelname" method="get" style="display:inline;">
#           <input autocomplete="off" class="tvserch" id="sbox_cname" name="tv_channel_name" onblur="this.placeholder='電視節目查詢'" onfocus="this.placeholder=''" onkeypress="chlSearchForm(event);" placeholder="電視節目查詢" type="text"/>
#           <div class="btn_serch gabtn" data-ga="['search box','search box_電視節目查詢','']" data-input="['input','sbox_cname','']">
#            查詢
#           </div>
#          </form>
#         </div>
#         <!--tab_serchbar  style2-->
#         <div class="top_change" data-change="2" style="display:none;">
#          <form action="https://www.ezding.com.tw/page/booking/index.html?channel=yahoo&amp;campaign_code=yahoopc" id="form_movieticket" method="get">
#           <span>
#            選擇
#            <br/>
#            戲院
#           </span>
#           <select class="movie_theater" id="sbox_tid" name="cinemaId">
#            <option value="">
#             請選擇戲院
#            </option>
#            <option value="40288eb0050f542401050f554e7e0674">
#             台北信義威秀影城
#            </option>
#            <option value="5f60dacd-45b3-102d-8d74-e400529c">
#             台北京站威秀影城
#            </option>
#            <option value="470e99e70b5611eaa91e06ba2bcebcfa">
#             MUVIE CINEMAS台北松仁威秀
#            </option>
#            <option value="46efa950eafa11e38b12987bdb90dba4">
#             台北樂聲影城
#            </option>
#            <option value="40288eb0050f542401050f5550201811">
#             哈拉影城
#            </option>
#            <option value="40288eb0050f542401050f5681782dc5">
#             喜樂時代影城南港店
#            </option>
#            <option value="40288eb0050f542401050f5566201ba4">
#             台北華威天母影城
#            </option>
#            <option value="40288eb0050f542401050f551a8a48c3">
#             台北日新威秀影城
#            </option>
#            <option value="40288eb0050f542401050f55532606b5">
#             喜滿客絕色影城
#            </option>
#            <option value="40288eb0050f31210ada0f55676b1bbc">
#             台北美麗華大直影城
#            </option>
#            <option value="b020ba50fbc811e58858f2128151146f">
#             梅花數位影院
#            </option>
#            <option value="f644412efbb811e58858f2128151146f">
#             台北真善美劇院
#            </option>
#            <option value="737ece862a0111e18e86000bdb90dba4">
#             板橋大遠百威秀影城
#            </option>
#            <option value="4c163aba9c5311e494ae8b4ddf78b93a">
#             台北新民生戲院
#            </option>
#            <option value="73544d843cd311e69bb83d0f96c001c2">
#             林口MITSUI OUTLET PARK威秀影城
#            </option>
#            <option value="e9c365f27f4e11e494ae8b4ddf78b93a">
#             台北in89豪華數位影城
#            </option>
#            <option value="cf2b5aa8132f11e6b767a1b123456789">
#             台北新光影城
#            </option>
#            <option value="c072c5c43fc011e9a245782bcb259cad">
#             喜樂時代影城永和店
#            </option>
#            <option value="5d4b59f567ac11e7a6b1061be09fe071">
#             桃園in89統領影城
#            </option>
#            <option value="c256b670b10811e8959e782bcb259cad">
#             桃園統領威秀影城
#            </option>
#            <option value="40288eb0050f542401050f5573651ca2">
#             新竹大遠百威秀影城
#            </option>
#            <option value="4f9fbbac7a2d11e18e86000bdb90dba4">
#             新竹巨城威秀影城
#            </option>
#            <option value="883ddebefe9e11e49e5e8d16c6a1d23a">
#             頭份尚順威秀影城
#            </option>
#            <option value="40288eb0050f542401050f5576601cdc">
#             台中Tiger City威秀影城
#            </option>
#            <option value="7ff29bea908122e9060e893bcb360cad">
#             台中豐原in89豪華影城
#            </option>
#            <option value="9f1b3df8f0a44110ab9412513c546d33">
#             台中新時代凱擘影城
#            </option>
#            <option value="84599c0a220d11e18e86000bdb90dba4">
#             台中大遠百威秀影城
#            </option>
#            <option value="5307fea6405811e392f7000bdb90dba4">
#             台中華威台中影城
#            </option>
#            <option value="9fa318f9c99f4f6987a46efc5e3f50f2">
#             台中新光影城
#            </option>
#            <option value="40288eb0050f542401050f557dfc1d65">
#             台南大遠百威秀影城
#            </option>
#            <option value="370b0003943222e8a7b2172be10fe182">
#             台南FOCUS威秀影城
#            </option>
#            <option value="c3ab0cdc8cad11e494ae8b4ddf78b93a">
#             台南南紡威秀影城
#            </option>
#            <option value="5d4b59f597ac11e7a6b1091be09fe001">
#             台南真善美劇院
#            </option>
#            <option value="a6f9c512bec5463183d3d7eaec37fb42">
#             台南新光影城
#            </option>
#            <option value="40288eb0050f542401050f5582141dac">
#             高雄大遠百威秀影城
#            </option>
#            <option value="44f76448bf2511e59a5d4b53bcb866d6">
#             高雄in89駁二電影院
#            </option>
#            <option value="40288eb0050f542401050f5581582dc5">
#             喜滿客夢時代影城
#            </option>
#            <option value="2c28121ae2c711e292f7000bdb90dba4">
#             中影屏東影城
#            </option>
#            <option value="e8bf57d61edb11e9a245782bcb259cad">
#             花蓮新天堂樂園威秀影城
#            </option>
#            <option value="6ff18bea897011e8959e782bcb259cad">
#             澎湖in89豪華影城
#            </option>
#           </select>
#           <span>
#            選擇
#            <br/>
#            片名
#           </span>
#           <select class="movie_name" id="sbox_tmid" name="movieId">
#           </select>
#           <span>
#            選擇
#            <br/>
#            日期
#           </span>
#           <select class="movie_day" name="showDate">
#           </select>
#           <span>
#            選擇
#            <br/>
#            場次
#           </span>
#           <select class="movie_screenings" name="session">
#           </select>
#           <span>
#            選擇
#            <br/>
#            數量
#           </span>
#           <select class="movie_amount" name="ticketQuantity">
#           </select>
#           <div class="btn_serch gabtn" data-ga="['search box','search box_快速訂票','']" data-input="['select','sbox_tid','sbox_tmid']">
#            查詢
#           </div>
#          </form>
#         </div>
#         <!--tab_serchbar  style3-->
#         <div class="top_change" data-change="3" style="display:none;">
#          <form action="https://movies.yahoo.com.tw/moviesearch_result.html" id="form_starsearch" method="get">
#           <input autocomplete="off" class="starserch" id="starserch" name="keyword" onblur="this.placeholder='電影/ 明星搜尋'" onfocus="this.placeholder=''" placeholder="電影 / 明星搜尋" type="text"/>
#           <div class="inputex" style="visibility:hidden">
#           </div>
#           <div class="btn_serch gabtn" data-ga="['search box','search box_電影明星搜尋','']" data-input="['input','starserch','']">
#            查詢
#           </div>
#          </form>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="content _c" id="container">
#       <div id="content_r">
#        <!--AD 300X250-->
#        <!-- if $exist diff with 0 will removed from module section -->
#        <div class="top_ad_300_250 r_box" data-ad="LREC" id="boxLREC">
#        </div>
#        <!--AD 300X100-->
#        <div class="ad_300_250 r_box" data-ad="NP1" id="boxNP1">
#        </div>
#        <!--電影排行榜-->
#        <div class="r_box _c">
#         <div class="title">
#          <span>
#           電影排行榜
#          </span>
#         </div>
#         <div class="r_box_inner">
#          <ul class="tabbox_btn_r">
#           <li class="select" data-id="list1">
#            台北票房榜
#           </li>
#           <li data-id="list2">
#            全美票房榜
#           </li>
#           <li data-id="list3">
#            預告片榜
#           </li>
#          </ul>
#          <div class="ranking_inner_r">
#           <div class="tab-content">
#            <div class="tab-pane" id="list1">
#             <div class="ranking_top_info_r _c">
#              <div class="ranking_top_info_img_r">
#               <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','隱形人']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%9A%B1%E5%BD%A2%E4%BA%BA-the-invisible-man-10359">
#                <img alt="" src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/February2020/bZ7jc0ecBnPrGgIl6T83-486x720.jpg"/>
#               </a>
#              </div>
#              <div class="ranking_top_info_inner_r">
#               <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','隱形人']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%9A%B1%E5%BD%A2%E4%BA%BA-the-invisible-man-10359">
#                隱形人
#               </a>
#               <span class="text_truncate_4 text_truncate_dot">
#                <p>
#                 「雖然無法看見，卻能造成傷害。」艾美獎得主伊莉莎白摩斯（熱門影集《使女的故事》）領銜主演，《隱形人》是一部關於癡迷的現代恐怖片，靈感來自環球影業經典怪物角色。
#                </p>
#                <p>
#                </p>
#                <p>
#                 西西莉亞受到一名富有和傑出的科學家感情綁架，被困在充滿暴力和控制的危險關係中，她靠著她的姊妹（影集《生死之間》哈莉特黛爾 飾），她們的兒時好友（《衝出康普頓》歐帝斯哈吉 飾）以及他的青少年女兒（HBO影集《高校十八禁》絲托姆瑞德 飾）的幫助，趁夜黑風高之際逃走並躲藏起來。
#                </p>
#                <p>
#                </p>
#                <p>
#                 但是當她具有虐待狂的前男友（Netflix影集《鬼入侵》奧立佛傑森柯恩 飾）自殺後將他巨大財富的一部分留給她，西西莉亞就懷疑他其實是假死。當一連串詭譎的巧合造成致命後果，威脅她所愛之人的性命時，她的精神瀕臨崩潰，而她必須證明她受到沒人看得見的兇手追殺。
#                </p>
#                <p>
#                </p>
#                <p>
#                 《隱形人》一片由當代恐怖大師傑森布倫為他的布倫屋製片公司製作，由雷沃納爾自編自導自製，他是《奪魂鋸》系列電影其中一名原創者，最近的作品則包括《人類升級》和《陰兒房第3章：從靈開始》。
#                </p>
#                <p>
#                </p>
#                <p>
#                 這部電影的製片還有Goalpost Pictures的凱莉杜弗瑞斯尼（《人類升級》、《閃亮女聲》）。執行製片則是雷沃納爾、碧翠絲史奎拉、查爾斯雷頓、蘿絲瑪麗布萊特、班葛蘭特、庫柏山繆森以及珍娜特瓦特諾。《隱形人》一片由澳洲Goalpost Pictures暨布倫屋製作公司並聯合Nervous Tick製作公司為環球影業製作。
#                </p>
#               </span>
#              </div>
#             </div>
#             <ul class="ranking_list_r">
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','隱形人']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%9A%B1%E5%BD%A2%E4%BA%BA-the-invisible-man-10359">
#               <li class="select">
#                <div class="num">
#                 1
#                </div>
#                <span>
#                 隱形人
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','女鬼橋']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A5%B3%E9%AC%BC%E6%A9%8B-the-bridge-curse-10437">
#               <li class="">
#                <div class="num">
#                 2
#                </div>
#                <span>
#                 女鬼橋
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','大畫特務']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A4%A7%E7%95%AB%E7%89%B9%E5%8B%99-hitman-agent-jun-10478">
#               <li class="">
#                <div class="num">
#                 3
#                </div>
#                <span>
#                 大畫特務
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','極地守護犬']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%A5%B5%E5%9C%B0%E5%AE%88%E8%AD%B7%E7%8A%AC-the-call-of-the-wild-10383">
#               <li class="">
#                <div class="num">
#                 4
#                </div>
#                <span>
#                 極地守護犬
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','明明會說話']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%98%8E%E6%98%8E%E6%9C%83%E8%AA%AA%E8%A9%B1-mr-zoo-10440">
#               <li class="">
#                <div class="num">
#                 5
#                </div>
#                <span>
#                 明明會說話
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','鳴鳥不飛：烏雲密布']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%B3%B4%E9%B3%A5%E4%B8%8D%E9%A3%9B-%E7%83%8F%E9%9B%B2%E5%AF%86%E5%B8%83-twittering-birds-never-fly-the-clouds-gather-10458">
#               <li class="">
#                <div class="num">
#                 6
#                </div>
#                <span>
#                 鳴鳥不飛：烏雲密布
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','音速小子']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%9F%B3%E9%80%9F%E5%B0%8F%E5%AD%90-sonic-the-hedgehog-9246">
#               <li class="">
#                <div class="num">
#                 7
#                </div>
#                <span>
#                 音速小子
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','1917']" href="https://movies.yahoo.com.tw/movieinfo_main/1917-1917-10189">
#               <li class="">
#                <div class="num">
#                 8
#                </div>
#                <span>
#                 1917
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','戰慄糖果屋']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%88%B0%E6%85%84%E7%B3%96%E6%9E%9C%E5%B1%8B-gretel-and-hansel-10472">
#               <li class="">
#                <div class="num">
#                 9
#                </div>
#                <span>
#                 戰慄糖果屋
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','猛禽小隊: 小丑女大解放']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%8C%9B%E7%A6%BD%E5%B0%8F%E9%9A%8A-%E5%B0%8F%E4%B8%91%E5%A5%B3%E5%A4%A7%E8%A7%A3%E6%94%BE-birds-of-prey-and-the-fantabulous-emancipation-of-one-harley-quinn-10268">
#               <li class="">
#                <div class="num">
#                 10
#                </div>
#                <span>
#                 猛禽小隊: 小丑女大解放
#                </span>
#               </li>
#              </a>
#             </ul>
#             <div class="rankin_time_r">
#              統計時間 : 2020-03-07~2020-03-08
#             </div>
#            </div>
#            <div class="tab-pane" id="list2">
#             <div class="ranking_top_info_r _c">
#              <div class="ranking_top_info_img_r">
#               <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','1/2的魔法']" href="https://movies.yahoo.com.tw/movieinfo_main/1-2%E7%9A%84%E9%AD%94%E6%B3%95-onward-10505">
#                <img alt="" src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/February2020/UemKo8bQBSqJvEYCrfue-1280x1831.jpg"/>
#               </a>
#              </div>
#              <div class="ranking_top_info_inner_r">
#               <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','1/2的魔法']" href="https://movies.yahoo.com.tw/movieinfo_main/1-2%E7%9A%84%E9%AD%94%E6%B3%95-onward-10505">
#                1/2的魔法
#               </a>
#               <span class="text_truncate_4 text_truncate_dot">
#                <p>
#                 《1/2的魔法》故事背景在現代科技已比精通魔法還方便的精靈世界，精靈、人馬、美人魚、獨角獸、小龍等魔法生物都生活在現代化社區裡，過著與你我無異的「沒有魔法的生活」。由湯姆霍蘭與克里普瑞特所配音的精靈兄弟們，很小的時後便失去了父親，但在弟弟的16歲生日這天，他收到了一個很特別的禮物- 他父親從前的魔杖以及一串魔咒，可以讓爸爸起死回生，但年久失修的魔法技能，讓施魔法時出了差錯，爸爸只剩一雙腿，於是兄弟倆踏上尋找魔法石的征途，最後能否順利讓爸爸「完璧」歸來呢?
#                </p>
#               </span>
#              </div>
#             </div>
#             <ul class="ranking_list_r">
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','1/2的魔法']" href="https://movies.yahoo.com.tw/movieinfo_main/1-2%E7%9A%84%E9%AD%94%E6%B3%95-onward-10505">
#               <li class="select">
#                <div class="num">
#                 1
#                </div>
#                <span>
#                 1/2的魔法
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','隱形人']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%9A%B1%E5%BD%A2%E4%BA%BA-the-invisible-man-10359">
#               <li class="">
#                <div class="num">
#                 2
#                </div>
#                <span>
#                 隱形人
#                </span>
#               </li>
#              </a>
#              <li class="unclick">
#               <div class="num">
#                3
#               </div>
#               <span>
#                The Way Back
#               </span>
#              </li>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','音速小子']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%9F%B3%E9%80%9F%E5%B0%8F%E5%AD%90-sonic-the-hedgehog-9246">
#               <li class="">
#                <div class="num">
#                 4
#                </div>
#                <span>
#                 音速小子
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','極地守護犬']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%A5%B5%E5%9C%B0%E5%AE%88%E8%AD%B7%E7%8A%AC-the-call-of-the-wild-10383">
#               <li class="">
#                <div class="num">
#                 5
#                </div>
#                <span>
#                 極地守護犬
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','艾瑪']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%89%BE%E7%91%AA-emma-10396">
#               <li class="">
#                <div class="num">
#                 6
#                </div>
#                <span>
#                 艾瑪
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','絕地戰警FOR LIFE']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%B5%95%E5%9C%B0%E6%88%B0%E8%AD%A6FOR-LIFE-bad-boys-for-life-10242">
#               <li class="">
#                <div class="num">
#                 7
#                </div>
#                <span>
#                 絕地戰警FOR LIFE
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','猛禽小隊：小丑女大解放']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%8C%9B%E7%A6%BD%E5%B0%8F%E9%9A%8A-%E5%B0%8F%E4%B8%91%E5%A5%B3%E5%A4%A7%E8%A7%A3%E6%94%BE-birds-of-prey-and-the-fantabulous-emancipation-of-one-harley-quinn-10268">
#               <li class="">
#                <div class="num">
#                 8
#                </div>
#                <span>
#                 猛禽小隊：小丑女大解放
#                </span>
#               </li>
#              </a>
#              <li class="unclick">
#               <div class="num">
#                9
#               </div>
#               <span>
#                Impractical Jokers: The Movie
#               </span>
#              </li>
#              <li class="unclick">
#               <div class="num">
#                10
#               </div>
#               <span>
#                My Hero Academia
#               </span>
#              </li>
#             </ul>
#             <div class="rankin_time_r">
#              統計時間 : 2020-03-06~2020-03-08
#             </div>
#            </div>
#            <div class="tab-pane" id="list3">
#             <div class="ranking_top_info_r _c">
#              <div class="ranking_top_info_img_r">
#               <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','大畫特務']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A4%A7%E7%95%AB%E7%89%B9%E5%8B%99-hitman-agent-jun-10478">
#                <img alt="" src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/February2020/1rMkH8EO94K2aLWlRpVQ-1280x1813.jpg"/>
#               </a>
#              </div>
#              <div class="ranking_top_info_inner_r">
#               <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','大畫特務']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A4%A7%E7%95%AB%E7%89%B9%E5%8B%99-hitman-agent-jun-10478">
#                大畫特務
#               </a>
#               <span class="text_truncate_4 text_truncate_dot">
#                <p>
#                 ★繼《雞不可失》後， 2020年開春韓國最爆笑電影！
#                </p>
#                <p>
#                 ★《天國的階梯》男神權相佑從影最爆笑動作喜劇！
#                </p>
#                <p>
#                 ★韓國首周票房笑出3.5億台幣，榮登票房亞軍！
#                </p>
#                <p>
#                 ★213萬韓國影迷笑噴，CGV影院91%、Naver觀眾8.2分超高評價！
#                </p>
#                <p>
#                 ★金牌特務變漫畫網紅，史上最ㄎㄧㄤ斜槓人生！
#                </p>
#                <p>
#                </p>
#                <p>
#                 醉高機密 神來一筆 史上最爆網紅誕生！
#                </p>
#                <p>
#                </p>
#                <p>
#                 韓國國家情報局秘密組織「防牌鳶」，專將孤苦無依的小孩培訓成頂尖特務，其中身手矯健的特務阿俊(權相佑飾)由魔鬼教頭千德奎(鄭俊鎬飾)親自訓練，他快狠準的身手一舉殲滅無數罪犯，成為恐怖份子都聞之喪膽的金牌特務…
#                </p>
#                <p>
#                </p>
#                <p>
#                 然阿俊心裡卻有個小小夢想－成為超人氣網路漫畫家！
#                </p>
#                <p>
#                </p>
#                <p>
#                 於是，他決定在一次任務中詐死脫身，隱姓埋名努力畫畫15年，但他的漫畫卻被網民嫌到爆，甚至被譏為靠太太美娜(黃雨瑟惠飾)養的中年魯蛇。某夜鬱鬱不得志的阿俊藉酒消愁，將他的特務人生畫成漫畫上傳一夕爆紅，無心之舉掀起網民空前轟動，更引來情報局和恐怖份子的大追殺…
#                </p>
#               </span>
#              </div>
#             </div>
#             <ul class="ranking_list_r">
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','大畫特務']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A4%A7%E7%95%AB%E7%89%B9%E5%8B%99-hitman-agent-jun-10478">
#               <li class="select">
#                <div class="num">
#                 1
#                </div>
#                <span>
#                 大畫特務
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','練愛iNG']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%B7%B4%E6%84%9BiNG-acting-out-of-love-10442">
#               <li class="">
#                <div class="num">
#                 2
#                </div>
#                <span>
#                 練愛iNG
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','血衛']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%A1%80%E8%A1%9B-bloodshot-10469">
#               <li class="">
#                <div class="num">
#                 3
#                </div>
#                <span>
#                 血衛
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','鋼鐵勳章']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%8B%BC%E9%90%B5%E5%8B%B3%E7%AB%A0-the-last-full-measure-10432">
#               <li class="">
#                <div class="num">
#                 4
#                </div>
#                <span>
#                 鋼鐵勳章
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','複製柔伊']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%A4%87%E8%A3%BD%E6%9F%94%E4%BC%8A-my-zoe-10455">
#               <li class="">
#                <div class="num">
#                 5
#                </div>
#                <span>
#                 複製柔伊
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','我，最親愛的']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%88%91-%E6%9C%80%E8%A6%AA%E6%84%9B%E7%9A%84-goodbye-mother-10503">
#               <li class="">
#                <div class="num">
#                 6
#                </div>
#                <span>
#                 我，最親愛的
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','艾瑪']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%89%BE%E7%91%AA-emma-10396">
#               <li class="">
#                <div class="num">
#                 7
#                </div>
#                <span>
#                 艾瑪
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','戰慄糖果屋']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%88%B0%E6%85%84%E7%B3%96%E6%9E%9C%E5%B1%8B-gretel-and-hansel-10472">
#               <li class="">
#                <div class="num">
#                 8
#                </div>
#                <span>
#                 戰慄糖果屋
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','明明會說話']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%98%8E%E6%98%8E%E6%9C%83%E8%AA%AA%E8%A9%B1-mr-zoo-10440">
#               <li class="">
#                <div class="num">
#                 9
#                </div>
#                <span>
#                 明明會說話
#                </span>
#               </li>
#              </a>
#              <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','刺激1995']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%88%BA%E6%BF%801995-shawshank-redemption-10518">
#               <li class="">
#                <div class="num">
#                 10
#                </div>
#                <span>
#                 刺激1995
#                </span>
#               </li>
#              </a>
#             </ul>
#             <div class="rankin_time_r">
#              統計時間 : 2020-03-14
#             </div>
#            </div>
#           </div>
#           <div class="btn_plus_more gabtn rk" data-ga="['電影排行榜','電影排行榜_台北票房榜_看更多','']">
#            <a href="https://movies.yahoo.com.tw/chart.html">
#             <div class="plus">
#             </div>
#             看更多
#            </a>
#           </div>
#           <div class="btn_plus_more gabtn rk" data-ga="['電影排行榜','電影排行榜_全美票房榜_看更多','']">
#            <a href="https://movies.yahoo.com.tw/chart.html?cate=us">
#             <div class="plus">
#             </div>
#             看更多
#            </a>
#           </div>
#           <div class="btn_plus_more gabtn rk" data-ga="['電影排行榜','電影排行榜_預告片榜_看更多','']">
#            <a href="https://movies.yahoo.com.tw/chart.html?cate=trailer">
#             <div class="plus">
#             </div>
#             看更多
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#        <!--懶人卡-->
#        <div class="r_box _c">
#         <div class="title">
#          <span>
#           懶人卡
#          </span>
#         </div>
#         <div class="r_box_inner">
#          <div class="lazy_card_r">
#           <dl>
#            <dt>
#             <div class="lazy_card_inner_r">
#              <a class="gabtn" data-ga="['懶人卡','','']" href="https://tw.youcard.yahoo.com/cardstack/4f69d1e0-64fd-11ea-877d-37b91cf858b1" target="_blank">
#               <div class="foto">
#                <img alt="" src="https://s1.yimg.com/lo/api/res/1.2/LB0nYbSXzJz8HcG4dXivJg--~A/YXBwaWQ9dHdhYnVuZXdz/https://i.imgur.com/lAmAZ29.jpg.cf.jpg"/>
#               </div>
#               <div class="lazy_card_info_r">
#                <div class="lazy_txt">
# ...
#               </div>
#              </div>
#              <div class="info_box">
#               <h2 class="text_truncate_2">
#                《魔髮精靈唱遊世界》靈魂女歌手SZA與流行樂巨星賈斯汀合作的全新單曲《THE OTHER SIDE》
#               </h2>
#               <span class="jq_text_overflow_120 jq_text_overflow_link">
#                九度入圍葛萊美獎、曾獲奧斯卡金像獎及金球獎提名的女歌手SZA，以及十度葛萊美獎得主、四度艾美獎贏家，並且曾經入圍奧斯卡金像獎的流行樂巨星賈斯汀提姆布萊克攜手合作，推出《The Other Side》這首歌的單曲和MV。
#               </span>
#               <div class="day">
#                2020-03-13
#               </div>
#              </div>
#             </div>
#            </a>
#           </li>
#           <li>
#            <a class="gabtn" data-ga="['情報站','情報站_文章4','《這一刻，想見你》男神涂善存情竇初開送貼身小物陪伴曖昧對象  怨嘆至今主動追求的感情都失敗！']" href="https://movies.yahoo.com.tw/article/%E9%80%99%E4%B8%80%E5%88%BB%E6%83%B3%E8%A6%8B%E4%BD%A0%E7%94%B7%E7%A5%9E%E6%B6%82%E5%96%84%E5%AD%98%E6%83%85%E7%AB%87%E5%88%9D%E9%96%8B%E9%80%81%E8%B2%BC%E8%BA%AB%E5%B0%8F%E7%89%A9%E9%99%AA%E4%BC%B4%E6%9B%96%E6%98%A7%E5%B0%8D%E8%B1%A1-%E6%80%A8%E5%98%86%E8%87%B3%E4%BB%8A%E4%B8%BB%E5%8B%95%E8%BF%BD%E6%B1%82%E7%9A%84%E6%84%9F%E6%83%85%E9%83%BD%E5%A4%B1%E6%95%97-134216956.html">
#             <div class="news_content">
#              <div class="foto">
#               <div class="fotoinner">
#                <img alt="" src="https://movies.yahoo.com.tw/y/r/w490/bt/api/res/1.2/5FfgZcHVwaQYG9EPKFQDuA--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz0zNTkzO2g9MjAyMTs-/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-03/d151d1d0-652f-11ea-bbff-c7512fa51cfc"/>
#               </div>
#              </div>
#              <div class="info_box">
#               <h2 class="text_truncate_2">
#                《這一刻，想見你》男神涂善存情竇初開送貼身小物陪伴曖昧對象  怨嘆至今主動追求的感情都失敗！
#               </h2>
#               <span class="jq_text_overflow_120 jq_text_overflow_link">
#                由mm2滿滿額娛樂股份有限公司出品，邁進國際投資控股有限公司及硯石（廈門）文化傳媒有限公司聯合出品，今天春天最酸甜的青春電影《這一刻，想見你》，迎接即將到來的白色情人節，特別釋出電影中的告白影音，只見帥氣男主角涂善存對著鏡頭深情表白，一雙電眼融化許多少女的心
#               </span>
#               <div class="day">
#                2020-03-13
#               </div>
#              </div>
#             </div>
#            </a>
#           </li>
#           <li>
#            <a class="gabtn" data-ga="['情報站','情報站_文章5','疫情燒到美劇！《獵鷹與酷寒戰士》、《少年謝爾頓》15影集被迫停拍']" href="https://movies.yahoo.com.tw/article/%E7%96%AB%E6%83%85%E7%87%92%E5%88%B0%E7%BE%8E%E5%8A%87%E7%8D%B5%E9%B7%B9%E8%88%87%E9%85%B7%E5%AF%92%E6%88%B0%E5%A3%AB%E5%B0%91%E5%B9%B4%E8%AC%9D%E7%88%BE%E9%A0%93-15-%E5%BD%B1%E9%9B%86%E8%A2%AB%E8%BF%AB%E5%81%9C%E6%8B%8D-132051210.html">
#             <div class="news_content">
#              <div class="foto">
#               <div class="fotoinner">
#                <img alt="" src="https://movies.yahoo.com.tw/y/r/w490/bt/api/res/1.2/MyiMBC1PFcwXx7G1txfe9Q--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz0yMDAwO2g9MTEwMjs-/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-03/dba4d2c0-652c-11ea-b75b-527213c95fac"/>
#               </div>
#              </div>
#              <div class="info_box">
#               <h2 class="text_truncate_2">
#                疫情燒到美劇！《獵鷹與酷寒戰士》、《少年謝爾頓》15影集被迫停拍
#               </h2>
#               <span class="jq_text_overflow_120 jq_text_overflow_link">
#                新冠肺炎（COVID-19，俗稱武漢肺炎）疫情擴大，電影演員湯姆漢克（Tom Hanks）與妻子麗塔威森（Rita Wilson）在澳洲拍攝電影被確診染病，電影公司隨即停工。美國娛樂產業相繼採取預防、保護措施，院線電影《007：生死交戰》與《玩命關頭9》宣布延後上映，連小螢幕市場都受到影響，許多劇組拍攝喊卡，到底有哪些影集受到影響呢？
#               </span>
#               <div class="day">
#                2020-03-13
#               </div>
#              </div>
#             </div>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="btn_plus_more gabtn">
#          <a class="gabtn" data-ga="['情報站','情報站_看更多','']" href="https://movies.yahoo.com.tw/article_index.html">
#           <div class="plus">
#           </div>
#           看更多
#          </a>
#         </div>
#        </div>
#        <!--精采圖片-->
#        <div class="l_box have_arbox _c">
#         <div class="title">
#          <span>
#           精彩圖片
#          </span>
#          <dl class="title_btnbox _appendarr">
#          </dl>
#         </div>
#         <div class="l_box_inner">
#          <ul class="featured_img imglist">
#           <li>
#            <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片1','IMDb精選！《寄生上流》粉絲應該也愛的12部電影']" href="https://movies.yahoo.com.tw/slideshow/im-db%E7%B2%BE%E9%81%B8%E5%AF%84%E7%94%9F%E4%B8%8A%E6%B5%81%E7%B2%89%E7%B5%B2%E6%87%89%E8%A9%B2%E4%B9%9F%E6%84%9B%E7%9A%84-12-%E9%83%A8%E9%9B%BB%E5%BD%B1-223158513.html">
#             <div class="_slickcontent">
#              <div class="foto">
#               <img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/7gCfnBtMDDkFRHOCmC0adw--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz01OTc7aD0zOTg7/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-02/71cfed50-5b43-11ea-bfe5-804313a97fc8"/>
#               <div class="btn_openfoto">
#               </div>
#              </div>
#              <div class="foto_info">
#               <span class="text_truncate_2">
#                IMDb精選！《寄生上流》粉絲應該也愛的12部電影
#               </span>
#              </div>
#             </div>
#            </a>
#           </li>
#           <li>
#            <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片2','圖多有鬼！心臟夠強才能看的最新恐怖片單']" href="https://movies.yahoo.com.tw/slideshow/%E5%9C%96%E5%A4%9A%E6%9C%89%E9%AC%BC%E5%BF%83%E8%87%9F%E5%A4%A0%E5%BC%B7%E6%89%8D%E8%83%BD%E7%9C%8B%E7%9A%84%E6%9C%80%E6%96%B0%E6%81%90%E6%80%96%E7%89%87%E5%96%AE-231558617.html">
#             <div class="_slickcontent">
#              <div class="foto">
#               <img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/WW_7grv53TOUV9p7lTELMA--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz02MDA7aD00MDA7/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-02/bfda0130-575a-11ea-bb76-01da98388aaf"/>
#               <div class="btn_openfoto">
#               </div>
#              </div>
#              <div class="foto_info">
#               <span class="text_truncate_2">
#                圖多有鬼！心臟夠強才能看的最新恐怖片單
#               </span>
#              </div>
#             </div>
#            </a>
#           </li>
#           <li>
#            <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片3','別出心裁！藝術家精心設計奧斯卡小金人海報']" href="https://movies.yahoo.com.tw/slideshow/%E5%88%A5%E5%87%BA%E5%BF%83%E8%A3%81%E8%97%9D%E8%A1%93%E5%AE%B6%E7%B2%BE%E5%BF%83%E8%A8%AD%E8%A8%88%E5%A5%A7%E6%96%AF%E5%8D%A1%E5%B0%8F%E9%87%91%E4%BA%BA%E6%B5%B7%E5%A0%B1-024015275.html">
#             <div class="_slickcontent">
#              <div class="foto">
#               <img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/jJZLb8wDv.uJSy_1H2mWBQ--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz0xNTAwO2g9MTUwMDs-/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-02/47d86c60-4bae-11ea-b91e-a878f8435ba6"/>
#               <div class="btn_openfoto">
#               </div>
#              </div>
#              <div class="foto_info">
#               <span class="text_truncate_2">
#                別出心裁！藝術家精心設計奧斯卡小金人海報
#               </span>
#              </div>
#             </div>
#            </a>
#           </li>
#           <li>
#            <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片4','賀新年！迪士尼釋出春節版新片海報']" href="https://movies.yahoo.com.tw/slideshow/%E8%B3%80%E6%96%B0%E5%B9%B4%E8%BF%AA%E5%A3%AB%E5%B0%BC%E9%87%8B%E5%87%BA%E6%98%A5%E7%AF%80%E7%89%88%E6%96%B0%E7%89%87%E6%B5%B7%E5%A0%B1-210955962.html">
#             <div class="_slickcontent">
#              <div class="foto">
#               <img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/1JacKdtfKDSMLN6hOBwwgA--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz04MDA7aD0xNDU3Ow--/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2020-01/0dfa3f50-4212-11ea-bfed-5be09f0f1dc5"/>
#               <div class="btn_openfoto">
#               </div>
#              </div>
#              <div class="foto_info">
#               <span class="text_truncate_2">
#                賀新年！迪士尼釋出春節版新片海報
#               </span>
#              </div>
#             </div>
#            </a>
#           </li>
#           <li>
#            <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片5','【Yahoo年度十大】年度最嚇！2019十大驚悚恐怖電影盤點']" href="https://movies.yahoo.com.tw/slideshow/-yahoo%E5%B9%B4%E5%BA%A6%E5%8D%81%E5%A4%A7%E5%B9%B4%E5%BA%A6%E6%9C%80%E5%9A%87-2019-%E5%8D%81%E5%A4%A7%E9%A9%9A%E6%82%9A%E6%81%90%E6%80%96%E9%9B%BB%E5%BD%B1%E7%9B%A4%E9%BB%9E-015046327.html">
#             <div class="_slickcontent">
#              <div class="foto">
#               <img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/5g_.q2c3L1wZFyymRBLmPQ--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz0xMDc1O2g9NzE4Ow--/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2019-12/7a902560-25ef-11ea-bfff-31c138f35d45"/>
#               <div class="btn_openfoto">
#               </div>
#              </div>
#              <div class="foto_info">
#               <span class="text_truncate_2">
#                【Yahoo年度十大】年度最嚇！2019十大驚悚恐怖電影盤點
#               </span>
#              </div>
#             </div>
#            </a>
#           </li>
#           <li>
#            <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片6','重回黑幫本色！《紳士追殺令》釋出角色海報']" href="https://movies.yahoo.com.tw/slideshow/%E9%87%8D%E5%9B%9E%E9%BB%91%E5%B9%AB%E6%9C%AC%E8%89%B2%E7%B4%B3%E5%A3%AB%E8%BF%BD%E6%AE%BA%E4%BB%A4%E9%87%8B%E5%87%BA%E8%A7%92%E8%89%B2%E6%B5%B7%E5%A0%B1-003549174.html">
#             <div class="_slickcontent">
#              <div class="foto">
#               <img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/gEx4zaYYPAyqdrzlk3659g--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz05OTI7aD0xNDE4Ow--/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2019-12/f0d7d7f0-25e4-11ea-bbf7-7ba3e186376a"/>
#               <div class="btn_openfoto">
#               </div>
#              </div>
#              <div class="foto_info">
#               <span class="text_truncate_2">
#                重回黑幫本色！《紳士追殺令》釋出角色海報
#               </span>
#              </div>
#             </div>
#            </a>
#           </li>
#           <li>
#            <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片7','星光熠熠！《星戰9》進軍東京紅毯']" href="https://movies.yahoo.com.tw/slideshow/%E6%98%9F%E5%85%89%E7%86%A0%E7%86%A0%E6%98%9F%E6%88%B0-9-%E9%80%B2%E8%BB%8D%E6%9D%B1%E4%BA%AC%E7%B4%85%E6%AF%AF-093858821.html">
#             <div class="_slickcontent">
#              <div class="foto">
#               <img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/2Stj65fQuywlLeuFz9Ji1Q--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz0xNTAwO2g9MTAwMDs-/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2019-12/2a4b3620-1fe7-11ea-9fed-d5a52439c518"/>
#               <div class="btn_openfoto">
#               </div>
#              </div>
#              <div class="foto_info">
#               <span class="text_truncate_2">
#                星光熠熠！《星戰9》進軍東京紅毯
#               </span>
#              </div>
#             </div>
#            </a>
#           </li>
#           <li>
#            <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片8','小勞勃道尼親自試鏡！《杜立德》角色海報問世']" href="https://movies.yahoo.com.tw/slideshow/%E5%B0%8F%E5%8B%9E%E5%8B%83%E9%81%93%E5%B0%BC%E8%A6%AA%E8%87%AA%E8%A9%A6%E9%8F%A1%E6%9D%9C%E7%AB%8B%E5%BE%B7%E8%A7%92%E8%89%B2%E6%B5%B7%E5%A0%B1%E5%95%8F%E4%B8%96-092739157.html">
#             <div class="_slickcontent">
#              <div class="foto">
#               <img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/5_AOgEu_KnYdfZmyNPdw9g--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz0xMDQwO2g9MTUwMDs-/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2019-12/dc9c15d0-1fe5-11ea-a7f7-65683ff2e529"/>
#               <div class="btn_openfoto">
#               </div>
#              </div>
#              <div class="foto_info">
#               <span class="text_truncate_2">
#                小勞勃道尼親自試鏡！《杜立德》角色海報問世
#               </span>
#              </div>
#             </div>
#            </a>
#           </li>
#           <li>
#            <a class="gabtn" data-ga="['精彩圖片','精彩圖片_圖片9','女力崛起！《猛禽小隊》釋出角色海報']" href="https://movies.yahoo.com.tw/slideshow/%E5%A5%B3%E5%8A%9B%E5%B4%9B%E8%B5%B7%E7%8C%9B%E7%A6%BD%E5%B0%8F%E9%9A%8A%E9%87%8B%E5%87%BA%E8%A7%92%E8%89%B2%E6%B5%B7%E5%A0%B1-070556559.html">
#             <div class="_slickcontent">
#              <div class="foto">
#               <img alt="" src="https://movies.yahoo.com.tw/y/r/w418/bt/api/res/1.2/9J.rWMzO2vE9QdaiI9iF.g--~A/YXBwaWQ9dHdhYnVuZXdzO2ZpPWZpbGw7dz05NzI7aD0xNTAwOw--/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2019-12/f87c72c0-1a51-11ea-baef-8dd89c1067a2"/>
#               <div class="btn_openfoto">
#               </div>
#              </div>
#              <div class="foto_info">
#               <span class="text_truncate_2">
#                女力崛起！《猛禽小隊》釋出角色海報
#               </span>
#              </div>
#             </div>
#            </a>
#           </li>
#          </ul>
#          <div class="btn_plus_more">
#           <a class="gabtn" data-ga="['精彩圖片','精彩圖片_看更多','']" href="https://movies.yahoo.com.tw/tagged/slideshow">
#            <div class="plus">
#            </div>
#            看更多
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </main>
#    <footer class="clearfix" id="footer" style="display: block;">
#     <div id="loadbox">
#      <a class="gabtn" data-ga="['其他連結','其他連結_服務中心','頁尾_其他連結']" href="https://tw.help.yahoo.com/kb/helpcentral" target="_blank">
#       服務中心
#      </a>
#      |
#      <a class="gabtn" data-ga="['其他連結','其他連結_隱私權','頁尾_其他連結']" href="https://policies.yahoo.com/tw/zh-hant/yahoo/privacy/index.htm" target="_blank">
#       隱私權(更新)
#      </a>
#      |
#      <a class="gabtn" data-ga="['其他連結','其他連結_建議','頁尾_其他連結']" href="https://yahoo.uservoice.com/forums/600523" target="_blank">
#       建議
#      </a>
#      |
#      <a class="gabtn" data-ga="['其他連結','其他連結_關於我們的廣告','頁尾_其他連結']" href="https://policies.yahoo.com/tw/zh-hant/yahoo/privacy/adinfo/" target="_blank">
#       關於我們的廣告
#      </a>
#      |
#      <a class="gabtn" data-ga="['其他連結','其他連結_服務條款','頁尾_其他連結']" href="https://info.yahoo.com/legal/tw/yahoo/utos/zh-hant-tw/" target="_blank">
#       服務條款(更新)
#      </a>
#      |
#      <a href="https://guce.yahoo.com/privacy-dashboard?locale=zh-Hant-TW" target="_blank">
#       隱私權儀表板
#      </a>
#      由Yahoo奇摩電影 提供
#     </div>
#    </footer>
#   </div>
#   <!-- Javascript -->
#   <script src="https://s.yimg.com/ss/rapid3.js">
#   </script>
#   <script src="https://s.yimg.com/ss/rapidworker-1.2.js">
#   </script>
#   <!-- Native Ad -->
#   <script type="text/javascript">
#    const nativeAdAll = "bdd2eb9c-51e8-404a-921c-ae7090fc5fda";
#   const nativeAdOption = "";
#
#   window.native = window.native || [];
#   window.native.push(nativeAdAll);
#   if(nativeAdOption.length) {
#     window.native.push(nativeAdOption);
#   }
#   window.apiKey = "QS4CB5BPWQKCYKVVSR89";
#
#   (function(d) {
#     var script = d.createElement("script");
#     script.async = true;
#     script.src = "https://s.yimg.com/dy/ads/native.js";
#     d.body.appendChild(script);
#   })(document);
#   </script>
#   <script src="/build/js/app.js?id=4c505b2df8739bb6f23d&amp;r=1555478321" type="text/javascript">
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=7241469&amp;c7=https%3A%2F%2Fmovies.yahoo.com.tw&amp;c5=794026701&amp;cv=2.0&amp;cj=1" width="1"/>
#   </noscript>
#   <script>
#   </script>
#   <script type="application/javascript">
#    (function (w, d, t, r, u) {
#     w[u] = w[u] || []
#     w[u].push({
#       'projectId': '10000',
#       'properties': {
#         'pixelId': '428726',
#         'qstrings': {'country': 'tw', 'property': 'movie', 'tag': ''}
#       }
#     })
#     var s = d.createElement(t)
#     s.src = r
#     s.async = true
#     s.onload = s.onreadystatechange = function () {
#       var y, rs = this.readyState, c = w[u]
#       if (rs && rs != 'complete' && rs != 'loaded') {return}
#       try {
#         y = YAHOO.ywa.I13N.fireBeacon
#         w[u] = []
#         w[u].push = function (p) {y([p])}
#         y(c)
#       } catch (e) {}
#     }
#     var scr = d.getElementsByTagName(t)[0], par = scr.parentNode
#     par.insertBefore(s, scr)
#   })(window, document, 'script', 'https://s.yimg.com/wi/ytc.js', 'dotq')
#   </script>
#  </body>
# </html>

# %%
# 查看目前上映那些電影，並擷取出其ID資訊
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
html = soup.find("select", attrs={'name':'movie_id'})
movie_item = html.find_all("option", attrs={'data-name':re.compile('.*')})

for p in movie_item:
    print("Movie: %s, ID: %s" % (p["data-name"], p["value"]))
# Out:
# Movie: 電影版 地獄少女, ID: 10525
# Movie: 刺激1995, ID: 10518
# Movie: 通靈少年2020, ID: 10517
# Movie: 安雅的回家路, ID: 10516
# Movie: 牆內的房客, ID: 10512
# Movie: 南山的部長們, ID: 10509
# Movie: 另類神父, ID: 10500
# Movie: 破．局, ID: 10496
# Movie: 劇場版 不起眼女主角培育法 Fine, ID: 10486
# Movie: 複製柔伊, ID: 10455
# Movie: 練愛iNG, ID: 10442
# Movie: 鋼鐵勳章, ID: 10432
# Movie: 我，最親愛的, ID: 10503
# Movie: 血衛, ID: 10469
# Movie: 導演先生的完美假期, ID: 10545
# Movie: 大地蜜語, ID: 10513
# Movie: 狂飆一夢, ID: 10506
# Movie: 親愛的莎瑪, ID: 10491
# Movie: 大畫特務, ID: 10478
# Movie: 戰慄糖果屋, ID: 10472
# Movie: 失戀殺人：三角禁戀, ID: 10465
# Movie: 明明會說話, ID: 10440
# Movie: 艾瑪, ID: 10396
# Movie: 罪樂園, ID: 10349
# Movie: 鳴鳥不飛：烏雲密布, ID: 10458
# Movie: 哥布林殺手 劇場版, ID: 10438
# Movie: 女鬼橋, ID: 10437
# Movie: 怨咒, ID: 10421
# Movie: 娘娘腔日記, ID: 10401
# Movie: 極地守護犬, ID: 10383
# Movie: 叔．叔, ID: 10371
# Movie: 隱形人, ID: 10359
# Movie: 電影音效傳奇：好萊塢之聲, ID: 10484
# Movie: 悲慘世界, ID: 10479
# Movie: 閃閃小超人電影版, ID: 10474
# Movie: 陰櫥, ID: 10457
# Movie: 絕命大平台, ID: 10447
# Movie: 李察朱威爾事件, ID: 10368
# Movie: 音速小子, ID: 9246
# Movie: 逃出夢幻島, ID: 10485
# Movie: 超＂人＂氣動物園, ID: 10445
# Movie: 就愛斷捨離, ID: 10436
# Movie: 猛禽小隊：小丑女大解放, ID: 10268
# Movie: 紅鞋公主與七矮人, ID: 10417
# Movie: 1917, ID: 10189
# Movie: 你的情歌, ID: 10407
# Movie: 她們, ID: 10202
# Movie: 巧虎電影：英雄遊樂園, ID: 10429
# Movie: 寄生上流, ID: 10020

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 10518

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}

# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
resp = requests.get(url, params=payload, headers=headers)
#print(resp.json())  # 若有需要，列印出json原始碼

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 新北市, 代號(area_id): 8
# 放映地區: 桃園, 代號(area_id): 16
# 放映地區: 新竹, 代號(area_id): 20
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 台南, 代號(area_id): 10
# 放映地區: 高雄, 代號(area_id): 17

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 28

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})

# 列印播放日期
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 三月 14
# 三月 15
# 三月 16
# 三月 17
# 三月 18

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2020-03-18"

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
#print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'lxml')
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})

# %%
movie_list=soup.find(class_="pc-movie-schedule-form").find_all('ul')
#for location in movie_list.find_all("li",attrs={'class':'adds'}):
    #print("電影院名稱: "+location.a.string)
for location in movie_list:
    try:
        print("電影院名稱: ",location.find('li',attrs={'class':'adds'}).find('a').text)
        print("影片放映類型: ",location.find('li',attrs={'class':"taps"}).find('span').text)
        print("時間表: ")
        for i in location.find_all("label",attrs={'class':'select'}):
            print(i.text)
        print("----------------------------------------------------------------------")
    except:
        continue
# Out:
# 電影院名稱:  台北美麗華大直影城
# 影片放映類型:  數位
# 時間表:
# 14:00
# 18:30
# ----------------------------------------------------------------------
# 電影院名稱:  台北信義威秀影城
# 影片放映類型:  數位
# 時間表:
# 10:35
# 14:30
# 17:10
# 19:50
# 22:30
# ----------------------------------------------------------------------
# 電影院名稱:  喜樂時代影城南港店
# 影片放映類型:  數位
# 時間表:
# 11:00
# 15:30
# 20:00
# 22:40
# ----------------------------------------------------------------------
# 電影院名稱:  MUVIE CINEMAS台北松仁威秀
# 影片放映類型:  TITAN
# 時間表:
# 13:20
# ----------------------------------------------------------------------

# %%
'''

  試著從上一步驟回傳的電影院資料中，擷取電影院名稱、影片放映類型以及時間表
  
  Your code here.

'''
# Out:
# ----------------------------------------------------------------------
# 電影院:  台北美麗華大直影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 11:10:00
# 2019-08-21 13:15:00
# 2019-08-21 15:20:00
# 2019-08-21 19:30:00
# 2019-08-21 21:40:00
# 2019-08-21 22:30:00
# ----------------------------------------------------------------------
# 電影院:  台北新光影城
# 放映類型:  數位
# 2019-08-21 10:00:00
# 2019-08-21 14:50:00
# 2019-08-21 19:30:00
# ----------------------------------------------------------------------
# 電影院:  台北in89豪華數位影城
# 放映類型:  數位
# 2019-08-21 09:30:00
# 2019-08-21 11:20:00
# 2019-08-21 13:15:00
# 2019-08-21 15:10:00
# 2019-08-21 16:10:00
# 2019-08-21 17:10:00
# 2019-08-21 18:05:00
# 2019-08-21 19:10:00
# 2019-08-21 21:10:00
# 2019-08-21 23:10:00
# 2019-08-22 01:10:00
# ----------------------------------------------------------------------
# 電影院:  台北日新威秀影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 10:55:00
# 2019-08-21 12:50:00
# 2019-08-21 14:45:00
# 2019-08-21 16:40:00
# 2019-08-21 18:35:00
# 2019-08-21 20:35:00
# ----------------------------------------------------------------------
# 電影院:  喜滿客絕色影城
# 放映類型:  數位
# 2019-08-21 10:00:00
# 2019-08-21 11:55:00
# 2019-08-21 13:50:00
# 2019-08-21 15:45:00
# 2019-08-21 17:40:00
# 2019-08-21 19:35:00
# 2019-08-21 21:30:00
# ----------------------------------------------------------------------
# 電影院:  台北信義威秀影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 11:00:00
# 2019-08-21 13:00:00
# 2019-08-21 15:00:00
# 2019-08-21 17:00:00
# 2019-08-21 19:00:00
# 2019-08-21 21:00:00
# 2019-08-21 23:00:00
# ----------------------------------------------------------------------
# 電影院:  喜滿客京華影城
# 放映類型:  數位
# 2019-08-21 10:30:00
# 2019-08-21 12:30:00
# 2019-08-21 14:30:00
# 2019-08-21 16:30:00
# 2019-08-21 18:30:00
# 2019-08-21 20:30:00
# 2019-08-21 22:30:00
# ----------------------------------------------------------------------
# 電影院:  京站威秀影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 11:00:00
# 2019-08-21 13:00:00
# 2019-08-21 15:00:00
# 2019-08-21 17:00:00
# 2019-08-21 19:00:00
# 2019-08-21 21:00:00
# ----------------------------------------------------------------------
# 電影院:  喜樂時代影城南港店
# 放映類型:  數位
# 2019-08-21 10:20:00
# 2019-08-21 11:10:00
# 2019-08-21 12:20:00
# 2019-08-21 13:10:00
# 2019-08-21 14:20:00
# 2019-08-21 15:10:00
# 2019-08-21 16:20:00
# 2019-08-21 17:10:00
# 2019-08-21 18:20:00
# 2019-08-21 19:15:00
# 2019-08-21 20:20:00
# 2019-08-21 21:15:00
# 2019-08-21 22:20:00
