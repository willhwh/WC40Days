# %% [markdown]
# # 動態網頁爬蟲 - 使用 Selenium
#
# * 了解 Selenium 用於動態網頁爬蟲的原理
# * 能夠使用 Selenium 撰寫動態網頁爬蟲

# %% [markdown]
# ## 使用 Requests 爬蟲

# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("https://hahow.in/courses")
d = BeautifulSoup(r.text, 'lxml')

d.body.text
# 只會爬蟲 JavaScript 語法，沒有網頁內容中的資料
# Out:
# '[Element.prototype,Document.prototype,DocumentFragment.prototype].forEach((function(e){e.hasOwnProperty("prepend")||Object.defineProperty(e,"prepend",{configurable:!0,enumerable:!0,writable:!0,value:function(){var e=Array.prototype.slice.call(arguments),t=document.createDocumentFragment();e.forEach((function(e){var n=e instanceof Node;t.appendChild(n?e:document.createTextNode(String(e)))})),this.insertBefore(t,this.firstChild)}})}));var loadDeferredStyles=function(){var e=document.getElementById("deferred-styles"),t=document.createElement("div");t.innerHTML=e.textContent,document.head.prepend(t),e.parentElement.removeChild(e)},raf=window.requestAnimationFrame||window.mozRequestAnimationFrame||window.webkitRequestAnimationFrame||window.msRequestAnimationFrame;raf?raf((function(){window.setTimeout(loadDeferredStyles,0)})):window.addEventListener("load",loadDeferredStyles)!function(t,h,e,j,s,n){t.hj=t.hj||function(){(t.hj.q=t.hj.q||[]).push(arguments)},t._hjSettings={hjid:301739,hjsv:6},s=h.getElementsByTagName("head")[0],(n=h.createElement("script")).async=1,n.src="https://static.hotjar.com/c/hotjar-"+t._hjSettings.hjid+".js?sv="+t._hjSettings.hjsv,s.appendChild(n)}(window,document)!function(e){function f(f){for(var d,t,n=f[0],o=f[1],b=f[2],u=0,l=[];u<n.length;u++)t=n[u],Object.prototype.hasOwnProperty.call(a,t)&&a[t]&&l.push(a[t][0]),a[t]=0;for(d in o)Object.prototype.hasOwnProperty.call(o,d)&&(e[d]=o[d]);for(i&&i(f);l.length;)l.shift()();return r.push.apply(r,b||[]),c()}function c(){for(var e,f=0;f<r.length;f++){for(var c=r[f],d=!0,t=1;t<c.length;t++){var o=c[t];0!==a[o]&&(d=!1)}d&&(r.splice(f--,1),e=n(n.s=c[0]))}return e}var d={},t={23:0},a={23:0},r=[];function n(f){if(d[f])return d[f].exports;var c=d[f]={i:f,l:!1,exports:{}};return e[f].call(c.exports,c,c.exports,n),c.l=!0,c.exports}n.e=function(e){var f=[];t[e]?f.push(t[e]):0!==t[e]&&{7:1,16:1,17:1,30:1,34:1,37:1,50:1,51:1,117:1,121:1}[e]&&f.push(t[e]=new Promise((function(f,c){for(var d="static/css/"+({}[e]||e)+"."+{0:"31d6cfe0",1:"31d6cfe0",2:"31d6cfe0",3:"31d6cfe0",4:"31d6cfe0",5:"31d6cfe0",6:"31d6cfe0",7:"22fcc149",8:"31d6cfe0",9:"31d6cfe0",10:"31d6cfe0",11:"31d6cfe0",12:"31d6cfe0",13:"31d6cfe0",14:"31d6cfe0",15:"31d6cfe0",16:"6e7b7be2",17:"7c365a51",18:"31d6cfe0",19:"31d6cfe0",20:"31d6cfe0",21:"31d6cfe0",25:"31d6cfe0",26:"31d6cfe0",27:"31d6cfe0",28:"31d6cfe0",29:"31d6cfe0",30:"7c365a51",31:"31d6cfe0",32:"31d6cfe0",33:"31d6cfe0",34:"22fcc149",35:"31d6cfe0",36:"31d6cfe0",37:"22fcc149",38:"31d6cfe0",39:"31d6cfe0",40:"31d6cfe0",41:"31d6cfe0",42:"31d6cfe0",43:"31d6cfe0",44:"31d6cfe0",45:"31d6cfe0",46:"31d6cfe0",47:"31d6cfe0",48:"31d6cfe0",49:"31d6cfe0",50:"7c365a51",51:"7c365a51",52:"31d6cfe0",53:"31d6cfe0",54:"31d6cfe0",55:"31d6cfe0",56:"31d6cfe0",57:"31d6cfe0",58:"31d6cfe0",59:"31d6cfe0",60:"31d6cfe0",61:"31d6cfe0",62:"31d6cfe0",63:"31d6cfe0",64:"31d6cfe0",65:"31d6cfe0",66:"31d6cfe0",67:"31d6cfe0",68:"31d6cfe0",69:"31d6cfe0",70:"31d6cfe0",71:"31d6cfe0",72:"31d6cfe0",73:"31d6cfe0",74:"31d6cfe0",75:"31d6cfe0",76:"31d6cfe0",77:"31d6cfe0",78:"31d6cfe0",79:"31d6cfe0",80:"31d6cfe0",81:"31d6cfe0",82:"31d6cfe0",83:"31d6cfe0",84:"31d6cfe0",85:"31d6cfe0",86:"31d6cfe0",87:"31d6cfe0",88:"31d6cfe0",89:"31d6cfe0",90:"31d6cfe0",91:"31d6cfe0",92:"31d6cfe0",93:"31d6cfe0",94:"31d6cfe0",95:"31d6cfe0",96:"31d6cfe0",97:"31d6cfe0",98:"31d6cfe0",99:"31d6cfe0",100:"31d6cfe0",101:"31d6cfe0",102:"31d6cfe0",103:"31d6cfe0",104:"31d6cfe0",105:"31d6cfe0",106:"31d6cfe0",107:"31d6cfe0",108:"31d6cfe0",109:"31d6cfe0",110:"31d6cfe0",111:"31d6cfe0",112:"31d6cfe0",113:"31d6cfe0",114:"31d6cfe0",115:"31d6cfe0",116:"31d6cfe0",117:"d28f2505",118:"31d6cfe0",119:"31d6cfe0",120:"31d6cfe0",121:"11f61336",122:"31d6cfe0",123:"31d6cfe0",124:"31d6cfe0",125:"31d6cfe0",126:"31d6cfe0",127:"31d6cfe0",128:"31d6cfe0",129:"31d6cfe0",130:"31d6cfe0",131:"31d6cfe0",132:"31d6cfe0",133:"31d6cfe0",134:"31d6cfe0",135:"31d6cfe0",136:"31d6cfe0",137:"31d6cfe0",138:"31d6cfe0",139:"31d6cfe0",140:"31d6cfe0",141:"31d6cfe0",142:"31d6cfe0",1 ...

# %% [markdown]
# ## 動態模擬瀏覽器行為

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup

# %%
browser = webdriver.Chrome(executable_path='chromedriver')
browser.get("https://hahow.in/courses")

# %%
# 取得資料（等瀏覽器資料出現後才執行）
html_source = browser.page_source
html_source
# Out:
# '<html lang="zh-TW" data-react-helmet="lang"><head><div><link href="https://hahow.in/static/css/24.454d8622.chunk.css" rel="stylesheet"></div><meta name="description" content="超過百堂有趣的線上課程，讓你輕鬆自學那些學校沒有教的事！" data-react-helmet="true"><meta property="fb:app_id" content="1287520191288194" data-react-helmet="true"><meta property="og:locale" content="zh-TW" data-react-helmet="true"><meta property="og:description" content="Hahow 提供最多元有趣的線上課程，並透過獨特的課程募資機制，讓熱愛自學與交換技能的你，在家就可以完成高效率的線上學習與成就！" data-react-helmet="true"><meta property="og:url" content="https://hahow.in/" data-react-helmet="true"><meta property="og:image" content="https://hahow.in/static/images/og-image.jpg" data-react-helmet="true"><meta property="og:type" content="article" data-react-helmet="true"><meta property="og:site_name" content="Hahow - 好學校" data-react-helmet="true"><meta property="og:title" content="Hahow 好學校 | 最有趣的線上課程平台 | 自學那些學校沒教的事" data-react-helmet="true"><meta name="google-site-verification" content="dxQXUxo-Ypo_w3JIINgVr9PJItIfniuKoi5FJ4LZFcU" data-react-helmet="true"><meta name="application-name" content="Hahow" data-react-helmet="true"><meta name="author" content="Hahow - 好學校" data-react-helmet="true"><meta name="keywords" content="Hahow,好學校,線上課程,課程募資,網路教學" data-react-helmet="true"><link rel="apple-touch-icon" sizes="180x180" href="https://hahow.in/static/images/apple-touch-icon.png" data-react-helmet="true"><style type="text/css">.styles_overlay__CLSq- {\n  background: rgba(0, 0, 0, 0.75);\n  display: flex;\n  align-items: flex-start;\n  justify-content: center;\n  position: fixed;\n  top: 0;\n  left: 0;\n  right: 0;\n  bottom: 0;\n  overflow-y: auto;\n  overflow-x: hidden;\n  z-index: 1000;\n  padding: 1.2rem;\n}\n.styles_overlayCenter__YHoO7 {\n  align-items: center;\n}\n.styles_modal__gNwvD {\n  max-width: 800px;\n  position: relative;\n  padding: 1.2rem;\n  background: #ffffff;\n  background-clip: padding-box;\n  box-shadow: 0 12px 15px 0 rgba(0, 0, 0, 0.25);\n  margin: auto;\n}\n.styles_closeButton__20ID4 {\n  position: absolute;\n  top: 14px;\n  right: 14px;\n  border: none;\n  padding: 0;\n  background-color: transparent;\n  display: flex;\n}\n.styles_closeIcon__1QwbI {\n}\n.styles_transitionEnter__3j_-a {\n  opacity: 0.01;\n}\n.styles_transitionEnterActive___eQs7 {\n  opacity: 1;\n  transition: opacity 500ms cubic-bezier(0.23, 1, 0.32, 1);\n}\n.styles_transitionExit__1KmEf {\n  opacity: 1;\n}\n.styles_transitionExitActive__1nQXw {\n  opacity: 0.01;\n  transition: opacity 500ms cubic-bezier(0.23, 1, 0.32, 1);\n}\n</style><meta charset="utf-8"><meta name="viewport" content="width=device-width,initial-scale=1"><meta name="p:domain_verify" content="85be3689f02516040edbcaa21c56777c"><meta name="hahow-version" content="%HAHOW_VERSION%"><title>探索課程 - Hahow 好學校</title><link rel="shortcut icon" href="https://hahow.in/favicon.ico"><link rel="apple-touch-icon" href="https://hahow.in/highres-icon.png"><link rel="apple-touch-icon" href="https://hahow.in/apple-touch-icon.png"><link rel="mask-icon" href="https://hahow.in/website_icon.svg" color="#eb5e00"><link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" crossorigin="anonymous"><link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css"><script type="text/javascript" async="" src="https://www.googleadservices.com/pagead/conversion_async.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/plugins/ua/ec.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/gtm/js?id=GTM-M8VMH5D&amp;cid=1101336507.1589836974"></script><script type="text/javascript" async="" src="https://widget.intercom.io/widget/pd9xhh4p"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="ht ...

# %%
# 取得資料
html_source = browser.page_source

soup = BeautifulSoup(html_source, 'html.parser')
soup.find('h4', class_='title').text
# 改用 selenium 就可以正常取得
# Out:
# '【AI 深度學習】新手入門應用篇'

# %% [markdown]
# ## 作業目標
#
# * 1. 根據範例使用 selenuim 取出 Hahow 網站中所有課程的資料，並用一個適合的資料結構儲存（Hint: 將所有資料存在一個變數當中取出）
# * 2. 剛剛的做法只能取出第一頁，試著取出所有頁面的資料。

# %%
import time

# %%
browser = webdriver.Chrome(executable_path='chromedriver')
browser.get("https://hahow.in/courses")

# %%
link_list=[]
for i in range(1,21):
    link_list.append("https://hahow.in/courses?page="+str(i))

# %%
info={}
for link in link_list:
    browser.get(link)
    time.sleep(10)
    html_source = browser.page_source
    soup = BeautifulSoup(html_source, 'html.parser')
    courses=soup.find_all(class_='sc-10r5mg2-0')
    for course in courses:
        title=course.find('h4', class_='title').text
        price=course.find_all('span')[-1].text
    
        info.update({title:price})
info
# Out:
# {'中小企業政府免費補助計畫自己來': 'NT$3,188',
#  '從零開始，Unity3D 射擊遊戲製作真簡單': 'NT$1,380',
#  '手繪珠寶設計入門：完成你的第一件珠寶設計': 'NT$1,900',
#  '職場寫作課：從個人品牌到自媒體': 'NT$1,688',
#  '跨國實戰：新鮮人用設計思考寫出好履歷': 'NT$900',
#  '紙上的美妝師：連禾時尚彩妝畫': 'NT$1,680',
#  '顧客分類大師：Python x RFM 會員經營新觀點': 'NT$1,988',
#  '翻轉文字：給孩子好玩的創意寫作課！': 'NT$1,600',
#  '大人的蠟筆畫：活用油畫知識，寫實生活微光': 'NT$1,500',
#  '機器學習攻略：實戰心法到求職技巧': 'NT$1,800',
#  '法式甜點在地魂製作攻略－日日在家菓實日': 'NT$2,680',
#  '林長揚職場簡報術：一次搞定所有工作簡報！': 'NT$1,800',
#  '概念式時尚插畫｜我的小小時裝週': 'NT$1,980',
#  '羅寶鴻的安定教養課：12 個對話練習與心法': 'NT$1,188',
#  '七日減醣計畫「一週持續執行！」邊吃邊享瘦': 'NT$1,080',
#  '閱讀攝影的眼神 - 啟動你的影像理解力': 'NT$1,480',
#  '手機 App 開發入門：App Inventor 2 實作': 'NT$800',
#  '全民防疫通識課：陳建仁副總統來開講': 'NT$0',
#  '省錢攝影術：零基礎拍好美食＆商品！': 'NT$1,690',
#  'Linux 我來教: CentOS/ RHEL 8 新世代雲端': 'NT$3,300',
#  '口譯員浩爾的打獵式聆聽＆資訊處理術': 'NT$1,499',
#  '資料變決策！從零上手 Tableau 大數據視覺化': 'NT$2,580',
#  '互動藝術程式創作入門 Creative Coding ': 'NT$2,400',
#  '人生管理學：把自己當成公司經營': 'NT$2,049',
#  '薩克斯風 - 13 堂基本功吹出專輯的美聲': 'NT$1,500',
#  '用實際案例學設計-美編的 InDesign 排版課': 'NT$1,600',
#  '動盪時代的資產配置：王伯達人生財務規劃學': 'NT$3,500',
#  '手繪轉電繪，我選 Procreate！': 'NT$2,600',
#  '氣球達人不藏私！宋俊霖的塞球雕塑造型課': 'NT$3,000',
#  '0-2 歲寶寶父母必修課 - 專業治療師開課囉！': 'NT$1,880',
#  '一支手機拍完行銷影片，產品賣更好！': 'NT$2,500',
#  'Keynote即戰力：簡報製作到上台演講都搞定': 'NT$2,400',
#  '輕鬆學好道地美式發音！': 'NT$2,000',
#  '資料科學：Azure 機器學習工作室入門': 'NT$890',
#  '話聊庶務課－探索你說話的個人風格': 'NT$1,280',
#  '新手上路必學：電商人才求職全攻略！': 'NT$3,600',
#  'Office論文格式技巧：高效編輯專業文件': 'NT$1,490',
#  '蝦皮個人賣家行銷術：突破網拍初期盲點  ': 'NT$1,299',
#  'ZBrush 201 從初階到高階 - 隱藏密技大公開': 'NT$2,680',
#  'PHP 攻略：Laravel 5.8 從入門到實務': 'NT$2,400',
#  '成功前進科技巨頭，百萬年薪面試術！': 'NT$2,699',
#  'Github 免費架站術！輕鬆打造個人品牌': 'NT$890',
#  '網美咖啡廳在你家，九款鏡面蛋糕一次學': 'NT$2,480',
#  '產品分析入門：UX 設計師的思考術': 'NT$2,450',
#  'Docker 部署入門完全指南-圖片速學攻略': 'NT$1,199',
#  'Python 0 到 1 基礎商業數據分析實戰': 'NT$3,188',
#  '角色原型雕塑 - 走進電影美術的世界': 'NT$2,680',
#  '【AI 深度學習】新手入門應用篇': 'NT$2,500',
#  '一次搞懂專案管理 - 從入門到業界實務': 'NT$2,200',
#  '畫出有質感的 2D 手繪動畫 - Toon Boom': 'NT$2,000',
#  '你的遠端私人教練，從零開始的增肌訓練課': 'NT$2,980',
#  '新制多益聽力滿分攻略－高效率秒殺解題技巧': 'NT$4,990',
#  '指尖上的閃亮秘密 - 你的第一堂指甲養護課': 'NT$1,200',
#  '資料應用：Excel VBA 爬蟲與 IE 操控入門': 'NT$2,400',
#  '把美肌關了吧！韓星好膚質底妝，是畫出來的': 'NT$2,000',
#  '超強印象！人與動物的 logo 設計課': 'NT$1,680',
#  '職場必備的批判思考力：反省力篇': 'NT$499',
#  '日本電商代購批貨：銷售獲利心法': 'NT$3,990',
#  '程式交易極速上手！用 Eleader 30 秒寫策略': 'NT$3,600',
#  '開運陽宅系列：人人必備的臥房風水常識': 'NT$1,888',
#  '兩小時學會子彈筆記：訂製專屬你的高效生活': 'NT$1,499',
#  '跨平台 APP - React Native 快速學習攻略': 'NT$2,500',
#  'YouTuber 的 36 堂課：讓你被更多人看到': 'NT$2,400',
#  '英文寫作經典指南：10個流暢俐落的必備法則': 'NT$2,450',
#  '讓創作帶來長期收入！圖像 IP 授權第一課': 'NT$2,380',
#  'Python 資料分析 - 網頁爬蟲與視覺呈現': 'NT$1,680',
#  '低熱量馬卡龍自己做：韓國金老師的甜點時光': 'NT$1,280',
#  '產品思維：Spotify 產品經理帶你快速入門': 'NT$1,800',
#  '自學程式如何快速入門 - 以 Python/JS 為例': 'NT$2,200',
#  '說說刺繡：基礎到進階立體，此刻的煦色韶光': 'NT$2,340',
#  'Katie 凱蒂流動瑜珈：啟動熱能，身心修復': 'NT$1,800',
#  '社會在走 面子要有-明星彩妝師的型男打造術': 'NT$1,999',
#  'GTM 建置術：數位追蹤必備，代碼設定神器': 'NT$2,400',
#  '如何成為資料分析師：從問題解決到行動方案': 'NT$1,980',
#  '日常應用到舞台，Hold 住全場主持力': 'NT$1,750',
#  '開店一次搞定！餐廳創業最強生存攻略': 'NT$4,800',
#  '成為專業筆譯必備：商務日文翻譯力': 'NT$3,000',
#  '你的第一堂花藝課：一起來綁一束花吧！': 'NT$1,800',
#  '貓咪就醫減壓完全指南': 'NT$1,580',
#  '陳列設計：隱形的視覺傳銷學': 'NT$2,000',
#  '專業造型師技法在家學 - 新娘秘書養成班': 'NT$3,000',
#  '一小時光屋 - 魔術方塊速解高手之路': 'NT$880',
#  '職場必備的批判思考力：論戰力篇': 'NT$499',
#  '散戶必看！台股擂台王的波段操作心法': 'NT$3,600',
#  '把捉日常光影細節-畫出充滿靈魂的人像插畫': 'NT$1,600',
#  '生活中的哲學！給新手的手沖咖啡入門課': 'NT$2,800',
#  '從興趣到接案：建立專業插畫創作流程': 'NT$2,680',
#  '生活要清爽：讓空間煥然一新的整理收納課': 'NT$1,580',
#  '利息養成現金流：債券入門投資術': 'NT$1,990',
#  '小資族保險的第一堂入門課': 'NT$1,688',
#  '創作你的療癒香草茶！百種風味搭配邏輯': 'NT$1,680',
#  '托福口說拿分 4 原則｜發音、表達一把罩': 'NT$2,500',
#  'LOGO 必修課：發展品牌識別的第一步': 'NT$2,400',
#  'Excel VBA 金融資料抓取 | 打造股票研究系統': 'NT$3,450',
#  '開啟你的 AI 技能 —— 無痛入門 NLP': 'NT$2,600',
#  '日本求職全攻略，開啟你海外求職第一步': 'NT$1,800',
#  'AI 行銷學：用 Python 機器學習創造商業新價值': 'NT$3,888',
#  '戶外攝影實戰：用鏡頭看見台灣': 'NT$1,800',
#  '從生活小物到街景，用鋼筆速寫在日子裡旅行': 'NT$1,200',
#  'illustrator 入門：從形狀到美麗的向量插畫': 'NT$1,960',
#  '小資族 ETF 狠會賺投資法': 'NT$3,680',
#  '不用動腦的攝影課-七堂課拍出有質感的照片': 'NT$790',
#  '英雄之旅：自己的故事，別當配角': 'NT$2,049',
#  'AutoLisp - 紮實入門與實例應用': 'NT$2,500',
#  'GA 從零上手！數位時代必學的數據行銷秘笈': 'NT$2,400',
#  '真空烹調在家做，科學方法學舒肥': 'NT$1,800',
#  '區塊鏈應用敲門磚：行動支付到商業案例': 'NT$2,399',
#  '開啟程式設計之門 - C++ 核心課程': 'NT$1,490',
#  'R語言和文字探勘 - 洞悉巨量文字的商業價值': 'NT$2,790',
#  '網路行銷新手入門，打造品牌電商 (上)': 'NT$1,800',
#  '職場必備的批判思考力：創意力篇': 'NT$499',
#  '品牌力革命：運動品牌塑造心法': 'NT$3,200',
#  'ZBrush - 設計師公仔入門課': 'NT$4,190',
#  '零基礎輕鬆學：流行鋼琴【即興伴奏】彈唱': 'NT$2,380',
#  '金融市場 x 程式交易：通往財富自由之路': 'NT$4,200',
#  '韓語基礎文法自由行－輕鬆開口說': 'NT$1,990',
#  '愛上突破困難的新自己：啟發成長五要訣': 'NT$2,500',
#  'BIM 實務即戰力！一堂課學會建築資訊模型': 'NT$4,190',
#  '電音製作入門：EDM 編曲攻略！': 'NT$2,500',
#  '從姿勢開始：生活人體工學 & 痠痛自救法！': 'NT$2,200',
#  '手作乾燥花 - 創造植感生活': 'NT$1,800',
#  '一支燈學打光，家裡就是攝影棚': 'NT$1,990',
#  '【影像說書人】攝影不只是按下快門': 'NT$2,580',
#  '求職平台大揭秘！寫出讓人資心動的專業履歷': 'NT$1,800',
#  '活用深度學習：MT4 交易程式整合視覺模型': 'NT$3,890',
#  '新手必學的3件事 - 進場點、停損點、停利點': 'NT$599',
#  '玩轉數據與資料：Excel VBA 入門教學': 'NT$2,790',
#  '產品經理職場學：PM 必修的職涯指南！': 'NT$1,888',
#  '成為電音製作人：帶你完成一首電音單曲！': 'NT$2,980',
#  '廣告照片怎麼拍 ─ 美食拍攝秘訣教給你嘍': 'NT$2,600',
#  '職場必備的批判思考力：基礎篇': 'NT$499',
#  'IG 全攻略：從零開始的 Instagram 經營學': 'NT$1,800',
#  '聲入人心-周震宇的人聲必修課': 'NT$2,680',
#  '如何秒速視譜？驚人的獨家視譜法': 'NT$2,580',
#  '吉他彈唱診療室 - 彈唱入門必學基本功': 'NT$2,000',
#  'Git - 軟體工程師必備的版本管理時光機': 'NT$2,600',
#  '知名歌手的老師 幫你歌聲大改造': 'NT$2,200',
#  '爵士吉他入門訓練班': 'NT$2,800',
#  '面子裡子都不輸 - 王介安的 GAS 職場談判課': 'NT$2,890',
#  '不可錯過的時代趨勢：從自學區塊鏈到專家！': 'NT$2,200',
#  '科技苦手事務所：不學 Coding 的邏輯思考課': 'NT$820',
#  '醫學簡報快製力': 'NT$4,190',
#  'ChatBot 從 0 到 1 突破演算法の後社群神器': 'NT$1,800',
#  '將知識提煉成觀點：鮪魚的獨門閱讀心法！': 'NT$1,600',
#  '15 單元看懂經濟運行，掌握全球投資趨勢': 'NT$3,600',
#  '樂理指法一把抓 - 鋼琴基礎從零開始': 'NT$1,900',
#  '超人氣吸睛表達力－職場必學表達課！': 'NT$1,980',
#  '提升工程師的科技力！AWS 雲端網站建置': 'NT$1,790',
#  '一滑就看完！條漫繪製攻略': 'NT$1,290',
#  '用 Python 理財：打造自己的 AI 股票理專': 'NT$3,999',
#  '淺談設計營運: 給設計團隊的版本控制技巧': 'NT$790',
#  '打造被動收入：建立人生主導權的系統化做法': 'NT$3,590',
#  'TALK SMART！打造更有深度的英語口說': 'NT$1,500',
#  '學會 9 種場合適用妝容 － 小資女孩化妝術': 'NT$1,500',
#  '行銷必上文案課：受眾溝通與表達': 'NT$1,280',
#  '時間管理心法：升級人生作業系統': 'NT$1,799',
#  '工作疲累的救星：放鬆筋膜不求人！': 'NT$1,800',
#  'Python 入門特訓 - 基礎實作到證照攻略': 'NT$1,490',
#  '百萬 YouTuber 阿滴－攻心剪輯術！': 'NT$1,800',
#  '火頭工做麵包：用科學方法學做健康麵包': 'NT$2,600',
#  '存零股學理財 - 累積你人生的第一張股王': 'NT$1,288',
#  '啟動你的工匠魂：打造第一個皮件作品！': 'NT$2,380',
#  'Kotlin Android 高效開發：全新語言雲端世代': 'NT$4,000',
#  '氣球達人宋俊霖 教你氣球編織玩造型！': 'NT$2,500',
#  '買房必知！告別無殼蝸牛的銀行貸財術！': 'NT$2,980',
#  '紙上咖啡店開張！雪莉的午茶繪畫課': 'NT$2,000',
#  '出遊拍照不 NG - 應用 PS 修出美麗天空': 'NT$999',
#  'amps－初階人物繪製基礎概念': 'NT$2,000',
#  '看穿公司背後隠藏的秘密   一切從財報開始': 'NT$2,066',
#  '好想法好好說 - 潘月琪的12堂質感說話課': 'NT$1,800',
#  '用 Python 打造自己的股票小秘書': 'NT$4,288',
#  '訪談溝通術：交流、說服與談判的必勝訣竅': 'NT$1,890',
#  '新多益閱讀：英語教父助你一舉突破企業門檻': 'NT$2,000',
#  '小資生活投資學，美股研究趣': 'NT$1,888',
#  'Logic Pro X 從零開始': 'NT$1,300',
#  '職場必備的 Excel 關鍵技法 - 入門': 'NT$650',
#  '為個人品牌設計的 WiX 網站架設實作': 'NT$3,200',
#  '設計色彩學：建立自己的色彩品味資料庫': 'NT$1,800',
#  '【幫寶貝做照片貼圖】用愛將回憶保鮮  ': 'NT$999',
#  '上台惡夢變美夢：穩健台風的魅力溝通術': 'NT$1,800',
#  '怪獸工場 - 基礎素描實戰篇': 'NT$3,600',
#  '你的明星教練－祖雄的腹肌養成計畫': 'NT$1,600',
#  '股市投資新手策略筆記': 'NT$1,500',
#  'PS 核心技法 | 人像膚質精修篇': 'NT$2,780',
#  'AI 人工智慧－深度學習－金融實戰應用': 'NT$2,888',
#  '實用記憶法 - 用記憶改善生活': 'NT$1,500',
#  '水彩插畫師皮忠 - 鯨魚初階課': 'NT$1,600',
#  '一練就上手！書寫高效率日常美字': 'NT$1,600',
#  '三步驟學會即興演奏爵士樂': 'NT$2,800',
#  '用手機捕捉瞬息美好-IPPA 冠軍的攝影心法': 'NT$1,800',
#  '微電影進階－硬體原理與 Log 調色技術': 'NT$2,800',
#  '興趣變副業！打造自己的手作品牌': 'NT$2,500',
#  '畫桌上的植物學-自然控的觀察手繪圖鑑課': 'NT$1,900',
#  'Java 與 Kotlin 一起學 : 程式設計的起點': 'NT$2,600',
#  '不正經古文講堂：流傳五千年的魯蛇哲學': 'NT$1,500',
#  '動畫背後邏輯與創意－臺灣吧知識轉譯力': 'NT$2,000',
#  '大學生必修的 12 堂簡報課': 'NT$1,800',
#  '賴導教你 搜便宜機票 玩航空哩程！': 'NT$1,600',
#  '韓式豆沙裱花-特殊造型蛋糕': 'NT$2,600',
#  '批判到創新：不是研究生也能學的研究方法': 'NT$1,800',
#  '台灣小說名場面：五百字吸收文字內力': 'NT$1,800',
#  '標標標標標準字 - 從生活創意到邏輯實踐': 'NT$2,400',
#  '瘦身營養學：用科學飲食邁向理想體態！': 'NT$1,790',
#  '藍曬技法 - 初學者的氰版顯影  ': 'NT$999',
#  '數據為王: 金融資料分析＆算法交易': 'NT$2,866',
#  '零基礎邁向區塊鏈工程師：Solidity 智能合約': 'NT$4,000',
#  '職場英文大補帖｜上班族的 Email 寫作課': 'NT$1,999',
#  '玩轉 Unity! 零基礎打造自己的 2D 遊戲！': 'NT$2,000',
#  'Evernote，你的無壓工作術': 'NT$1,380',
#  'Excel程式量化交易速成：不盯盤期貨投資法': 'NT$1,888',
#  'Excel 達人：學會所有商務應用的需求！': 'NT$2,500',
#  '愛情哲學課-學習愛情知識 克服愛的難題': 'NT$999',
#  '【Illustrator / Ai 進階】深度精修班': 'NT$2,190',
#  'Power BI數據分析實戰-邏輯與資料視覺化': 'NT$2,500',
#  '第一次自助旅行就輕鬆上手！': 'NT$1,370',
#  'ETF 投資全球：帶你量身打造專屬資產配置': 'NT$3,000',
#  '啾啾鞋的資料彙整術 - 別淹沒在資訊海！': 'NT$1,500',
#  '職場在走法律常識要有-上班族必修法律課': 'NT$1,800',
#  '四小時學會打光，成為商業攝影師！': 'NT$3,800',
#  '實用Photoshop- 入門到大師，紮實範例': 'NT$2,046',
#  '簡報方舟：高效簡報的系統化做法': 'NT$1,800',
#  '比阿里巴巴還便宜的女裝批發': 'NT$3,980',
#  '從生活認識微積分：基礎觀念篇(1)': 'NT$1,400',
#  '伸縮自如的字體課：從基本功到創意風格': 'NT$2,400',
#  '教養心法：用數位心智圖提升孩童學習力': 'NT$2,400',
#  'TOEIC — 全方位攻略 2018 新制多益！': 'NT$1,000',
#  'R語言和商業分析-洞悉商業世界中的資料科學': 'NT$2,500',
#  '經典駭客攻擊教程：給每個人的網站安全入門': 'NT$2,500',
#  '掌握英文8原則-自學英文的最短路徑': 'NT$1,500',
#  '台科 EMBA 年年爆滿的一門 Word 課（B+C 系列）': 'NT$1,050',
#  'Android APP高效入門 強靭基礎刻不容緩': 'NT$3,600',
#  '一步一步學編劇：搞笑催淚技巧大揭密': 'NT$2,200',
#  '營養師萊恩：狗狗鮮食簡單做': 'NT$1,680',
#  '畫圖無死角，360 度全景透視法': 'NT$2,400',
#  'ZBrush 101 - 從零開始學 ZBrush': 'NT$1,800',
#  'Final Cut Pro X 入門 - 0到1帶你學會剪輯': 'NT$2,000',
#  '全方位學 WordPress - 從架站到整合行銷': 'NT$7,680',
#  '斜槓世代必學｜自拍自剪影片養成計畫': 'NT$1,500',
#  'After Effects 基礎合成應用實例 I ': 'NT$2,500',
#  '印花樂－自製手感印花好禮': 'NT$1,200',
#  '三小時教你怎麼講道德不輸人': 'NT$1,200',
#  '設計師接案學－業界求生必備守則': 'NT$1,800',
#  '【精良日本製作】零基礎電繪實例教學課程': 'NT$2,000',
#  '空間大數據分析：GIS入門': 'NT$1,900',
#  'Facebook 廣告投放實戰': 'NT$2,400',
#  '從 iPad 入門 - 音樂製作 & 影像剪輯': 'NT$1,000',
#  '【影音行銷】將名單變成訂單的最佳解答': 'NT$1,800',
#  '獵頭顧問 S 姐帶你健檢人生職涯': 'NT$1,888',
#  '在家也能成為氣球達人！': 'NT$1,500',
#  '平面設計 - 從理論到實務運用及對談 (初階)': 'NT$2,000',
#  '英語教父教你輕鬆戰勝新多益聽力': 'NT$2,000',
#  '加密貨幣交易戰鬥營 - 一條龍翻身攻略！': 'NT$3,288',
#  '美食攝影師：配色、擺盤、光影的視覺饗宴': 'NT$1,390',
#  'AE基礎動畫 -【讓 2D 角色簡單動起來】': 'NT$2,200',
#  '總體經濟投資術：用數據分析清楚了解市場': 'NT$3,000',
#  '零經驗不 NG，建構你的【股市金流】': 'NT$3,200',
#  '【電商正夯】找工作找實習必備 4 大技能': 'NT$2,500',
#  '畫你、畫他、畫我們的人物頭像！': 'NT$1,200',
#  '從上手到專業，寫出你想要的文案效果': 'NT$1,680',
#  'Adobe XD / PS  —  網頁設計 與 UI 教學': 'NT$1,990',
#  '穿越影像的魔幻世界 - PS 超現實合成後製教學': 'NT$1,300',
#  '240 分鐘 - 忘掉拍照，學會攝影': 'NT$2,049',
#  '免批卡免出國，也能日本代購批貨': 'NT$1,980',
#  '用 Python 理財：打造小資族選股策略': 'NT$3,200',
#  '【行內人密技】讓你的 Word 擁有 World': 'NT$1,200',
#  '超現實影像創作 - PS 合成後製課': 'NT$1,100',
#  '超療癒韓式裱花裝飾蛋糕 自己動手做': 'NT$2,400',
#  '外商銀行主管 - 教您外匯市場賺錢的秘密': 'NT$2,466',
#  '超快速 iOS 實用開發入門～學會6個APP': 'NT$2,200',
#  '【不會畫圖】也能學會動態LINE貼圖製作': 'NT$1,488',
#  '內容力：打造品牌的超能力': 'NT$1,800',
#  '創業先修，你準備好了嗎？': 'NT$1,800',
#  '台科 EMBA 年年爆滿的一門 Word 課（A系列）': 'NT$950',
#  '網路行銷全方位入門實戰（下集）': 'NT$1,480',
#  'Unity 遊戲開發- [進階篇] 打造堆疊遊戲': 'NT$1,299',
#  '從 0 開始學 AE（下集）｜進階動態應用': 'NT$2,500',
#  '攝影創作 - 調出電影感色彩': 'NT$1,500',
#  '快速養成《深入人心英文簡報術》': 'NT$1,680',
#  '臉的故事-風格人像壓克力繪畫': 'NT$1,300',
#  '【不沾水水彩】入門-色鉛筆畫出水彩風': 'NT$1,300',
#  '股市投資實務': 'NT$4,500',
#  '上班族的存股投資術': 'NT$2,000',
#  '【吉他伴奏大全】': 'NT$1,200',
#  '三小時學會拆解社會現象與新聞議題！': 'NT$990',
#  '藝術字數位化，手寫風格 Logo 設計': 'NT$1,200',
#  '財富順流 GPS - 3 步驟打造財務自由藍圖！': 'NT$2,680',
#  '精準設計：簡報心法篇': 'NT$4,500',
#  '行動裝置繪圖趣 ☆ 手機平板皆可畫': 'NT$750',
#  '社群力：30 堂課突破你的內容行銷盲點！': 'NT$2,400',
#  '小資族理財的第一堂入門課': 'NT$1,688',
#  'AutoCAD 電腦繪圖 3D應用篇－紮實入門': 'NT$2,500',
#  '打動人心的創作秘密，畫出個性的角色設計': 'NT$1,280',
#  '【Illustrator / Ai 入門】五小時保證上手': 'NT$1,590',
#  '入門到專精，成為職業 DJ 從這裡開始！': 'NT$3,600',
#  '資料庫設計 - 有效的使用系統資料': 'NT$1,890',
#  '給對 Premiere 毫無頭緒的你：最完整的 8 堂課': 'NT$1,200',
#  '用程式構築的繪畫世界 — CSS 繪圖': 'NT$1,800',
#  '職人必修的 RWD 網頁入門班': 'NT$2,000',
#  '當個水彩甜點師 — 雪莉的午茶繪畫課': 'NT$1,200',
#  'Python 資料分析＆機器學習入門': 'NT$2,500',
#  '在台灣也能學一口漂亮英文！Phonics 自然發音&正音教學': 'NT$990',
#  '40 張佈燈圖來看打燈這回事': 'NT$999',
#  'MATLAB 音訊處理入門 - 專屬語音助理': 'NT$2,500',
#  '畫圖不帶尺，輕鬆學會透視畫建築！': 'NT$1,800',
#  '解碼程式思維－物件導向的靈魂': 'NT$800',
#  '追劇學韓文—韓語初級會話課程': 'NT$980',
#  '網路行銷全方位入門實戰（上集）': 'NT$1,480',
#  '從0開始：從書籍封面學平面設計！': 'NT$1,500',
#  '旅行插畫，培養不可或缺的創造力': 'NT$1,090',
#  '吉他編曲超訓練：豐富精緻的彈奏設計': 'NT$2,499',
#  '設計 DIY - 網拍家的 PS 設計實戰': 'NT$1,800',
#  '浪漫探戈 - 從基本舞步到即興組合': 'NT$300',
#  '漫遊程海 | Python 入門到製作遊戲演算法': 'NT$1,390',
#  '從零開始學文案 — 育名的文案小教室': 'NT$2,500',
#  '進入比特幣世界 - 比 99% 的人更懂它！': 'NT$1,380',
#  '商用日語：一次學好各種敬語及書信禮儀': 'NT$1,500',
#  '履歷面試大剖析－網路科技外商求職技巧': 'NT$899',
#  '人人都是賈伯斯,你也可以開發自己的產品': 'NT$2,200',
#  'POP-UP！立體繪本手工書 - 娃娃屋篇': 'NT$1,200',
#  '拯救你的樂理 - 現代音樂和聲學': 'NT$2,800',
#  'Duga 的奇幻插畫課 - 幻想角色篇': 'NT$1,200',
#  '動畫互動網頁特效入門（JS/CANVAS）': 'NT$2,500',
#  '不必下蠱的人心攻略術 — 小說實戰技術': 'NT$1,500',
#  '跟著插畫家十堂課輕鬆學塔羅': 'NT$990',
#  '如何練習動漫速寫 - Anime Sketches': 'NT$600',
#  '從入門到業界實戰 - UI / UX 前端網頁設計': 'NT$2,500',
#  '從 0 到 1 - 為初學者而設計的日文課': 'NT$1,500',
#  '開啟資料科學的學習大門 - R入門教學': 'NT$500',
#  '你真的會買淘寶？代購秘密大公開': 'NT$990',
#  'AE/MG || 進階動畫特效 Vol.2': 'NT$2,000',
#  'APP Inventor 2  進階實戰': 'NT$1,000',
#  '日本 ACG 繪師教你用 PS 畫出宇宙少女': 'NT$1,500',
#  '從 0 開始學 AE（上集）｜動態設計基礎': 'NT$1,200',
#  '與大師相會：每個人都能體現的舞台魅力': 'NT$2,880',
#  '【Java 程式語言】從 0 到 1': 'NT$1,890',
#  '攻城獅必學 - 從0到1打造購物網站': 'NT$2,000',
#  'Python 網頁爬蟲入門實戰': 'NT$1,890',
#  'C 語言入門特訓': 'NT$1,000',
#  '靈魂的代言人-塔羅牌義全解析': 'NT$800',
#  'Python Web 程式設計入門實戰': 'NT$1,590',
#  '攝影剪輯必學6堂課 - 微電影、VLOG、MV': 'NT$900',
#  'App Inventor 2 入門特訓': 'NT$1,000',
#  '藝用解剖學1 - 達文西維特魯威人': 'NT$1,000',
#  '吉他從零開始-Fingerstyle（進階）': 'NT$800',
#  '設計思考，頂尖企業都在學的創新流程！': 'NT$2,400',
#  '在世界各地都可以成為溜溜球高手': 'NT$1,200',
#  'Node.js 網站開發 with React.js': 'NT$1,980',
#  '怪獸工場 - 基礎角色造型篇': 'NT$1,500',
#  '怪獸工場-遊戲場景設計篇': 'NT$1,500',
#  'Photoshop練功坊 -入門操作到進階合成': 'NT$1,500',
#  '不到一小時就能學會的個人網站製作': 'NT$220',
#  '初心者！Lightroom數位暗房基礎後製': 'NT$500',
#  '相機外閃的神奇攝影術': 'NT$1,990',
#  '六分鐘快速理解一篇英文文章!': 'NT$950',
#  '挖出你的節奏細胞!爵士鼓教學-基本節奏篇': 'NT$1,800',
#  '一個小時！DIY你的作品集網站': 'NT$1,200',
#  '迎向南美－從零開始學西班牙文': 'NT$450',
#  '前進夢想工作：寫出必勝履歷！': 'NT$800',
#  '用歌唱技巧唱出屬於自己的迪士尼魂-初階': 'NT$1,500',
#  '初學者也能學會名片設計': 'NT$1,500',
#  '邊走邊畫，帶著手帳旅行去！': 'NT$850',
#  '常見日文發音錯誤及發音指南': 'NT$1,900',
#  '比ㄅㄆㄇ簡單的韓語發音': 'NT$1,590',
#  '從零打造屬於你的停格動畫 Vol.1': 'NT$2,000',
#  '十堂課輕鬆學會木吉他自彈自唱': 'NT$800',
#  'JavaScript 程式設計新手村': 'NT$1,980',
#  'AutoCAD 電腦繪圖2D基礎篇－紮實入門': 'NT$2,500',
#  '手作印章：篆刻基礎技法': 'NT$500',
#  '莉朵花藝 - 體驗不凋花（材料包已售完）': 'NT$200',
#  'Illustrator 平面圖像設計': 'NT$1,200',
#  '初心者 － Python 入門': 'NT$899',
#  '愛上西班牙文～ 西班牙怎麼吃?': 'NT$390',
#  'Processing - 讓程式碼說設計語言': 'NT$1,200',
#  '復古風味色鉛筆食品速寫': 'NT$850',
#  '克服阻礙，快速說出流暢英文': 'NT$1,480',
#  'Photoshop 最重要的基本課': 'NT$1,000',
#  '2016 未來大人物－全系列課程': 'NT$800',
#  'iOS 入門 － 從介面設計到開發': 'NT$1,600',
#  '小編必學，百萬觀眾動畫製作術－動畫星球': 'NT$1,500',
#  'MG特效 -【3D陣列圖形與分子運用C4D+AE】': 'NT$1,750',
#  'Sass － 讓 CSS 變得更簡單有趣': 'NT$1,200',
#  '有系統 把字寫好一點都不難': 'NT$600',
#  '成長駭客 (1)－Landing Page 5 分鐘上手': 'NT$1,200',
#  '超簡單羊毛氈捲毛好朋友入門班': 'NT$500',
#  '男友必學攝影課 by 有fu攝影': 'NT$1,499',
#  '資料科學：Orange3 入門': 'NT$250',
#  'PHP+MySQL 動態網頁入門': 'NT$1,800',
#  '創業必備：Laravel 5.3 後端網站入門': 'NT$1,980',
#  'Spine 新手快速做動畫超簡單！': 'NT$799',
#  '動物水彩 - 記錄生活中的小夥伴': 'NT$600',
#  '神秘腹語術，我要成為腹語師！': 'NT$1,500',
#  '編劇：一起說個好故事': 'NT$2,500',
#  'LINE 貼圖 DIY - 隨手創意輕鬆玩！': 'NT$500',
#  'UI設計入門，輕鬆上手 Sketch App！': 'NT$1,500',
#  '日文助詞大補帖': 'NT$2,500',
#  '動畫互動網頁程式入門 (HTML/CSS/JS)': 'NT$2,000',
#  '用簡單的日文自助遊日本': 'NT$500',
#  '波波的氣球娃娃 - 歌姬初音篇': 'NT$500',
#  '用隨處可得的平價筆寫一手美字': 'NT$800',
#  '超簡單學會 3D 建模 & 列印－基礎篇': 'NT$1,000',
#  '輕鬆畫出毛小孩的幸福臉龐♡ 免費軟體 MediBang Paint': 'NT$750',
#  '讓圖不只是好看的－資訊設計思考力！': 'NT$1,800',
#  '流行歌曲製作秘訣：Cubase 8 編曲軟體應用': 'NT$1,500',
#  '創業必備：前端網頁設計入門': 'NT$500',
#  '精準設計：PowerPoint 實戰技巧': 'NT$900',
#  '角色設計2_人體動態與空間透視': 'NT$1,200',
#  '基礎音樂製作 - Ableton Live': 'NT$750',
#  '超濃郁！美味的食物插畫': 'NT$550',
#  '日文時態快速上手': 'NT$2,000',
#  '丟掉 Word，進入 InDesign 的排版世界': 'NT$1,000',
#  'Cartoon 插畫 - 人物篇 (●—●)': 'NT$500',
#  '畫，故事 //手繪深度圖像創作': 'NT$650',
#  '怪獸工場 - 頭部構成與造型設計篇': 'NT$1,500',
#  '怪獸工場 - 人體結構篇': 'NT$1,500',
#  '每天戀一點，戀愛心理學': 'NT$600',
#  '音樂創作原來這麼簡單！': 'NT$600',
#  '手繪溫度．甜點丼飯插畫篇': 'NT$799',
#  'SAI 插畫快速好上手': 'NT$350',
#  '一堂把你變高跟鞋專家的課': 'NT$399',
#  '刺繡 - 簡單學會多種針法做別針': 'NT$600',
#  'AE/MG || 動畫特效 Vol.1': 'NT$1,500',
#  '一張速寫，一個生活故事': 'NT$500',
#  '設計風，手寫英文藝術字（基礎篇）': 'NT$650',
#  '超簡單！原子筆也能輕鬆畫插畫': 'NT$300',
#  'CRYENGINE 獨立遊戲開發 - 場景建構篇': 'NT$600',
#  '用烏克麗麗教你藍調即興 - 初級': 'NT$800',
#  '數位技法 - 配色質感輕鬆搞定！': 'NT$500',
#  '角色設計1_人體骨架結構': 'NT$900',
#  '他抓得住我！自由筆觸繪出人像靈魂': 'NT$300',
#  '怪獸工場 - 色彩光學篇': 'NT$1,500',
#  '怪獸工場 - 灰階觀念篇': 'NT$1,500',
#  '實作「冬季甜點首部曲」DESSERT - WILLIAMS SONOMA': 'NT$600',
#  '打出靈魂的節奏 - Cajon 木箱鼓 系列入門 1': 'NT$500',
#  '旅行中手繪建築插畫，你也可以！': 'NT$500',
#  '超簡單讓你學會 Beatbox': 'NT$400',
#  '用 Illustrator 畫出你的原創角色': 'NT$600',
#  '臉部素描－輕鬆打好人物畫基礎': 'NT$350',
#  '一學就會的澎澎甜甜圈精緻吊飾': 'NT$350',
#  '讓您的畫作說故事！圖像感情的經營之道': 'NT$300',
#  '超實用！暖場破冰魔術': 'NT$350',
#  '西洋棋國手教你下西洋棋': 'NT$450',
#  '透視超訣竅(下)  如何運用透視畫出複雜的建築': 'NT$500',
#  '用電腦畫出手繪風賀卡！': 'NT$300',
#  '吉他從零開始 - 初級篇': 'NT$600',
#  '透視超訣竅(上)  如何運用透視畫出複雜的建築': 'NT$500',
#  '自己當導演！全方位微電影製作（基礎）': 'NT$500',
#  '掌握產品素描 - ID Sketch（入門）': 'NT$300',
#  '和以莉高露一起學吉他': 'NT$250',
#  '超療癒！唐幼馨的孕婦瑜伽': 'NT$499',
#  '火箭飛船遊太空 Rocket 2': 'NT$1,200',
#  '火箭發射飛行中 Rocket 1': 'NT$1,200',
#  '火箭準備起飛了 Yoga Basics': 'NT$1,200',
#  '超好玩！李麥克的親子玩具製作': 'NT$199',
#  '動物插畫': 'NT$300',
#  '超滿足！王師傅的元氣料理': 'NT$299',
#  '超 EAZY！在家初學的紓壓瑜伽': 'NT$199',
#  '做自己的藏書票（新孔版）': 'NT$150',
#  '法式繽紛馬卡龍': 'NT$500',
#  '簡單學會入門款 【復古手工書 】': 'NT$200',
#  '糖果娃娃 - 學校畢業紀念娃娃': 'NT$150',
#  '為申請學校或工作寫好英文自傳': 'NT$600',
#  '療癒感手繪插畫食譜': 'NT$200',
#  '教你用免費軟體 混音組曲當 DJ！': 'NT$1,000',
#  '不一樣的西洋美術史': 'NT$288',
#  'Line 的貼圖自己動手做！': 'NT$185',
#  '數位拼貼的手感': 'NT$300',
#  '幾何圖形分割 X 色塊組合': 'NT$100'}
