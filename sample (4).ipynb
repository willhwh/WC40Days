# %% [markdown]
# # 動態網頁爬蟲 - API Request
#
# * 了解 API Request 用於動態網頁爬蟲的原理
# * 能夠使用 API Request 撰寫動態網頁爬蟲

# %% [markdown]
# ## 觀察 API 請求資訊

# %% [markdown]
# ![](https://imgur.com/obLkbFe.jpg)

# %% [markdown]
# ## 作業目標
#
# * 根據範例的教學，去找出 Dcard 中呼叫的 API 當中，有一個跟「取得所有看板」是哪一個？並且利用 Requests 呼叫。

# %% [markdown]
# ![Screen%20Shot%202020-05-18%20at%205.45.33%20PM.png](attachment:Screen%20Shot%202020-05-18%20at%205.45.33%20PM.png)

# %%
import requests
import json

# %%
boards=['rainbow','food','dreesup']
for baord in boards:
    link='https://www.dcard.tw/service/api/v2/forums/{0}/posts?popular=true&limit=30'.format(board)
    print(link)
    r = requests.get(link)
    d = json.loads(r.text)
    print(d)
# Out:
# https://www.dcard.tw/service/api/v2/forums/dressup/posts?popular=true&limit=30
# ...

# %%
d
# Out:
# [{'id': 233694419,
#   'title': 'Uniqlo U圓領T 你收集了幾色♡',
#   'excerpt': '在UQ工作後衣櫥裡的素T 都是U圓領T，超好穿 布料是滑面的磅數又厚 不會透膚 超讚的，排開就是療癒，今年超推31色 奶油米白色 （自取） 好好看（๑˃̵ᴗ˂̵） 想知道大家都買什麼顏色～每年的顏色都',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': 'be1a095b-175e-4523-9e06-66a05d939676',
#   'replyId': None,
#   'createdAt': '2020-05-17T14:18:45.677Z',
#   'updatedAt': '2020-05-18T11:30:21.431Z',
#   'commentCount': 497,
#   'likeCount': 3336,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['衣服', 'UNIQLO'],
#   'meta': {'layout': 'classic'},
#   'forumName': '穿搭',
#   'forumAlias': 'dressup',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '南開科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'fc019184-b328-4c4a-9fe7-128d77990963',
#     'url': 'https://megapx-assets.dcard.tw/images/4d24251c-746c-4d6a-9fa4-477d6bd123bb/160.jpeg',
#     'normalizedUrl': 'https://megapx-assets.dcard.tw/images/4d24251c-746c-4d6a-9fa4-477d6bd123bb/160.jpeg',
# ...
