# %% [markdown]
# # 靜態網頁的資料爬蟲策略
#
#
# * 了解靜態網頁的資料爬蟲策略
# * 認識適用於靜態網頁爬蟲的相關套件工具：Request
# * 認識適用於靜態網頁爬蟲的相關套件工具：BeatifulSoup

# %% [markdown]
# ## 作業目標
#
# 利用 Request + BeatifulSoup 爬取下列兩個網站內容並解析：
#
# 1. Dcared 網址： https://www.dcard.tw/f
# 2. 知乎： https://www.zhihu.com/explore
#
# 並且回答下面問題：
#
# 1. Request 取回之後該怎麼取出資料，資料型態是什麼？
# 2. 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？
# 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %% [markdown]
# ### 1. Dcard 網址： https://www.dcard.tw/f

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.dcard.tw/f'
r=requests.get(url)

r.encoding = 'utf-8'
print(r.text[0:3000])
# Out:
# <!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><link rel="stylesheet" type="text/css" href="https://fonts.googleapis.com/css?family=Roboto:400,300"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><meta property="al:android:app_name" content="Dcard"/><link rel="manifest" href="/_next/static/manifest.json"/><link rel="icon" type="image/png" sizes="16x16" href="/_next/static/images/icon-16-1daa7474e5fe761a7239d12c56b88680.png"/><link rel="icon" type="image/png" sizes="24x24" href="/_next/static/images/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png"/><link rel="icon" type="image/png" sizes="32x32" href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/images/icon-192-49149beb434e1f6bccac918f6608564c.png"/><link rel="apple-touch-icon" type="image/png" sizes="57x57" href="/_next/static/images/icon-57-c95fcd930b41dbc6de0495348939582f.png"/><link rel="apple-touch-icon" type="image/png" sizes="72x72" href="/_next/static/images/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png"/><link rel="apple-touch-icon" type="image/png" sizes="76x76" href="/_next/static/images/icon-76-67203a784694f8378d2f51f24970e2f7.png"/><link rel="apple-touch-icon" type="image/png" sizes="114x114" href="/_next/static/images/icon-114-c58f911deb58868e8cc68ea1e09cc688.png"/><link rel="apple-touch-icon" type="image/png" sizes="120x120" href="/_next/static/images/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png"/><link rel="apple-touch-icon" type="image/png" sizes="144x144" href="/_next/static/images/icon-144-679d873aa4b58f1117915545d3fdfa1d.png"/><link rel="apple-touch-icon" type="image/png" sizes="152x152" href="/_next/static/images/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png"/><link rel="apple-touch-icon" type="image/png" sizes="180x180" href="/_next/static/images/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png"/><link rel="shortcut icon" type="image/png" href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gt

# %%
print('Request 取回之後該怎麼取出資料，資料型態是什麼？ =>')

print(type(r.text))
# Out:
# Request 取回之後該怎麼取出資料，資料型態是什麼？ =>
# <class 'str'>

# %%
print('為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ => ')
soup = BeautifulSoup(r.text, "html5lib")
print(soup)
print(type(soup))
# Out:
# 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ =>
# <!DOCTYPE html>
# <html lang="zh-TW"><head itemscope="" itemtype="https://schema.org/WebSite" prefix="og: http://ogp.me/ns#"><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/><meta content="default" name="apple-mobile-web-app-status-bar-style"/><link href="https://fonts.googleapis.com/css?family=Roboto:400,300" rel="stylesheet" type="text/css"/><meta content="Dcard" name="application-name"/><meta content="app-id=951353454" name="apple-itunes-app"/><meta content="#006aa6" name="theme-color"/><meta content="yes" name="mobile-web-app-capable"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="light" name="supported-color-schemes"/><meta content="211628828926493" property="fb:app_id"/><meta content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764" property="fb:pages"/><meta content="951353454" property="al:ios:app_store_id"/><meta content="Dcard" property="al:ios:app_name"/><meta content="com.sparkslab.dcardreader" property="al:android:package"/><meta content="Dcard" property="al:android:app_name"/><link href="/_next/static/manifest.json" rel="manifest"/><link href="/_next/static/images/icon-16-1daa7474e5fe761a7239d12c56b88680.png" rel="icon" sizes="16x16" type="image/png"/><link href="/_next/static/images/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png" rel="icon" sizes="24x24" type="image/png"/><link href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="icon" sizes="32x32" type="image/png"/><link href="/_next/static/images/icon-192-49149beb434e1f6bccac918f6608564c.png" rel="icon" sizes="192x192" type="image/png"/><link href="/_next/static/images/icon-57-c95fcd930b41dbc6de0495348939582f.png" rel="apple-touch-icon" sizes="57x57" type="image/png"/><link href="/_next/static/images/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png" rel="apple-touch-icon" sizes="72x72" type="image/png"/><link href="/_next/static/images/icon-76-67203a784694f8378d2f51f24970e2f7.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/><link href="/_next/static/images/icon-114-c58f911deb58868e8cc68ea1e09cc688.png" rel="apple-touch-icon" sizes="114x114" type="image/png"/><link href="/_next/static/images/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/><link href="/_next/static/images/icon-144-679d873aa4b58f1117915545d3fdfa1d.png" rel="apple-touch-icon" sizes="144x144" type="image/png"/><link href="/_next/static/images/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/><link href="/_next/static/images/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/><link href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="shortcut icon" type="image/png"/><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-TWLTW4M');</script><meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/><meta charset="utf-8"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" name="description"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="og:description"/><meta content="website" property="og:type"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="twitter:description"/><meta content="https://www.dcard.tw/images/landing.png" itemprop="image" name="image"/><meta content="https://www.dcard.tw/images/landing.png" property="og:image"/><meta content="https://www.dcard.tw/images/landing.png" property="og:image:secure_url"/><meta content="https://www.dcard.tw/images/landing.png" property="twitter:image"/><title>Dcard</title><link href="https://www.dcard.tw/f" rel="canonical"/><meta content="https://www.dcard.tw/f" itemprop="url" name="url"/><meta content="Dcard" property="og:site_name"/><meta content="Dcard" property="og:title"/><meta content="https://www.dcard.tw/f" property="og:url"/><meta content="Dcard" property="twitter:title"/><meta content="dcard://category/all/%E5%85%A8%E9%83%A8/hot" property="al:android:url"/><meta content="dcard://category" property="al:ios:url"/><script type="application/ld+json">{"@context":"https://schema.org","@type":"CollectionPage","name":"Dcard","url":"https://www.dcard.tw/f","description":"廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"}</script><script type="application/ld+json">{"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Dcard","item":"https://www.dcard.tw"},{"@type":"ListItem","position":2,"name":"全部","item":"https://www.dcard.tw/f"}]}</script><meta content="21" name="next-head-count"/><link as="style" href="/_next/static/css/6d1bbc10820647a103b8.css" rel="preload"/><link href="/_next/static/css/6d1bbc10820647a103b8.css" rel="stylesheet"/><link as="script" href="/_next/static/tHbZZenqbhkCanLpQ7oNm/pages/forum.js" rel="preload"/><link as="script" href="/_next/static/tHbZZenqbhkCanLpQ7oNm/pages/_app.js" rel="preload"/><link as="script" href="/_next/static/chunks/commons.23a5ca801a9c9812d59b.js" rel="preload"/><link as="script" href="/_next/static/chunks/00f0fadd406dd3012cf621fbc2eca3f2c8274672.c73cd90a604ee231c759.js" rel="preload"/><link as="script" href="/_next/static/chunks/3079fdc3133a8fd9356af38d1a5546959243baf1.0ec0780d93a30be16ebc.js" rel="preload"/><link as="script" href="/_next/static/chunks/979af3517416bf1ff58af059fa629f8792fccd34.973fcdc6f3c8b3c0637e.js" rel="preload"/><link as="script" href="/_next/static/chunks/86.b9b20c66672656e2039c.js" rel="preload"/><link as="script" href="/_next/static/chunks/d25ee3136c33695b5e78ede96b1119ddbd24f96f.1367cc81e55c13012c0b.js" rel="preload"/><link as="script" href="/_next/static/chunks/3c4859d19f00ad0f5d804de5d236492f40221cb1.354692c7b5d0973351fe.js" rel="preload"/><link as="script" href="/_next/static/chunks/98.cc70d5300303073be11d.js" rel="preload"/><link as="script" href="/_next/static/chunks/52e8e7bf1ff61c301939ae7b6cd70b7830a43f75.8903fa714d707be7e0e5.js" rel="preload"/><link as="script" href="/_next/static/chunks/2c9699ecc5a246d7a78dbf03b2ec8541c8acbf4e.0e36d06e70cdc88dc955.js" rel="preload"/><link as="script" href="/_next/static/chunks/97.bafe10ddcfe403415bac.js" rel="preload"/><link as="script" href="/_next/static/chunks/119.85d8207b19f15a22e9e1.js" rel="preload"/><link as="script" href="/_next/static/chunks/101.3cbd3d8f1995aa14362f.js" rel="preload"/><link as="script" href="/_next/static/chunks/430b1ba4e52dec45f14492f9b77c2c0aa4e50016.cff47e2afb4b09e017dd.js" rel="preload"/><link as="script" href="/_next/static/chunks/22b67f6682a5742d76c657686549d479750aed0b.f0751f70648283595006.js" rel="preload"/><link as="script" href="/_next/static/chunks/88.3ea3cf9ef6c10407b884.js" rel="preload"/><link as="script" hr ...
# /* sc-component-id: sc-global-1522344194 */
# body{background-color:#00324e;}
# /* sc-component-id: ksi2hf-0 */
# .eNbBFe{display:none;}
# /* sc-component-id: ydgdj7-0 */
# .hhSnba{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .hhSnba img,.hhSnba svg{height:100%;width:100%;}.gCQlMD{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:26px;height:26px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .gCQlMD img,.gCQlMD svg{height:100%;width:100%;}.iYfIzd{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:24px;height:24px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .iYfIzd img,.iYfIzd svg{height:100%;width:100%;}.jkPESf{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:40px;height:40px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .jkPESf img,.jkPESf svg{height:100%;width:100%;}.gRIdVl{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .gRIdVl img,.gRIdVl svg{height:100%;width:100%;}.iMiymk{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:16px;height:16px;fill:#c4c4c4;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .iMiymk img,.iMiymk svg{height:100%;width:100%;}.ieFmwo{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:16px;height:16px;fill:rgba(0,0,0,.6);stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .ieFmwo img,.ieFmwo svg{height:100%;width:100%;}.joALQw{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#3397cf;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .joALQw img,.joALQw svg{height:100%;width:100%;}.iLWWtS{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:18px;height:18px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .iLWWtS img,.iLWWtS svg{height:100%;width:100%;}.bwTNRH{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:44px;height:44px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .bwTNRH img,.bwTNRH svg{height:100%;width:100%;}.cbhXy{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:24px;height:24px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .cbhXy img,.cbhXy svg{height:100%;width:100%;}.bVLqqa{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:21px;height:21px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);}  ...
# /* sc-component-id: sc-1ag928-0 */
# .kUMklR{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-sizing:border-box;outline:none;font-size:16px;line-height:normal;border-radius:4px;padding:0 10px;height:40px;width:100%;-webkit-flex:1;-ms-flex:1;flex:1;color:rgba(0,0,0,.85);border:1px solid rgba(0,0,0,0.25);} .kUMklR::-webkit-input-placeholder{color:#c1c2c5;} .kUMklR::-moz-placeholder{color:#c1c2c5;} .kUMklR:-ms-input-placeholder{color:#c1c2c5;} .kUMklR::placeholder{color:#c1c2c5;}
# /* sc-component-id: pw4e6a-0 */
# .ierzKU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;} .ierzKU form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#00588a;border-radius:4px;overflow:hidden;width:100%;}.dODGjA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;} .dODGjA form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:rgb(238,238,238);border-radius:4px;overflow:hidden;width:100%;}
# /* sc-component-id: pw4e6a-1 */
# .fWARvU{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;font-size:14px;color:#fff;}.bkAvTt{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;font-size:16px;}
# /* sc-component-id: pw4e6a-2 */
# .jMlptb{background:#006aa6;border:1px solid #00588a;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:0 4px 4px 0;padding:0 9px;cursor:pointer;outline:none;}
# /* sc-component-id: pw4e6a-3 */
# .elZfHj{padding-left:10px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: pw4e6a-4 */
# .copHwd{padding:0 2px;}
# /* sc-component-id: sc-1divb7s-0 */
# .kkFyqs{position:-webkit-sticky;position:sticky;top:60px;background:#fafafa;border-bottom:1px solid #dedede;padding:0 60px;z-index:10;}.jGSaFz{position:-webkit-sticky;position:sticky;top:48px;background:#fff;border-bottom:1px solid #dedede;padding:0 16px;z-index:10;}
# /* sc-component-id: sc-1divb7s-1 */
# .jgHqud{padding-top:10px;}
# /* sc-component-id: sc-1divb7s-2 */
# .fvImY{height:40px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-1divb7s-3 */
# .jqcDIF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: sc-1divb7s-4 */
# .kQMWIM{height:100%;white-space:nowrap;} .kQMWIM:first-child{padding-left:0;} .kQMWIM a{color:#3397cf;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 20px;} .kQMWIM a::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}.eOmoiY{height:100%;white-space:nowrap;} .eOmoiY:first-child{padding-left:0;} .eOmoiY a{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 20px;} .eOmoiY a::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}.iXnhSl{height:100%;white-space:nowrap;-webkit-flex:1;-ms-flex:1;flex:1;} .iXnhSl:first-child{padding-left:0;} .iXnhSl a{color:#3397cf;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 0px;} .iXnhSl a::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}.glFNEP{height:100%;white-space:nowrap;-webkit-flex:1;-ms-flex:1;flex:1;} .glFNEP:first-child{padding-left:0;} .glFNEP a{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 0px;} .glFNEP a::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}
# /* sc-component-id: r0dumd-0 */
# .hraxjl{position:fixed;top:60px;right:25px;z-index:1000;}.eZbqml{position:fixed;bottom:33px;left:50%;right:50%;width:100vw;z-index:1000;}
# /* sc-component-id: sc-84v443-0 */
# .jAlbWa{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:#3397cf;color:#fff;} .jAlbWa:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .jAlbWa:hover{background:#006aa6;}.kgcVsA{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:13px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:#3397cf;color:#fff;} .kgcVsA:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);}.kGxGfT{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:1px solid #fff;color:#fff;background:transparent;} .kGxGfT:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);}.iIxOaU{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:none;opacity:0.5;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:#3397cf;color:#fff;} .iIxOaU:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .iIxOaU:hover{background:#006aa6;}.bcPQqz{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:13px;padding:0 16px;height:37px;pointer-events:none;opacity:0.5;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:#3397cf;color:#fff;} .bcPQqz:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);}.kUHSsi{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:1px solid #c1c2c5;background:#fff;color:rgba(0,0,0,.6);} .kUHSsi:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .kUHSsi:hover{background:#efefef;} .kUHSsi:active{box-shadow:inset 0 1px 2px 0 rgba(0,0,0,0.3);}.eSJmXu{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:13px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:1px solid #c1c2c5;background:#fff;color:rgba(0,0,0,.6);} .eSJmXu:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .eSJmXu:active{box-shadow:inset 0 1px 2px 0 rgba(0,0,0,0.3);}.fXqGIR{display:inline-block;position:relative;outline:none;-web ...
# /* sc-component-id: sc-84v443-2 */
# .jnmJtt> button{border-radius:0;} .jnmJtt>*:first-child{border-radius:4px 0 0 4px;border-right-width:0;} .jnmJtt>*:first-child button{border-radius:4px 0 0 4px;border-right-width:0;} .jnmJtt>*:last-child{border-radius:0 4px 4px 0;border-left-width:0;} .jnmJtt>*:last-child button{border-radius:0 4px 4px 0;border-left-width:0;}
# /* sc-component-id: avchkw-0 */
# .lcIqKn{display:grid;max-width:1280px;margin:auto;padding:60px 20px 0 0;grid-template-columns:[start] 208px [mainLeft] auto [mainRight] 300px [end];-webkit-transition:grid-template-columns .5s;transition:grid-template-columns .5s;}
# /* sc-component-id: avchkw-1 */
# .dLkKRc{grid-column:start / mainLeft;}
# /* sc-component-id: avchkw-2 */
# .ciNPhh{min-width:calc(728px + 24px);grid-column:mainLeft / mainRight;}.hpsGZq{min-width:calc(undefinedpx + 0px);grid-column:mainLeft / mainRight;}
# /* sc-component-id: avchkw-3 */
# .kIHllc{grid-column:mainRight / end;}
# /* sc-component-id: sc-17vj83f-0 */
# .iJCqeQ{margin:0 12px;min-height:calc(100vh - 80px);min-width:728px;padding-top:20px;height:100%;}.kqKnyl{-webkit-flex:1;-ms-flex:1;flex:1;margin:0 0px;min-height:calc(100vh - 48px);min-width:0px;padding-top:0px;height:100%;}
# /* sc-component-id: sc-17vj83f-1 */
# .hSVvaC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-top:0px;}
# /* sc-component-id: sc-17vj83f-2 */
# .nlkop{height:100%;background:#fafafa;border-radius:4px 4px 0 0;}
# /* sc-component-id: cagncm-0 */
# .heuwav{position:relative;}
# /* sc-component-id: cagncm-1 */
# .LDAeQ{visibility:hidden;padding-top:calc(100% / 1.7777777777777777);pointer-events:none;}.bjdYUu{visibility:hidden;padding-top:calc(100% / 0.5624999999999993);pointer-events:none;}.bOYByu{visibility:hidden;padding-top:calc(100% / 0.5625);pointer-events:none;}.hwdXcL{visibility:hidden;padding-top:calc(100% / 1.8181818181818181);pointer-events:none;}.iDnaPx{visibility:hidden;padding-top:calc(100% / 1.7799999999999998);pointer-events:none;}.hIxRsU{visibility:hidden;padding-top:calc(100% / 0.6081081081081081);pointer-events:none;}.eGHBpF{visibility:hidden;padding-top:calc(100% / 0.7562499999999982);pointer-events:none;}.jOLwdE{visibility:hidden;padding-top:calc(100% / 0.7500000000000019);pointer-events:none;}.jIVHRC{visibility:hidden;padding-top:calc(100% / 1);pointer-events:none;}.lmWxXW{visibility:hidden;padding-top:calc(100% / 1.7679558011049723);pointer-events:none;}.ksBdyw{visibility:hidden;padding-top:calc(100% / 5);pointer-events:none;}.gBKTwh{visibility:hidden;padding-top:calc(100% / 1.7722222222222224);pointer-events:none;}.dOkRgV{visibility:hidden;padding-top:calc(100% / 1.3333333333333333);pointer-events:none;}.ejGGcN{visibility:hidden;padding-top:calc(100% / 1.787709497206704);pointer-events:none;}.fPUdMX{visibility:hidden;padding-top:calc(100% / 0.8624999999999999);pointer-events:none;}.kzfyvZ{visibility:hidden;padding-top:calc(100% / 2.162162162162162);pointer-events:none;}.fMTeMY{visibility:hidden;padding-top:calc(100% / 1.7391304347826089);pointer-events:none;}.jkGRpF{visibility:hidden;padding-top:calc(100% / 0.8);pointer-events:none;}.fQzSqc{visibility:hidden;padding-top:calc(100% / 0.5555555555555556);pointer-events:none;}.chEPPv{visibility:hidden;padding-top:calc(100% / 0.4666666666666667);pointer-events:none;}.hXfVSM{visibility:hidden;padding-top:calc(100% / 0.73125);pointer-events:none;}.fHznXz{visibility:hidden;padding-top:calc(100% / 1.4678899082568806);pointer-events:none;}.fJtwvR{visibility:hidden;padding-top:calc(100% / 0.5660377358490566);pointer-events:none;}.cElpbt{visibility:hidden;padding-top:calc(100% / 1.4893617021276597);pointer-events:none;}.dNlAQx{visibility:hidden;padding-top:calc(100% / 2.1666666666666665);pointer-events:none;}.capuLP{visibility:hidden;padding-top:calc(100% / 0.7207207207207208);pointer-events:none;}.cnIlhe{visibility:hidden;padding-top:calc(100% / 1.774074074074074);pointer-events:none;}.jNwtlj{visibility:hidden;padding-top:calc(100% / 0.75);pointer-events:none;}.hFDKYk{visibility:hidden;padding-top:calc(100% / 3);pointer-events:none;}.eGVkJA{visibility:hidden;padding-top:calc(100% / 1.7791666666666668);pointer-events:none;}.dtauNI{visibility:hidden;padding-top:calc(100% / 1.6161616161616161);pointer-events:none;}.jVNDlw{visibility:hidden;padding-top:calc(100% / 0.5);pointer-events:none;}.gGHnFD{visibility:hidden;padding-top:calc(100% / 1.1443661971830985);pointer-events:none;}.ibRuXO{visibility:hidden;padding-top:calc(100% / 0.9882903981264638);pointer-events:none;}.jPcQfP{visibility:hidden;padding-top:calc(100% / 1.4983277591973243);pointer-events:none;}.bRccIs{visibility:hidden;padding-top:calc(100% / 1.1);pointer-events:none;}.ghKRtU{visibility:hidden;padding-top:calc(100% / 1.6949152542372883);pointer-events:none;}.kTHVFM{visibility:hidden;padding-top:calc(100% / 1.081081081081081);pointer-events:none;}.dPpkNK{visibility:hidden;padding-top:calc(100% / 0.98125);pointer-events:none;}.hjUALt{visibility:hidden;padding-top:calc(100% / 0.46249999999999997);pointer-events:none;}.kGNRhO{visibility:hidden;padding-top:calc(100% / 1.2777777777777777);pointer-events:none;}.iOzsDO{visibility:hidden;padding-top:calc(100% / 1.775);pointer-events:none;}.nPcXo{visibility:hidden;padding-top:calc(100% / 0.46250000000000047);pointer-events:none;}.flvdrU{visibility:hidden;padding-top:calc(100% / 0.565625);pointer-events:none;}.ceocSa{visibility:hidden;padding-top:calc(100% / 0.5360134003350083);pointer-events:none;}.jeIltF{visibility:hidden;padding-top:calc(100% / 0.5357142857142857);pointe ...
# /* sc-component-id: cagncm-2 */
# .fNGJuR{position:absolute;left:0;top:0;right:0;bottom:0;}
# /* sc-component-id: sc-1ist1s2-0 */
# .cRUrbl{width:100%;}
# /* sc-component-id: sc-1qq954t-0 */
# .kYQETz{height:100%;}
# /* sc-component-id: bvzz47-0 */
# .jrlgGO{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;}.gxfQHx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;pointer-events:none;}
# /* sc-component-id: bvzz47-1 */
# .fEehkS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;opacity:0.75;}.itqZIx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: bvzz47-2 */
# .cBnrmc{display:block;height:20px;width:20px;border-radius:50%;border:2px solid #fafafa;margin-left:-4px;} .cBnrmc:first-child{margin-left:0;}.fqZlER{display:block;height:21px;width:21px;border-radius:50%;border:2px solid #fff;margin-left:-4px;} .fqZlER:first-child{margin-left:0;}.eIziSL{display:block;height:24px;width:24px;border-radius:50%;border:2px solid #fafafa;margin-left:-4px;} .eIziSL:first-child{margin-left:0;}.ivZWVt{display:block;height:20px;width:20px;border-radius:50%;border:2px solid #fff;margin-left:-4px;} .ivZWVt:first-child{margin-left:0;}
# /* sc-component-id: bvzz47-3 */
# .hZFMwL{padding-left:6px;}
# /* sc-component-id: cra5e8-0 */
# .gpDnCL{border-radius:50%;overflow:hidden;}
# /* sc-component-id: cra5e8-1 */
# .hbaYDn{background:#2490bf;color:#fff;font-size:25.6px;height:40px;width:40px;line-height:40px;text-align:center;border-radius:50%;}.fYHPhX{background:#cb3a6b;color:#fff;font-size:25.6px;height:40px;width:40px;line-height:40px;text-align:center;border-radius:50%;}.hAyDgJ{background:#cb3a6b;color:#fff;font-size:12.8px;height:20px;width:20px;line-height:20px;text-align:center;border-radius:50%;}.iVFhUp{background:#cb3a6b;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}.fPjsad{background:#2490bf;color:#fff;font-size:12.8px;height:20px;width:20px;line-height:20px;text-align:center;border-radius:50%;}.ldnNRb{background:#2490bf;color:#fff;font-size:30.72px;height:48px;width:48px;line-height:48px;text-align:center;border-radius:50%;}.ehIwJk{background:#cb3a6b;color:#fff;font-size:30.72px;height:48px;width:48px;line-height:48px;text-align:center;border-radius:50%;}.buwgzc{background:#2490bf;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}.eiVDLb{background:#2490bf;color:#fff;font-size:64px;height:100px;width:100px;line-height:100px;text-align:center;border-radius:50%;}.dLdNOh{background:#cb3a6b;color:#fff;font-size:64px;height:100px;width:100px;line-height:100px;text-align:center;border-radius:50%;}
# /* sc-component-id: cra5e8-2 */
# .ksDGRc{display:block;border-radius:50%;object-fit:cover;}
# /* sc-component-id: ulutkk-0 */
# .iKgfXR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:14px;}.bdZmTC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:13px;}
# /* sc-component-id: ulutkk-1 */
# .ivbvQc{white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: ulutkk-2 */
# .hXoZkZ{color:rgba(0,0,0,.6);} .hXoZkZ:not(:last-child)::after{content:'·';padding:0 0.5em;}
# /* sc-component-id: ulutkk-3 */
# .bWuoYI{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin-right:8px;}
# /* sc-component-id: ulutkk-5 */
# .eJhRoL{background-color:#a3a3a3;color:#fff;font-size:12px;padding:3px 4px;border-radius:4px;margin-left:8px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: ulutkk-6 */
# .eUUiOP{margin-left:3px;}
# /* sc-component-id: ulutkk-7 */
# .gFxUyu{-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}
# /* sc-component-id: uzae24-0 */
# .eSWhfz{width:100%;height:100%;position:relative;background:#000;}
# /* sc-component-id: uzae24-1 */
# .Fzfdz{position:absolute;top:0;left:0;width:100%;height:100%;}
# /* sc-component-id: cgkbr-0 */
# .dVbdRN{border:0;width:100%;}
# /* sc-component-id: sc-1n5ks60-0 */
# .bLpAcs{background-color:rgb(250,250,250);padding:20px 0 16px 0;border-bottom:1px solid #d9d9d9;}.ljZaZc{background-color:#fff;padding:20px 0 16px 0;border-bottom:1px solid #d9d9d9;}
# /* sc-component-id: sc-1n5ks60-1 */
# .gUkFib{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,.5);font-size:14px;margin-bottom:14px;}
# /* sc-component-id: sc-1n5ks60-2 */
# .gLEJWb{background-color:#f0b941;padding:2px 4px;border-radius:4px;color:#fff;margin-right:10px;}.gpGROt{background-color:rgba(0,0,0,0.35);padding:2px 4px;border-radius:4px;color:#fff;margin-right:10px;}
# /* sc-component-id: sc-1n5ks60-3 */
# .gsITcD{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;color:rgba(0,0,0,.5);font-size:14px;line-height:1;}
# /* sc-component-id: sc-1n5ks60-4 */
# .eEnMxW{color:#f0b941;font-weight:bold;font-size:28px;margin-right:10px;}
# /* sc-component-id: sc-1n5ks60-5 */
# .hBQCmL{-webkit-text-decoration-line:line-through;text-decoration-line:line-through;}
# /* sc-component-id: sc-1aui6l1-0 */
# .iFXkqk{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: sc-1aui6l1-1 */
# .kyLyek{border:none;background:#a8a8a8;width:12px;height:12px;border-radius:50%;margin:0 8px;padding:0;cursor:pointer;outline:none;}.bxUwdt{border:none;background:rgba(168,168,168,0.3);width:12px;height:12px;border-radius:50%;margin:0 8px;padding:0;cursor:pointer;outline:none;}
# /* sc-component-id: sc-1v5l8ro-0 */
# .cboeuQ{position:relative;}
# /* sc-component-id: sc-1v5l8ro-2 */
# .jTdrJK{border:none;background:none;position:absolute;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);opacity:0;cursor:pointer;outline:none;padding:0;left:20px;} .sc-1v5l8ro-0:hover .jTdrJK{opacity:1;}
# /* sc-component-id: sc-1v5l8ro-3 */
# .htnUjJ{border:none;background:none;position:absolute;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);opacity:0;cursor:pointer;outline:none;padding:0;right:20px;} .sc-1v5l8ro-0:hover .htnUjJ{opacity:1;}
# /* sc-component-id: sc-1v5l8ro-5 */
# .iCmpce{position:absolute;bottom:12px;left:50%;-webkit-transform:translateX(-50%);-ms-transform:translateX(-50%);transform:translateX(-50%);}
# /* sc-component-id: sc-1xsathd-0 */
# .frmeSE{width:100%;height:calc((728px - 120px) * (3 / 4));background-size:cover;background-position:center center;background-repeat:no-repeat;}.fFVWmP{width:100%;height:calc((100vw - 32px) * (3 / 4));background-size:cover;background-position:center center;background-repeat:no-repeat;}
# /* sc-component-id: sc-13e2k1-0 */
# .bAfPQq{margin:20px 0;}
# /* sc-component-id: xt0n8u-0 */
# .loyxor{border:0;}
# /* sc-component-id: omlszd-0 */
# .bbxbmN{border:0;height:100%;width:100%;}
# /* sc-component-id: sc-5aa8ap-0 */
# .gpeOcj{border:0;height:100%;width:100%;}
# /* sc-component-id: sc-1r4us9h-0 */
# .cDOlbF{overflow:hidden;position:relative;max-width:100%;max-height:vh;}.gLRgot{overflow:hidden;position:relative;max-width:100%;max-height:60vh;}
# /* sc-component-id: sc-1r4us9h-1 */
# .hTuwCj{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:vh;}.cuCQeX{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:60vh;}
# /* sc-component-id: sc-1r4us9h-2 */
# .bvlcaJ{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:vh;position:absolute;top:0;left:0;}.jzwjYE{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:60vh;position:absolute;top:0;left:0;}
# /* sc-component-id: kfwtwu-0 */
# .plPAm{position:relative;height:120px;padding:16px 0;width:100%;}.jxylh{position:relative;height:64px;padding:13px 0;width:100%;}
# /* sc-component-id: sc-1hbn6e7-0 */
# .cAUXkt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;text-align:center;padding:50px 0;}
# /* sc-component-id: sc-1hbn6e7-1 */
# .dagORX{display:block;width:250px;margin-bottom:30px;}
# /* sc-component-id: sc-1hbn6e7-2 */
# .fIvJvb{font-size:30px;font-weight:400;line-height:42px;margin-bottom:10px;}
# /* sc-component-id: sc-1hbn6e7-3 */
# .dARMVx{color:rgba(0,0,0,.45);font-size:18px;line-height:30px;max-width:45%;}
# /* sc-component-id: w1s81u-0 */
# .ghccAs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin:8px 0 6px;padding:0 10px;border:1px solid rgb(233,233,233);border-radius:4px;background:#fff;box-shadow:0 1px 2px #ddd;line-height:1.3;max-width:430px;width:100%;min-height:65px;overflow:hidden;}
# /* sc-component-id: w1s81u-1 */
# .jyJcRR{-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: w1s81u-2 */
# .dykAcs{margin-right:10px;border-radius:3px;padding:5px;overflow:hidden;background-color:#006aa6;}.cKxtrZ{margin-right:10px;border-radius:3px;overflow:hidden;background-color:#006aa6;}
# /* sc-component-id: w1s81u-3 */
# .feAVOA{-webkit-flex:1;-ms-flex:1;flex:1;min-width:0;}
# /* sc-component-id: w1s81u-4 */
# .gWtdfB{white-space:nowrap;text-overflow:ellipsis;overflow:hidden;font-size:16px;font-weight:bold;line-height:1.3;color:rgba(0,0,0,.85);padding-bottom:5px;}
# /* sc-component-id: w1s81u-5 */
# .ogdUz{white-space:nowrap;text-overflow:ellipsis;overflow:hidden;font-size:14px;color:rgba(0,0,0,.35);line-height:16px;height:16px;}
# /* sc-component-id: sc-1eso38c-0 */
# .lLnjb{margin:10px 0;}
# /* sc-component-id: hmo708-0 */
# .dkyZPk{white-space:pre-wrap;}
# /* sc-component-id: sc-1ro4bpk-0 */
# .jKdblb{font-size:15px;color:rgba(0,0,0,.6);line-height:1.6;word-wrap:break-word;}.jXIcFN{font-size:18px;line-height:1.6;word-wrap:break-word;}
# /* sc-component-id: sc-1ro4bpk-1 */
# .eTxtzv{padding-bottom:22px;}.bNRMtc{padding-bottom:16px;}
# /* sc-component-id: sc-1ro4bpk-2 */
# .aEXNq{padding:10px 0;border-top:1px solid rgb(233,233,233);border-bottom:1px solid rgb(233,233,233);}
# /* sc-component-id: sc-1ro4bpk-3 */
# .hPNbBN{font-size:16px;line-height:30px;color:rgba(0,0,0,.35);padding-bottom:3px;}.fMLUtJ{font-size:13px;line-height:30px;color:rgba(0,0,0,.35);padding-bottom:3px;}
# /* sc-component-id: sc-116rzs1-0 */
# .dYEYmA{font-size:19px;line-height:1.5;font-weight:500;word-wrap:break-word;color:rgba(0,0,0,.95);}.hzTqOV{font-size:30px;line-height:1.5;font-weight:500;word-wrap:break-word;color:rgba(0,0,0,.95);}
# /* sc-component-id: sc-1dy4jrl-0 */
# .dGuoO{padding:16px;border:1px solid rgb(233,233,233);border-radius:4px;}
# /* sc-component-id: sc-1dy4jrl-1 */
# .hSudgn{font-size:14px;padding-bottom:8px;}
# /* sc-component-id: sc-1dy4jrl-2 */
# .qyGOB{font-size:18px;color:rgba(0,0,0,.85);font-weight:normal;padding-bottom:8px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-1dy4jrl-3 */
# .cChNNo{padding:12px 0 22px;}.cHbQxZ{padding:12px 0 16px;}
# /* sc-component-id: sc-1dy4jrl-4 */
# .irssaW{font-size:14px;color:rgba(0,0,0,.6);white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-1dy4jrl-5 */
# .VJRLs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;color:rgba(0,0,0,.35);padding-top:50px;}
# /* sc-component-id: sc-1dy4jrl-6 */
# .kogORL:not(:last-child)::after{content:'·';padding:0 0.5em;}
# /* sc-component-id: x38uc4-0 */
# .hjRROS{grid-area:thumb;overflow:hidden;border-radius:4px;border:1px solid rgba(0,0,0,0.1);object-fit:cover;margin-left:20px;}.jOpoAq{grid-area:thumb;overflow:hidden;border-radius:4px;border:1px solid rgba(0,0,0,0.1);object-fit:cover;margin-left:16px;}
# /* sc-component-id: sc-1rp9nay-0 */
# .iFAYXP{margin:0 40px;padding:20px 20px;border-bottom:1px solid rgb(233,233,233);display:grid;grid-row-gap:12px;grid-template-areas:'header header' 'main thumb' 'footer thumb';grid-template-columns:1fr fit-content(84px);cursor:pointer;-webkit-tap-highlight-color:transparent;}.dIRWqE{margin:0 0px;padding:16px 16px;border-bottom:1px solid rgb(233,233,233);display:grid;grid-row-gap:12px;grid-template-areas:'header header' 'main thumb' 'footer thumb';grid-template-columns:1fr fit-content(72px);cursor:pointer;-webkit-tap-highlight-color:transparent;}
# /* sc-component-id: sc-1rp9nay-1 */
# .kbkhkz{grid-area:main;overflow:hidden;}
# /* sc-component-id: sc-1rp9nay-2 */
# .cQLDGK{font-size:14px;grid-area:header;overflow:hidden;}
# /* sc-component-id: sc-1rp9nay-3 */
# .hjiaRP{padding-bottom:8px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-1rp9nay-4 */
# .iylEpa{font-size:18px;color:rgba(0,0,0,.95);line-height:normal;}.jqeVLP{font-weight:normal;font-size:18px;color:rgba(0,0,0,.95);line-height:normal;}
# /* sc-component-id: sc-1rp9nay-5 */
# .BbchW{font-size:14px;color:rgba(0,0,0,.6);white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-1rp9nay-6 */
# .iFCZNH{font-size:14px;padding-left:4px;border-left:4px solid rgba(0,0,0,.15);color:rgba(0,0,0,.6);white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-1rp9nay-7 */
# .chxBzh{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;grid-area:footer;overflow:hidden;}
# /* sc-component-id: sc-1rp9nay-8 */
# .embxsz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-right:16px;}
# /* sc-component-id: sc-1rp9nay-9 */
# .evXCTK{padding-right:6px;}
# /* sc-component-id: sc-1rp9nay-11 */
# .fgsEtm{color:#3397cf;font-style:normal;}
# /* sc-component-id: sc-14deg4f-0 */
# .dqWqzv{background:#fff;}
# /* sc-component-id: rd4czy-0 */
# .gLgozE{padding:0 60px;}.eCXIkK{padding:0 16px;}
# /* sc-component-id: rd4czy-1 */
# .bkBufl{text-align:center;line-height:120px;color:rgba(0,0,0,.35);font-size:14px;}
# /* sc-component-id: sc-1ykc0nb-2 */
# .iNRVSl{display:inline-block;height:100%;}
# /* sc-component-id: sc-1yr042k-0 */
# .gpKohw{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-align-self:stretch;-ms-flex-item-align:stretch;align-self:stretch;white-space:nowrap;}
# /* sc-component-id: sc-1yr042k-1 */
# .kejNvk{border-left:1px solid rgb(222,222,222);padding-right:10px;height:30px;}
# /* sc-component-id: sc-1yr042k-2 */
# .daiIpF{cursor:pointer;border:none;background:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0;height:100%;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}
# /* sc-component-id: sc-1yr042k-4 */
# .duhhIF{margin-left:2px;}
# /* sc-component-id: sc-1yr042k-5 */
# .htVlD{color:rgba(0,0,0,.35);padding:0 5px;}
# /* sc-component-id: sc-1yr042k-6 */
# .lgWNNn{color:#3397cf;padding-left:2px;}
# /* sc-component-id: sc-1s7iq8o-0 */
# .iOjPQv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;}
# /* sc-component-id: sc-1s7iq8o-1 */
# .cKalRz{height:100%;-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: sc-1s7iq8o-2 */
# .dKebJG{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;font-size:16px;white-space:nowrap;color:rgba(0,0,0,.45);margin-right:20px;} .dKebJG > a{height:100%;} .dKebJG:last-child{margin-right:0;}.dGliJV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;font-size:16px;white-space:nowrap;color:rgba(0,0,0,.45);-webkit-flex:1;-ms-flex:1;flex:1;color:rgba(0,0,0,.35);font-weight:500;color:rgba(0,0,0,.6);} .dGliJV > a{height:100%;}.fJjvoY{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;font-size:16px;white-space:nowrap;color:rgba(0,0,0,.45);-webkit-flex:1;-ms-flex:1;flex:1;color:rgba(0,0,0,.35);font-weight:500;} .fJjvoY > a{height:100%;}.fACrXg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;font-size:16px;white-space:nowrap;color:rgba(0,0,0,.45);margin-right:20px;color:#3397cf;font-weight:500;} .fACrXg > a{height:100%;} .fACrXg:last-child{margin-right:0;}
# /* sc-component-id: sc-1s7iq8o-3 */
# .etevno{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;padding:0 16px;} .etevno::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}.cKmYJf{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;padding:0 5px;} .cKmYJf::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}.ejhEQx{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;padding:0 5px;} .ejhEQx::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}.bReBxG{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;padding:0 16px;} .bReBxG::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}
# /* sc-component-id: o9lczm-0 */
# .dcNdrk{display:block;border-radius:50%;object-fit:cover;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;overflow:hidden;}
# /* sc-component-id: z0xsuj-0 */
# .jXGXYv{height:-webkit-fit-content;height:-moz-fit-content;height:fit-content;}
# /* sc-component-id: z0xsuj-1 */
# .pgBqI{position:relative;top:0;z-index:1;width:100%;-webkit-transform:translate3d(0,0px,0);-ms-transform:translate3d(0,0px,0);transform:translate3d(0,0px,0);-webkit-transition:-webkit-transform 0.2s cubic-bezier(.4,0,.2,1);-webkit-transition:transform 0.2s cubic-bezier(.4,0,.2,1);transition:transform 0.2s cubic-bezier(.4,0,.2,1);}
# /* sc-component-id: gjnhoa-0 */
# .gvsHgZ{position:-webkit-sticky;position:sticky;top:60px;z-index:10;}
# /* sc-component-id: gjnhoa-1 */
# .dkztMQ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:60px;background:#fafafa;border-bottom:1px solid #dedede;padding:0 60px;}.eOqpTD{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:48px;background:#fff;border-bottom:1px solid #dedede;padding:0 16px;padding:0;}
# /* sc-component-id: gjnhoa-2 */
# .jUeWjN{height:8px;}
# /* sc-component-id: gjnhoa-3 */
# .dOaocD{color:#000;white-space:nowrap;font-size:30px;font-weight:500;margin-left:10px;} .dOaocD > a{color:inherit;}
# /* sc-component-id: gjnhoa-4 */
# .inlQlR{height:100%;margin:0 0 0 auto;}.bmbkUO{height:100%;margin:0 0 0 auto;margin:0;-webkit-flex:1;-ms-flex:1;flex:1;margin:0;width:100%;}.jnOTkv{height:100%;margin:0 0 0 auto;margin:0;width:100%;}.kFayiE{height:100%;margin:0 0 0 auto;margin:0;-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: c2strc-0 */
# .fIIbis{width:550px !important;}
# /* sc-component-id: aip51k-0 */
# .hskUee{padding-top:20px;}.cmjkHd{padding-top:0;}
# /* sc-component-id: sc-1r0yr6k-1 */
# .jHAnHT{width:100%;padding-top:calc(100% / 3);position:relative;}
# /* sc-component-id: sc-1r0yr6k-2 */
# ...
# /* sc-component-id: sc-1nb1ses-8 */
# .bquJZI{position:absolute;right:16px;fill:rgba(0,0,0,0.15);}
# /* sc-component-id: sc-1nb1ses-9 */
# .cAydWN{padding:20px 16px;font-size:15px;color:rgba(0,0,0,.35);}
# /* sc-component-id: sc-1nb1ses-10 */
# .gTWIOq{position:relative;display:block;width:100%;padding:16px;border-bottom:1px solid rgba(0,0,0,0.05);background-color:#fff;color:rgba(0,0,0,.6);font-size:17px;margin-top:5px;text-align:center;}
# /* sc-component-id: ie6wvd-0 */
# .gTOADb{height:48px;color:rgba(0,0,0,.35);line-height:48px;}
# /* sc-component-id: ie6wvd-1 */
# .bRXWjo{position:-webkit-sticky;position:sticky;z-index:10;top:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;height:48px;padding:0 16px;background-color:rgb(250,250,250);box-shadow:rgba(0,0,0,.35) 0 0 1px 0;color:rgba(0,0,0,.35);font-size:15px;} .bRXWjo .ie6wvd-0:not(:last-of-type){margin-right:25px;} .bRXWjo .ie6wvd-0:not(:last-of-type)::after{content:'＞';pointer-events:none;position:absolute;padding:0 5px;}
# /* sc-component-id: y3s7cu-0 */
# .ezIUZL{padding-top:30px;width:100%;background-color:#fff;}
# /* sc-component-id: y3s7cu-1 */
# .Imcbt{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;min-width:720px;max-width:1280px;margin:auto;}
# /* sc-component-id: y3s7cu-2 */
# .ccRKGO{position:absolute;top:0;right:50px;}
# /* sc-component-id: y3s7cu-3 */
# .dWMnHe{display:inline-block;margin-right:10px;}
# /* sc-component-id: y3s7cu-4 */
# .hwJdzb{border:1px solid #3397cf;}
# /* sc-component-id: y3s7cu-5 */
# .fBEMNt{height:100px;width:100px;}
# /* sc-component-id: y3s7cu-6 */
# .hbhur{margin-top:15px;font-size:24px;line-height:33px;color:rgba(0,0,0,.8);}
# /* sc-component-id: y3s7cu-7 */
# .gypTsL{font-size:14px;line-height:23px;color:rgba(0,0,0,.45);}
# /* sc-component-id: y3s7cu-8 */
# .dBMGCL{margin:8px 0 15px;}
# /* sc-component-id: y3s7cu-9 */
# .gpYAuB{border-radius:100vw;line-height:35px;margin:0 5px;}
# /* sc-component-id: y3s7cu-10 */
# .hiHxYL{position:-webkit-sticky;position:sticky;top:60px;z-index:10;background-color:#fff;border-bottom:1px solid rgba(0,0,0,0.15);width:100%;}
# /* sc-component-id: y3s7cu-11 */
# .dRIqAJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;width:480px;height:60px;margin:auto;}
# /* sc-component-id: y3s7cu-12 */
# .fFQZKv{height:100%;padding:0 10px;border-bottom:2px solid #3397cf;font-size:14px;line-height:58px;}.RMVyD{height:100%;padding:0 10px;border-bottom:2px solid transparent;font-size:14px;line-height:58px;color:rgba(0,0,0,.35);}
# /* sc-component-id: e1yc8n-0 */
# .dJBarR{width:100%;height:56px;border-top:1px solid rgba(0,0,0,0.05);background-color:#fff;}
# /* sc-component-id: e1yc8n-1 */
# .dhgIrV{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:600px;height:100%;margin:auto;color:rgba(0,0,0,.45);} .dhgIrV a{color:rgba(0,0,0,.45);}
# /* sc-component-id: sc-1neqvbe-0 */
# .eESbFC{min-height:100vh;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;padding-top:60px;background-color:rgb(250,250,250);}
# /* sc-component-id: sc-1neqvbe-1 */
# .nucvr{-webkit-flex:1;-ms-flex:1;flex:1;width:640px;margin:30px auto;}
# /* sc-component-id: sc-1neqvbe-2 */
# .dyvTHC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;min-height:calc(100vh - 48px);}
# /* sc-component-id: sc-1neqvbe-3 */
# .bwcxoB{-webkit-flex:1;-ms-flex:1;flex:1;width:100%;}
# /* sc-component-id: sc-5neb7b-0 */
# .idCkgm{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;height:100%;}
# /* sc-component-id: sc-5neb7b-1 */
# .ioQcNH img{height:164px;}
# /* sc-component-id: sc-1grr821-0 */
# .klNgtq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:88px;padding:20px;background-color:#fafafa;box-shadow:0 2px 4px 0 rgba(0,0,0,0.05);margin-bottom:10px;border:1px solid rgb(222,222,222);border-radius:4px;} .klNgtq:hover{background-color:#fff;}
# /* sc-component-id: sc-1jgpjwr-0 */
# .jkcMEZ{height:32px;width:78px;line-height:32px;font-size:15px;font-weight:500;}
# /* sc-component-id: sc-173wqjh-1 */
# .iepwgp{padding:0 60px;}
# /* sc-component-id: gj72ok-0 */
# .dVtQdk{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;}
# /* sc-component-id: gj72ok-1 */
# .kOehyt{color:rgba(0,0,0,.95);font-size:18px;font-size:18px;font-weight:normal;}
# /* sc-component-id: gj72ok-2 */
# .btkBFS{color:rgba(0,0,0,.6);padding-top:0.8em;}
# /* sc-component-id: sc-5lyygo-0 */
# .eOzFrE{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background-color:#fff;min-height:100vh;}
# /* sc-component-id: sc-5lyygo-1 */
# .krlvRE{-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-2i8szh-0 */
# .gFXEIu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#fff;position:relative;border-bottom:1px solid #dfdfdf;}
# /* sc-component-id: sc-2i8szh-1 */
# .cYyKPg{-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;overflow-x:auto;overflow-y:hidden;} .cYyKPg::-webkit-scrollbar{width:6px;height:6px;} .cYyKPg::-webkit-scrollbar-track:hover{background:rgba(0,0,0,0.3);} .cYyKPg::-webkit-scrollbar-thumb{background:rgba(0,0,0,0.5);border-radius:100vh;} .cYyKPg::-webkit-scrollbar{display:none;}
# /* sc-component-id: sc-2i8szh-2 */
# .lbEMIr{font-size:16px;white-space:nowrap;color:#000;padding:19px 17px;position:relative;font-weight:bold;} .lbEMIr::after{content:'';border-bottom:2px solid #f0b941;position:absolute;left:0;bottom:0;width:100%;}.hbzzjo{font-size:16px;white-space:nowrap;color:rgba(0,0,0,0.35);padding:19px 17px;position:relative;font-weight:bold;} .hbzzjo::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:0;width:100%;}
# /* sc-component-id: sc-2i8szh-3 */
# .geQVfb{background:none;border:none;padding:0 12px;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;outline:none;cursor:pointer;}
# /* sc-component-id: sc-2i8szh-4 */
# .gspxxW{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}
# /* sc-component-id: sc-1980x41-0 */
# .caYEsE{position:-webkit-sticky;position:sticky;width:100%;background-color:#fff;top:60px;padding:0 60px;border-radius:4px 4px 0 0;}
# /* sc-component-id: sc-1980x41-1 */
# .hJTCWE{font-size:24px;font-weight:bold;color:#000;background-color:#fff;padding:30px 0 10px;z-index:20;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-bottom:1px solid #dfdfdf;}
# /* sc-component-id: sc-1980x41-2 */
# .bfLtHd{background-color:#F2F3F4;border-radius:50%;width:40px;height:40px;position:relative;margin-right:13px;} .bfLtHd img{width:34px;height:34px;position:absolute;top:50%;left:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);}
# /* sc-component-id: sc-1khc4cn-0 */
# .WOuMT{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}
# /* sc-component-id: sc-1khc4cn-1 */
# .jexIQl{color:#fff;font-size:14px;border-radius:4px;background:#f0b941;padding:2px;margin-right:5px;margin-top:5px;}
# /* sc-component-id: sc-1qrjcza-0 */
# .exIniz{background:#fff;border-radius:10px;overflow:hidden;box-shadow:0px 3px 12px rgba(0,0,0,0.14);height:318px;} @media (max-width:375px){.exIniz{height:262px;}}
# /* sc-component-id: sc-1qrjcza-1 */
# .cbSnzv{width:100%;height:196px;overflow:hidden;} @media (max-width:375px){.cbSnzv{height:140px;}}
# /* sc-component-id: sc-1qrjcza-2 */
# .jJIaZR{width:100%;height:100%;object-fit:cover;display:block;}
# /* sc-component-id: sc-1qrjcza-3 */
# .iaFUdx{padding:8px;}
# /* sc-component-id: sc-1qrjcza-4 */
# .kwgChc{color:rgba(0,0,0,.5);font-size:12px;margin-bottom:2px;line-height:15px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-1qrjcza-5 */
# .dxFMDi{color:rgba(0,0,0,.95);font-size:14px;font-weight:500;line-height:17px;margin-bottom:4px;overflow:hidden;display:-webkit-box;text-overflow:ellipsis;-webkit-line-clamp:2;-webkit-box-orient:vertical;}
# /* sc-component-id: sc-1qrjcza-6 */
# .hBTfGg{color:#f0b941;font-size:16px;line-height:19px;font-weight:600;}
# /* sc-component-id: sc-1qrjcza-7 */
# @media (max-width:375px){.lePwhm .tag{margin-right:2px;}}
# /* sc-component-id: sc-117ywwl-0 */
# .dFFrLS{padding:20px 60px;}
# /* sc-component-id: sc-117ywwl-1 */
# .jbfJwI{display:grid;grid-template-columns:repeat(auto-fill,minmax(150px,1fr));grid-column-gap:10px;grid-row-gap:10px;}
# /* sc-component-id: sc-117ywwl-2 */
# .dpYkX{height:1px;}
# /* sc-component-id: sc-1nfgx48-0 */
# .iZTHgr{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-1nfgx48-1 */
# .jtERzi{background:#1f1f1f;border-radius:4px;color:#fff;padding:4px;line-height:1;}
# /* sc-component-id: sc-1nfgx48-2 */
# .fhiMIl{font-size:12px;color:rgba(0,0,0,.95);} .fhiMIl::before{content:':';padding:0 2px;}
# /* sc-component-id: sc-22ns0b-0 */
# .eTxeBz{background:rgb(250,250,250);position:relative;height:243px;border-radius:4px 4px 0 0;}
# /* sc-component-id: sc-22ns0b-1 */
# .dEesls{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: sc-22ns0b-2 */
# .lekQAR{padding:36px 0 36px 60px;-webkit-flex:1;-ms-flex:1;flex:1;height:100%;}
# /* sc-component-id: sc-22ns0b-3 */
# .gEtbuD{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-22ns0b-4 */
# .bjXrvs{font-size:16px;font-weight:bold;color:#f0b941;margin-right:12px;}
# /* sc-component-id: sc-22ns0b-5 */
# .cMgIWD{font-size:28px;font-weight:bold;color:rgba(0,0,0,.95);margin:15px 0;line-height:1.2;}
# /* sc-component-id: sc-22ns0b-6 */
# .ePyZJA{color:rgba(0,0,0,.45);font-size:14px;}
# /* sc-component-id: sc-22ns0b-7 */
# .kIGBXI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:baseline;-webkit-box-align:baseline;-ms-flex-align:baseline;align-items:baseline;padding:5px 0;}
# /* sc-component-id: sc-22ns0b-8 */
# .bnZydI{color:#f0b941;font-size:24px;font-weight:bold;margin-right:8px;}
# /* sc-component-id: sc-22ns0b-9 */
# .kMQskj{color:rgba(0,0,0,.35);font-size:12px;color:rgba(0,0,0,.35);-webkit-text-decoration:line-through;text-decoration:line-through;}
# /* sc-component-id: sc-22ns0b-10 */
# .cwTGAc{width:240px;height:243px;-webkit-clip-path:polygon(10% 0%,100% 0%,100% 100%,0% 100%);clip-path:polygon(10% 0%,100% 0%,100% 100%,0% 100%);background-size:cover;background-position:center center;background-repeat:no-repeat;border-top-right-radius:4px;} @media (max-width:375px){.cwTGAc{width:140px;-webkit-clip-path:polygon(20% 0%,100% 0%,100% 100%,0% 100%);clip-path:polygon(20% 0%,100% 0%,100% 100%,0% 100%);}}
# /* sc-component-id: sc-1xdmdu4-0 */
# .iswZjv{background-color:#fff;border-radius:4px;height:100%;}</style></head><body><div id="__next"><div class="sc-15zy2le-0 bUmARS"><div class="sc-1tl0s6i-0 gRRqRb"><div class="sc-1tl0s6i-1 bkKJCY"><a class="lvor8b-0 jsnIlX" href="/f" title="Dcard"><img alt="Dcard" class="sc-1ywcn7k-0 gYUaPZ" src="/_next/static/images/logo-6c547910a47669647856d4c9cc62f0ba.svg"/></a><div class="sc-15zy2le-1 DLzzZ"><div class="pw4e6a-0 ierzKU"><form><input aria-label="搜尋文章、看板、人物" class="sc-1ag928-0 kUMklR pw4e6a-1 fWARvU" name="query" placeholder="搜尋文章、看板、人物" type="search"/><button class="pw4e6a-2 jMlptb" title="搜尋"><span class="ydgdj7-0 hhSnba pw4e6a-5 etwaaz" fill="#fff" role="img" size="20"><svg viewBox="0 0 28 28"><path d="M22.9 21.2l-4.5-4.5A7.5 7.5 0 1017 18l4.5 4.5a.5.5 0 00.8 0l.5-.5a.5.5 0 000-.8zm-10.4-3.5a5.6 5.6 0 115.6-5.6 5.6 5.6 0 01-5.6 5.6z"></path></svg></span></button><button class="ksi2hf-0 eNbBFe" type="submit"></button></form></div></div></div><div class="sc-1tl0s6i-2 pwVHE" role="navigation"><a class="u7yy6z-0 fnZGBW" href="/signup?redirect=%2Ff" role="button"><span class="u7yy6z-1 fxrSjZ">登入</span></a><div class="sc-1ykc0nb-2 iNRVSl"><a class="u7yy6z-0 deAgGq" role="button" title="更多"><span class="u7yy6z-1 fxrSjZ"><span class="ydgdj7-0 gCQlMD u7yy6z-2 eFRAge" fill="#fff" role="img" size="26"><svg viewBox="0 0 24 24"><path d="M11.08 15.62l-4.69-4.69a1.31 1.31 0 01.92-2.24h9.38a1.31 1.31 0 01.92 2.24l-4.69 4.69a1.3 1.3 0 01-1.84 0z"></path><path d="M0 0h24v24H0z" fill="none"></path></svg></span></span></a></div></div></div></div><div class="avchkw-0 lcIqKn"><div class="avchkw-1 dLkKRc"><div class="sc-19x83id-0 eqvIEe"><a href="/forum/all"><div class="sc-1yi4rc3-0 btuVdm"><div class="sc-19x83id-1 iqLTew"><span class="ydgdj7-0 iYfIzd sc-19x83id-2 eJidNy" fill="#fff" role="img" size="24"><svg viewBox="0 0 24 24"><path d="M18.95 3H5.05A2.04 2.04 0 003 5.04v13.91A2.04 2.04 0 005.05 21h13.9A2.05 2.05 0 0021 18.96V5.03A2.05 2.05 0 0018.95 3zM6.68 17.73a1.64 1.64 0 111.64-1.64 1.64 1.64 0 01-1.64 1.64zm0-4.1A1.64 1.64 0 118.32 12a1.64 1.64 0 01-1.64 1.64zm0-4.08A1.64 1.64 0 118.32 7.9a1.64 1.64 0 01-1.64 1.64zm11.86 6.77a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.1a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.45a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.08a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1z" data-name="icon_md_forum"></path></svg></span></div><div class="sc-1vptqgj-1 fVjALD">所有看板</div></div></a><a href="/forum/popular"><div class="sc-1yi4rc3-0 btuVdm"><div class="sc-19x83id-1 iqLTew"><span class="ydgdj7-0 iYfIzd sc-19x83id-2 eJidNy" fill="#fff" role="img" size="24"><svg viewBox="0 0 24 24"><path d="M19.5 14.5a7.5 7.5 0 01-15 0 12.9 12.9 0 012.21-7.25l.02-.03a.18.18 0 01.04-.05.5.5 0 01.31-.15.51.51 0 01.55.46A3.36 3.36 0 0010.9 10a3.26 3.26 0 003.2-3.5 16.5 16.5 0 00-.32-2.9 1.63 1.63 0 01-.04-.19V3.4a.5.5 0 01.49-.5.51.51 0 01.28.08.45.45 0 01.1.09A15.95 15.95 0 0119.5 14.5zm-3.59-1.55a12.97 12.97 0 00-.22-1.32.5.5 0 00-.83-.27 7.93 7.93 0 01-3.73 1.77 2.94 2.94 0 00-2.63 2.93c0 2.55 3.3 4.32 5.95 1.5a5.75 5.75 0 001.46-4.6z" data-name="ic_hot"></path></svg></span></div><div class="sc-1vptqgj-1 fVjALD">即時熱門看板</div></div></a><a href="/goods"><div class="sc-1yi4rc3-0 btuVdm"><div class="sc-19x83id-1 iqLTew"><span class="ydgdj7-0 iYfIzd sc-5qff8c-0 jcFMFq" fill="#fff" role="img" size="24"><svg viewBox="0 0 24 24"><path d="M8 21a2 2 0 11-2-2 2 2 0 012 2zm10-2a2 2 0 102 2 2 2 0 00-2-2zm2.44-1.19v-1a.5.5 0 00-.5-.5H6.3a.5.5 0 01-.4-.81L7.05 14a1 1 0 00.16-.93L4.48 4.72A1 1 0 004 4.13l-1.85-.9a.5.5 0 00-.67.23l-.48.9a.51.51 0 00.24.64l1.47.71 2.43 7.48-.82 1a2.49 2.49 0 00-.09 2.94 2.62 2.62 0 002.2 1.1h13.5a.51.51 0 00.5-.42zm1.35-7V6.38a2 2 0 00-2-2H9.23A2 2 0 007.3 6.92l1.82 5.8a2 2 0 002.3 1.43l8.74-1.33a2 2 0 001.62-1.97z"></path></svg></span></div><div class="sc-1vptqgj-1 fVjALD">好物研究室</div></div></a><div class="wswqpf-0 ebZjiw ScrollbarsCustom" style="position:relative"><div class="wswqpf-1 IU ...
# <class 'bs4.BeautifulSoup'>

# %% [markdown]
# ### 2. 知乎： https://www.zhihu.com/explore

# %%
url = 'https://www.zhihu.com/explore'
r = requests.get(url)
r.encoding = 'utf-8'

print(r.text[0:600])
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %%
print('Request 取回之後該怎麼取出資料，資料型態是什麼？ =>')

print(type(r.text))
# Out:
# Request 取回之後該怎麼取出資料，資料型態是什麼？ =>
# <class 'str'>

# %%
print('為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ => ')
soup = BeautifulSoup(r.text, "html5lib")
print(soup)
print(type(soup))
# Out:
# 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ =>
# <!DOCTYPE html>
# <html data-hairline="true" data-theme="light" lang="zh"><head><meta charset="utf-8"/><title data-react-helmet="true">发现 - 知乎</title><meta content="width=device-width,initial-scale=1,maximum-scale=1" name="viewport"/><meta content="webkit" name="renderer"/><meta content="webkit" name="force-rendering"/><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><meta content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg" name="google-site-verification"/><meta content="有问题，上知乎。知乎，可信赖的问答社区，以让每个人高效获得可信赖的解答为使命。知乎凭借认真、专业和友善的社区氛围，结构化、易获得的优质内容，基于问答的内容生产方式和独特的社区机制，吸引、聚集了各行各业中大量的亲历者、内行人、领域专家、领域爱好者，将高质量的内容透过人的节点来成规模地生产和分享。用户通过问答等交流方式建立信任和连接，打造和提升个人影响力，并发现、获得新机会。" name="description" property="og:description"/><link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-152.67c7b278.png" rel="apple-touch-icon"/><link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-152.67c7b278.png" rel="apple-touch-icon" sizes="152x152"/><link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-120.b3e6278d.png" rel="apple-touch-icon" sizes="120x120"/><link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-76.7a750095.png" rel="apple-touch-icon" sizes="76x76"/><link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-60.a4a761d4.png" rel="apple-touch-icon" sizes="60x60"/><link href="https://static.zhihu.com/static/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://static.zhihu.com/static/search.xml" rel="search" title="知乎" type="application/opensearchdescription+xml"/><link href="//static.zhimg.com" rel="dns-prefetch"/><link href="//pic1.zhimg.com" rel="dns-prefetch"/><link href="//pic2.zhimg.com" rel="dns-prefetch"/><link href="//pic3.zhimg.com" rel="dns-prefetch"/><link href="//pic4.zhimg.com" rel="dns-prefetch"/><style>
# .u-safeAreaInset-top {
#   height: constant(safe-area-inset-top) !important;
#   height: env(safe-area-inset-top) !important;
#
# }
# .u-safeAreaInset-bottom {
#   height: constant(safe-area-inset-bottom) !important;
#   height: env(safe-area-inset-bottom) !important;
#
# }
# </style><link href="https://static.zhihu.com/heifetz/app.c91310dc4f140fccecd7.css" rel="stylesheet"/><link href="https://static.zhihu.com/heifetz/explore-routes.f253b5defa978f285109.css" rel="stylesheet"/><script crossorigin="anonymous" data-sentry-config="{&quot;dsn&quot;:&quot;https://65e244586890460588f00f2987137aa8@crash2.zhihu.com/193&quot;,&quot;sampleRate&quot;:0.1,&quot;release&quot;:&quot;355-6814eea9&quot;,&quot;ignoreErrorNames&quot;:[&quot;NetworkError&quot;,&quot;SecurityError&quot;],&quot;ignoreErrors&quot;:[&quot;origin message&quot;,&quot;Network request failed&quot;,&quot;Loading chunk&quot;,&quot;这个系统不支持该功能。&quot;,&quot;Can't find variable: webkit&quot;,&quot;Can't find variable: $&quot;,&quot;内存不足&quot;,&quot;out of memory&quot;,&quot;DOM Exception 18&quot;,&quot;The operation is insecure&quot;,&quot;[object Event]&quot;,&quot;[object FileError]&quot;,&quot;[object DOMError]&quot;,&quot;[object Object]&quot;,&quot;拒绝访问。&quot;,&quot;Maximum call stack size exceeded&quot;,&quot;UploadError&quot;,&quot;无法 fetch&quot;,&quot;draft-js&quot;,&quot;缺少 JavaScript 对象&quot;,&quot;componentWillEnter&quot;,&quot;componentWillLeave&quot;,&quot;componentWillAppear&quot;,&quot;getInlineStyleAt&quot;,&quot;getCharacterList&quot;],&quot;whitelistUrls&quot;:[&quot;static.zhihu.com&quot;]}" defer="" src="https://unpkg.zhimg.com/@cfe/sentry-script@latest/dist/init.js"></script></head><body><div id="root"><div><div class="LoadingBar"></div><div><header class="Sticky AppHeader" data-za-module="TopNavBar" role="banner"><div class="AppHeader-inner"><a aria-label="知乎" href="//www.zhihu.com"><svg aria-hidden="true" class="Icon ZhihuLogo ZhihuLogo--blue Icon--logo" height="30" style="height:30px;width:64px" viewBox="0 0 200 91" width="64"><title></title><g><path d="M53.29 80.035l7.32.002 2.41 8.24 13.128-8.24h15.477v-67.98H53.29v67.978zm7.79-60.598h22.756v53.22h-8.73l-8.718 5.473-1.587-5.46-3.72-.012v-53.22zM46.818 43.162h-16.35c.545-8.467.687-16.12.687-22.955h15.987s.615-7.05-2.68-6.97H16.807c1.09-4.1 2.46-8.332 4.1-12.708 0 0-7.523 0-10.085 6.74-1.06 2.78-4.128 13.48-9.592 24.41 1.84-.2 7.927-.37 11.512-6.94.66-1.84.785-2.08 1.605-4.54h9.02c0 3.28-.374 20.9-.526 22.95H6.51c-3.67 0-4.863 7.38-4.863 7.38H22.14C20.765 66.11 13.385 79.24 0 89.62c6.403 1.828 12.784-.29 15.937-3.094 0 0 7.182-6.53 11.12-21.64L43.92 85.18s2.473-8.402-.388-12.496c-2.37-2.788-8.768-10.33-11.496-13.064l-4.57 3.627c1.363-4.368 2.183-8.61 2.46-12.71H49.19s-.027-7.38-2.372-7.38zm128.752-.502c6.51-8.013 14.054-18.302 14.054-18.302s-5.827-4.625-8.556-1.27c-1.874 2.548-11.51 15.063-11.51 15.063l6.012 4.51zm-46.903-18.462c-2.814-2.577-8.096.667-8.096.667s12.35 17.2 12.85 17.953l6.08-4.29s-8.02-11.752-10.83-14.33zM199.99 46.5c-6.18 0-40.908.292-40.953.292v-31.56c1.503 0 3.882-.124 7.14-.376 12.773-.753 21.914-1.25 27.427-1.504 0 0 3.817-8.496-.185-10.45-.96-.37-7.24 1.43-7.24 1.43s-51.63 5.153-72.61 5.64c.5 2.756 2.38 5.336 4.93 6.11 4.16 1.087 7.09.53 15.36.277 7.76-.5 13.65-.76 17.66-.76v31.19h-41.71s.88 6.97 7.97 7.14h33.73v22.16c0 4.364-3.498 6.87-7.65 6.6-4.4.034-8.15-.36-13.027-.566.623 1.24 1.977 4.496 6.035 6.824 3.087 1.502 5.054 2.053 8.13 2.053 9.237 0 14.27-5.4 14.027-14.16V53.93h38.235c3.026 0 2.72-7.432 2.72-7.432z" fill-rule="evenodd"></path></g></svg></a><ul class="Tabs AppHeader-Tabs" role="navigation"><li class="Tabs-item AppHeader-Tab Tabs-item--noMeta" role="tab"><a class="Tabs-link AppHeader-TabsLink" data-za-not-track-link="true" href="//www.zhihu.com/">首页</a></li><li class="Tabs-item AppHeader-Tab Tabs-item--noMeta" role="tab"><a class="Tabs-link AppHeader-TabsLink is-active" data-za-not-track-link="true" href="//www.zhihu.com/explore">发现</a></li><li class="Tabs-item AppHeader-Tab Tabs-item--noMeta" role="tab"><a class="Tabs-link AppHeader-TabsLink" data-za-not-track-link="true" href="//www.zhihu.com/question/waiting">等你来答</a></li></ul><div class="SearchBar" data-za-module="PresetWordItem" role="search"><div class="SearchBar-toolWrapper"><form c ...
# 本圆桌推荐口粮茶为主，为中国茶文化为何不如咖啡做延伸思考。
# 饮茶使人褪去浮躁，活在当下，而不是停留于浮光掠影的荣光之中。欢迎来到本圆桌。</a><div class="ExploreRoundtableCard-info"><div class="ExploreRoundtableCard-guests"><img src="https://pic2.zhimg.com/50/36caa0435e3c612be47076d31f50de76_hd.jpg"/><img src="https://pic2.zhimg.com/50/03d2b2bdb_hd.jpg"/><span>2<!-- --> 位嘉宾参与</span></div><div class="ExploreRoundtableCard-count"><span>64<!-- --> 人关注</span></div></div></div><div class="ExploreRoundtableCard-followButton"><button class="ExploreFollowButton ExploreFollowButton--colored" style="color:rgba(179, 136, 125, 1)">关注圆桌</button></div></div><div class="ExploreRoundtableCard-questionList"><div class="ExploreRoundtableCard-questionItem"><a class="ExploreRoundtableCard-questionTitle" data-za-detail-view-id="5800" href="/question/349173717" rel="noopener noreferrer" target="_blank">想买实惠的口粮茶应该去哪？</a><div class="ExploreRoundtableCard-questionCounts"><span>111<!-- --> 个回答</span></div></div><div class="ExploreRoundtableCard-questionItem"><a class="ExploreRoundtableCard-questionTitle" data-za-detail-view-id="5800" href="/question/27487523" rel="noopener noreferrer" target="_blank">茶艺和茶道入门该怎么开始，有什么基本要求和可靠渠道？</a><div class="ExploreRoundtableCard-questionCounts"><span>41<!-- --> 个回答</span></div></div><div class="ExploreRoundtableCard-questionItem"><a class="ExploreRoundtableCard-questionTitle" data-za-detail-view-id="5800" href="/question/363544669" rel="noopener noreferrer" target="_blank">传统茶叶销售方式如何转型？</a><div class="ExploreRoundtableCard-questionCounts"><span>7<!-- --> 个回答</span></div></div></div></div></div></div><div class="ExploreHomePage-ContentSection-moreButton"><a data-za-detail-view-id="5802" href="/roundtable" rel="noreferrer noopener" target="_blank">查看更多圆桌<svg class="Zi Zi--ArrowRight" fill="currentColor" height="25" viewBox="0 0 24 24" width="25"><path d="M9.218 16.78a.737.737 0 0 0 1.052 0l4.512-4.249a.758.758 0 0 0 0-1.063L10.27 7.22a.737.737 0 0 0-1.052 0 .759.759 0 0 0-.001 1.063L13 12l-3.782 3.716a.758.758 0 0 0 0 1.063z" fill-rule="evenodd"></path></svg></a></div></div><div class="ExploreHomePage-ContentSection ExploreHomePage-section" id="collection"><div class="ExploreHomePage-ContentSection-header"><svg class="Zi Zi--Star" fill="currentColor" height="36" viewBox="0 0 24 24" width="36"><path d="M5.515 19.64l.918-5.355-3.89-3.792c-.926-.902-.639-1.784.64-1.97L8.56 7.74l2.404-4.871c.572-1.16 1.5-1.16 2.072 0L15.44 7.74l5.377.782c1.28.186 1.566 1.068.64 1.97l-3.89 3.793.918 5.354c.219 1.274-.532 1.82-1.676 1.218L12 18.33l-4.808 2.528c-1.145.602-1.896.056-1.677-1.218z" fill-rule="evenodd"></path></svg><span>热门收藏夹</span></div><div class="ExploreHomePage-ContentSection-body"><div class="ExploreHomePage-collections"><div class="ExploreCollectionCard ExploreHomePage-collectionCard"><div class="ExploreCollectionCard-header"><div class="ExploreCollectionCard-info"><a class="ExploreCollectionCard-title" data-za-detail-view-id="5804" data-za-detail-view-name="标题点击" href="/collection/31180103" rel="noopener noreferrer" target="_blank">随便收着</a><div class="ExploreCollectionCard-relatedMembers"><div class="ExploreCollectionCard-creator"><span class="UserLink ExploreCollectionCard-creatorAvatar"><div class="Popover"><div aria-expanded="false" aria-haspopup="true" aria-owns="null-content" id="null-toggle"><a class="UserLink-link" data-za-detail-view-element_name="User" data-za-detail-view-id="5806" href="//www.zhihu.com/people/fifixu" target="_blank"><img alt="许炎骏" class="Avatar UserLink-avatar" height="28" src="https://pic1.zhimg.com/84b87ddd0_is.jpg" srcset="https://pic1.zhimg.com/84b87ddd0_im.jpg 2x" width="28"/></a></div></div></span><a class="ExploreCollectionCard-creatorName" data-za-detail-view-id="5806" href="/people/fifixu" rel="noopener noreferrer" target="_blank">许炎骏</a><style data-emotion-css="18biwo">.css-18biwo{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}</style><sp ...
# <class 'bs4.BeautifulSoup'>

# %% [markdown]
# ### 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %%
import requests
url = 'https://www.zhihu.com/explore'
headers = {'user-agent': 'my-app/0.0.1'}
r = requests.get(url,headers=headers)

r.encoding = 'utf-8'
print(r.text[0:600])
# Out:
# <!doctype html>
# <html lang="zh" data-hairline="true" data-theme="light"><head><meta charSet="utf-8"/><title data-react-helmet="true">发现 - 知乎</title><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1"/><meta name="renderer" content="webkit"/><meta name="force-rendering" content="webkit"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg"/><meta name="description" property="og:description" content="有问题，上知乎。知乎，可信赖的问答社区，以让每个人高效获得可信赖的解答为使命。知乎凭借认真、专业和友善的社区氛围，结构化、易获得的
