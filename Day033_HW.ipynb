# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 未授權前存取

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html', verify = False)
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.text)
# Out:
# /Users/mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 本網站已依網站內容分級規定處理
# 警告︰您即將進入之看板內容需滿十八歲方可瀏覽。
# 若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。
#
#
#
#
#
#
# 我同意，我已年滿十八歲進入
#
#
# 未滿十八歲或不同意本條款離開
#
#
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
#
#
#
# (function(){window['__CF$cv$params']={r:'594819b8ad21f22e',m:'e196ed635b12c27ce420ca6ecf16e5152e757bfb-1589663584-1800-AWXLtu6q9bCbX12KGvtTQfohHXz72VXVUFqhoswCnLGBW3IcGKTU9vE2JWZSIyKPl+hpr4jJ8sVXxqOcjNu4ipeF4spNruQnpy6MVy77YUk6j8kCVX3G89OCl4pX6q5oXZ8L5dETOlgeoOXENFwVrS2pT7e5loXJX3Qi6Og9G4OReWivqzrnBsDHyDfAI7nK4g==',s:[0x6ecf687d36,0x22978d58d0],fb:100,}})();

# %% [markdown]
# ## 模仿授權機制

# %% [markdown]
# ### 方法一：先送登入，再送請求

# %%
rs = requests.session()
payload={
    'from':'/bbs/Gossiping/index.html',
    'yes': 'yes'
}
res = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
res = rs.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False)
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# /Users/mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
#
#
# [問卦] 看cheap的影片是不是很好睡？
#
#
# simon78410
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 simon78410 的文章
#
#
#  5/17
#
#
#
#
# 1
#
# Re: [問卦] 日本人：東京23區也大多是鄉下
#
#
# Rrrxddd
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Rrrxddd 的文章
#
#
#  5/17
#
#
#
#
# 9
#
# Re: [問卦] 我媽為了冰箱的冷凍庫翻臉...
#
#
# Jellyxkaki85
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Jellyxkaki85 的文章
#
#
#  5/17
#
#
#
#
# 5
#
# Re: [問卦] Re: 古代的甲甲怎麼打砲？
#
#
# stardust1224
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 stardust1224 的文章
#
#
#  5/17
#
#
#
#
#
#
# Re: [問卦] 小馮休學爆料→IG開放 這是什麼劇本?
#
#
# Mashin5566
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Mashin5566 的文章
#
#
#  5/17
#
#
#
#
#
#
# Re: [爆卦] 鍾肇政辭世
#
#
# assassinASHE
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 assassinASHE 的文章
#
#
#  5/17
#
#
#
#
# 2
#
# [問卦] 可不可以你也剛好喜歡我
#
#
# zntozteent
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 zntozteent 的文章
#
#
#  5/17
#
#
#
#
#
#
# [問卦] 燃燒～～～～～～～～～～
#
#
# fantasibear
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 fantasibear 的文章
#
#
#  5/17
#
#
#
#
# 3
#
# [問卦] 這個時間還不睡覺是？？？
#
#
# krit1009
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 krit1009 的文章
#
#
#  5/17
#
#
#
#
#
#
# Re: [新聞] 網友建議民進黨玩大一點：修憲
#
#
# tim200513
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 tim200513 的文章
#
#
#  5/17
#
#
#
#
# 1
#
# Re: [新聞] 「時力2.0」瞄準2022 徐永明：成為更負責
#
#
# rpg1510
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 rpg1510 的文章
#
#
#  5/17
#
#
#
#
#
#
# Re: [問卦] 喝了酒就不能做愛了？
#
#
# TOMMY75410
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 TOMMY75410 的文章
#
#
#  5/17
#
#
#
#
#
#
# Re: [問卦] 父母年收超過三百萬是什麼感覺
#
#
# ImHoluCan
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ImHoluCan 的文章
#
#
#  5/17
#
#
#
#
#
#
# Re: [問卦] 日本人：東京23區也大多是鄉下
#
#
# Subaru5566
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Subaru5566 的文章
#
#
#  5/17
#
#
#
#
#
#
# [問卦] 對血腥畫面逐漸無感
#
#
# lions1989
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 lions1989 的文章
#
#
#  5/17
#
#
#
#
# 1
#
# [問卦] google maps 機車行駛時間估計
#
#
# oxlittle
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 oxlittle 的文章
#
#
#  5/17
#
#
#
#
#
#
# Re: [問卦] 年收入80萬的都過什麼生活?
#
#
# dreeee
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 dreeee 的文章
#
#
#  5/17
#
#
#
#
# 2
#
# [新聞] 林佳龍：分防疫、安心與國際旅遊 下半年
#
#
# SammySosa
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 SammySosa 的文章
#
#
#  5/17
#
#
#
#
#
#
# [問卦] 八卦版人好少
#
#
# attyu
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 attyu 的文章
#
#
#  5/17
#
#
#
#
#
# 1
#
# [公告] 八卦板板規(2020.04.21)
#
#
# seabox
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 seabox 的文章
#
#
#  4/21
# !
#
#
#
# 13
#
# [協尋] 5/11 20:00五權五街車禍行車記錄器
#
#
# HiroXu
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 HiroXu 的文章
#
#
#  5/12
#
#
#
#
# 13
#
# [協尋] 5/7 新北市 新海橋 晚上10點行車記錄器
#
#
# niarmy
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 niarmy 的文章
#
#
#  5/12
#
#
#
#
# 29
#
# [公告] 五月份置底閒聊文
#
#
# Kay731
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Kay731 的文章
#
#
#  5/01
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
#
#
#
# (function(){window['__CF$cv$params']={r:'5948236608c47fac',m:'935c5a9db8ce148ae0c06ce1af7e7d62aa7b18a9-1589663980-1800-AetDnlHkm166fvzDDUk/0clDuKdE+AVyHXkFEFrDpB4qwJ6fwNy4Bs74ZWHcceNo6qBieTkbyOR6WAstG9qrnBCbAxkPnkSiEC7MirUATTVJUNZKkpY4kBdBRvHtoEH9azWTfuhE9ewdciVHeMdv55A=',s:[0xac9900addc,0xd425026332],fb:100,}})();

# %% [markdown]
# ### 方法二：在請求中帶入 cookie

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False, cookies={'over18': '1'})
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# /Users/mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
#
#
# [問卦] 看cheap的影片是不是很好睡？
#
#
# simon78410
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 simon78410 的文章
#
#
#  5/17
#
#
#
#
# 1
#
# Re: [問卦] 日本人：東京23區也大多是鄉下
#
#
# Rrrxddd
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Rrrxddd 的文章
#
#
#  5/17
#
#
#
#
# 9
#
# Re: [問卦] 我媽為了冰箱的冷凍庫翻臉...
#
#
# Jellyxkaki85
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Jellyxkaki85 的文章
#
#
#  5/17
#
#
#
#
# 5
#
# Re: [問卦] Re: 古代的甲甲怎麼打砲？
#
#
# stardust1224
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 stardust1224 的文章
#
#
#  5/17
#
#
#
#
#
#
# Re: [問卦] 小馮休學爆料→IG開放 這是什麼劇本?
#
#
# Mashin5566
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Mashin5566 的文章
#
#
#  5/17
#
#
#
#
#
#
# Re: [爆卦] 鍾肇政辭世
#
#
# assassinASHE
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 assassinASHE 的文章
#
#
#  5/17
#
#
#
#
# 2
#
# [問卦] 可不可以你也剛好喜歡我
#
#
# zntozteent
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 zntozteent 的文章
#
#
#  5/17
#
#
#
#
#
#
# [問卦] 燃燒～～～～～～～～～～
#
#
# fantasibear
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 fantasibear 的文章
#
#
#  5/17
#
#
#
#
# 3
#
# [問卦] 這個時間還不睡覺是？？？
#
#
# krit1009
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 krit1009 的文章
#
#
#  5/17
#
#
#
#
#
#
# Re: [新聞] 網友建議民進黨玩大一點：修憲
#
#
# tim200513
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 tim200513 的文章
#
#
#  5/17
#
#
#
#
# 1
#
# Re: [新聞] 「時力2.0」瞄準2022 徐永明：成為更負責
#
#
# rpg1510
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 rpg1510 的文章
#
#
#  5/17
#
#
#
#
#
#
# Re: [問卦] 喝了酒就不能做愛了？
#
#
# TOMMY75410
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 TOMMY75410 的文章
#
#
#  5/17
#
#
#
#
#
#
# Re: [問卦] 父母年收超過三百萬是什麼感覺
#
#
# ImHoluCan
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ImHoluCan 的文章
#
#
#  5/17
#
#
#
#
#
#
# Re: [問卦] 日本人：東京23區也大多是鄉下
#
#
# Subaru5566
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Subaru5566 的文章
#
#
#  5/17
#
#
#
#
#
#
# [問卦] 對血腥畫面逐漸無感
#
#
# lions1989
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 lions1989 的文章
#
#
#  5/17
#
#
#
#
# 1
#
# [問卦] google maps 機車行駛時間估計
#
#
# oxlittle
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 oxlittle 的文章
#
#
#  5/17
#
#
#
#
#
#
# Re: [問卦] 年收入80萬的都過什麼生活?
#
#
# dreeee
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 dreeee 的文章
#
#
#  5/17
#
#
#
#
# 2
#
# [新聞] 林佳龍：分防疫、安心與國際旅遊 下半年
#
#
# SammySosa
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 SammySosa 的文章
#
#
#  5/17
#
#
#
#
#
#
# [問卦] 八卦版人好少
#
#
# attyu
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 attyu 的文章
#
#
#  5/17
#
#
#
#
#
# 1
#
# [公告] 八卦板板規(2020.04.21)
#
#
# seabox
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 seabox 的文章
#
#
#  4/21
# !
#
#
#
# 13
#
# [協尋] 5/11 20:00五權五街車禍行車記錄器
#
#
# HiroXu
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 HiroXu 的文章
#
#
#  5/12
#
#
#
#
# 13
#
# [協尋] 5/7 新北市 新海橋 晚上10點行車記錄器
#
#
# niarmy
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 niarmy 的文章
#
#
#  5/12
#
#
#
#
# 29
#
# [公告] 五月份置底閒聊文
#
#
# Kay731
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Kay731 的文章
#
#
#  5/01
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
#
#
#
# (function(){window['__CF$cv$params']={r:'5948238c8b138125',m:'799aee555529c4508625921c60d30e9105a9ffda-1589663986-1800-AUxy4ug9nsI9Vj7I3ennNi0ds6qkJigfUDFpBAMoRUnXJpza8ukCMbxNrIMzx35lwubtUyFdKH9PcSt6rkwtWckxkqIxRaaUs7K32VA9XekBnjDeCxPfdGzfjFL/Hko9043KelZK6xiKjJ+lCqpcjx0=',s:[0x78096beaff,0x870309a495],fb:100,}})();

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）

# %%
requests.get('https://api.github.com/user', auth=('email', 'pass'))
# Out:
# <Response [200]>
